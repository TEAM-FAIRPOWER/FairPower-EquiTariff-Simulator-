# %%
import pandas as pd
import numpy as np

# %%
households = pd.read_csv("Households_2019.csv")
access = pd.read_csv("API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_158.csv")
energy = pd.read_csv("Chapter-9-Energy-Tables.csv")
tariff = pd.read_csv("Average_Electricity_Yield.csv")

# %%
households.head()
# Out:
#       county               indicator    Unit  Date   Value
# 0    Mombasa    Number of Households  Number  2019  378422
# 1    Mombasa  Average Household size     NaN  2019       3
# 2  Changamwe    Number of Households  Number  2019   46614
# 3  Changamwe  Average Household size     NaN  2019       3
# 4      Jomvu    Number of Households  Number  2019   53472

# %%
access.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Kenya          KEN  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...  2016  2017  2018  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  53.1  55.8  61.2
#
#    2019  2020  2021  2022  2023  2024  2025
# 0  69.7  71.5  76.5    76  76.2   NaN   NaN
#
# [1 rows x 70 columns]

# %%
energy = pd.read_csv("Chapter-9-Energy-Tables.csv", skiprows=2)
energy.head()
# Out:
#          INDUSTRIES    SIEC    Agriculture    Mining & Quarrying   \
# 0   NATURAL INPUTS:      NaN          -                     -
# 1             Solar   7000.0            NaN                   NaN
# 2              Wind   7000.0            NaN                   NaN
# 3             Hydro   7000.0            NaN                   NaN
# 4       Geo-Thermal   7000.0            NaN                   NaN
#
#     Manufacturing   Electricity, Gas, Steam and Air Conditioning Supply   \
# 0         8,051.0                                           40,314.9
# 1              NaN                                          1,769.27
# 2              NaN                                          7,229.30
# 3              NaN                                          9,600.05
# 4              NaN                                         21,715.49
#
#    Construction   Transport and Storage   \
# 0          -                       -
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
#
#    Accommodation and Food Service Activities    Other Commercial Sectors   \
# 0                                       -                           -
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
#
#    Public Administration and Defense   Undefined     Households   \
# 0                               -           -       1,295,821.7
# 1                                 NaN         NaN            NaN
# 2                                 NaN         NaN            NaN
# 3                                 NaN         NaN            NaN
# 4                                 NaN         NaN            NaN
#
#    Accumulation/Stock   Rest of the World   Flows to the environment   \
# 0                -                   -                          -
# 1                  NaN                 NaN                        NaN
# 2                  NaN                 NaN                        NaN
# 3                  NaN                 NaN                        NaN
# 4                  NaN                 NaN                        NaN
#
#           Total  Unnamed: 17
# 0   1,344,187.5          NaN
# 1       1,769.3          NaN
# 2       7,229.3          NaN
# 3       9,600.1          NaN
# 4      21,715.5          NaN

# %%
energy.columns = [
    "Source", "SIEC", "Agriculture", "Mining", "Manufacturing",
    "Electricity_Gas", "Construction", "Transport", "Accommodation",
    "Commercial", "Public_Admin", "Undefined", "Households",
    "Accumulation", "Rest_of_World", "Environment", "Total", "Extra"
]

# %%
household_energy = energy[["Source", "Households"]]
print(household_energy)
# Out:
#                                                Source      Households
# 0                                    NATURAL INPUTS:     1,295,821.7
# 1                                              Solar              NaN
# 2                                               Wind              NaN
# 3                                              Hydro              NaN
# 4                                        Geo-Thermal              NaN
# 5                                      Co-Generation              NaN
# 6                                       Biomass Wood     1,295,821.7
# 7                       ENERGY PRODUCTS CONSUMPTION:              NaN
# 8                                         Petroleum:         1,394.6
# 9                               Motor Spirit Premium            -
# 10                                 Aviation gasoline            -
# 11                                          Jet fuel            -
# 12                             Illuminating Kerosene          173.43
# 13   White spirit and special boiling point indust...           -
# 14                                  Light Diesel Oil            -
# 15                                  Heavy Diesel Oil            -
# 16                                  Fuel oils n.e.c.            -
# 17                                  Lubricating Oils            -
# 18                               Lubricating Greases            -
# 19                       Other petroleum oils n.e.c.            -
# 20                   Liquified Petroleum Gas (L.P.G)        1,221.13
# 21                                     Coal and Coke              NaN
# 22                                       Electricity          11,513
# 23                     Domestic and Small Commercial        9,905.20
# 24                                  Large and Medium              NaN
# 25                                   Street Lighting              NaN
# 26                             Rural electrification        1,607.60
# 27                                             Other              NaN
# 28                                          Biomass:     1,254,181.4
# 29                                          Firewood    1,154,567.77
# 30                                          Charcoal       99,613.62
# 31                                Wood/Process Waste              NaN
# 32                  Farm residue/Animal crop residue              NaN
# 33                                        RESIDUALS:            -
# 34                                        Extraction              NaN
# 35                                    Transformation              NaN
# 36                                            Losses              NaN
# 37                                             Other              NaN
# 38                                         TOTAL USE     2,551,397.6
# 39                     1 Terajoule (TJ)=10^12 Joules              NaN
# 40                              1000 Tonnes=4.184 TJ              NaN
# 41                                      1 GWh=3.6 TJ              NaN

# %%
# Drop rows where Households is NaN or a dash
clean_energy = energy[energy["Households"].notna()]
clean_energy = clean_energy[clean_energy["Households"] != "-"]

# Convert Households column to numeric
clean_energy["Households"] = pd.to_numeric(clean_energy["Households"], errors="coerce")

# Drop any rows that still have NaN after conversion
clean_energy = clean_energy.dropna(subset=["Households"])

# %%
clean_energy["Households_kWh"] = clean_energy["Households"] * 277778

# %%
energy["Households"] = (
    energy["Households"]
    .astype(str)                # force everything to string
    .str.replace(",", "")       # remove commas
    .str.replace("-", "0")      # replace dash with 0
)

energy["Households"] = pd.to_numeric(energy["Households"], errors="coerce")

# %%
clean_energy = energy.dropna(subset=["Households"])

# %%
clean_energy.loc[:, "Households_kWh"] = clean_energy["Households"] * 277778
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_40840\3873151426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_energy.loc[:, "Households_kWh"] = clean_energy["Households"] * 277778

# %%
household_energy = energy[["Source", "Households"]]
print(household_energy)
# Out:
#                                                Source  Households
# 0                                    NATURAL INPUTS:   1295821.70
# 1                                              Solar          NaN
# 2                                               Wind          NaN
# 3                                              Hydro          NaN
# 4                                        Geo-Thermal          NaN
# 5                                      Co-Generation          NaN
# 6                                       Biomass Wood   1295821.70
# 7                       ENERGY PRODUCTS CONSUMPTION:          NaN
# 8                                         Petroleum:      1394.60
# 9                               Motor Spirit Premium         0.00
# 10                                 Aviation gasoline         0.00
# 11                                          Jet fuel         0.00
# 12                             Illuminating Kerosene       173.43
# 13   White spirit and special boiling point indust...        0.00
# 14                                  Light Diesel Oil         0.00
# 15                                  Heavy Diesel Oil         0.00
# 16                                  Fuel oils n.e.c.         0.00
# 17                                  Lubricating Oils         0.00
# 18                               Lubricating Greases         0.00
# 19                       Other petroleum oils n.e.c.         0.00
# 20                   Liquified Petroleum Gas (L.P.G)      1221.13
# 21                                     Coal and Coke          NaN
# 22                                       Electricity     11513.00
# 23                     Domestic and Small Commercial      9905.20
# 24                                  Large and Medium          NaN
# 25                                   Street Lighting          NaN
# 26                             Rural electrification      1607.60
# 27                                             Other          NaN
# 28                                          Biomass:   1254181.40
# 29                                          Firewood   1154567.77
# 30                                          Charcoal     99613.62
# 31                                Wood/Process Waste          NaN
# 32                  Farm residue/Animal crop residue          NaN
# 33                                        RESIDUALS:         0.00
# 34                                        Extraction          NaN
# 35                                    Transformation          NaN
# 36                                            Losses          NaN
# 37                                             Other          NaN
# 38                                         TOTAL USE   2551397.60
# 39                     1 Terajoule (TJ)=10^12 Joules          NaN
# 40                              1000 Tonnes=4.184 TJ          NaN
# 41                                      1 GWh=3.6 TJ          NaN

# %%
household_sources = household_energy[household_energy["Source"].isin([
    "Electricity", 
    "Domestic and Small Commercial", 
    "Rural electrification", 
    "Firewood", 
    "Charcoal", 
    "Liquified Petroleum Gas (L.P.G)", 
    "Illuminating Kerosene"
])]

# %%
household_sources["Households_kWh"] = household_sources["Households"] * 277778

# %%
total_household_energy = household_sources["Households_kWh"].sum()
print("Total Household Energy (kWh):", total_household_energy)
# Out:
# Total Household Energy (kWh): 0.0

# %%
energy["Households"] = (
    energy["Households"]
    .astype(str)                 # force everything to string
    .str.replace(",", "")        # remove commas
    .str.replace("-", "0")       # replace dash with 0
)

energy["Households"] = pd.to_numeric(energy["Households"], errors="coerce")

# %%
clean_energy = energy.dropna(subset=["Households"]).copy()

# %%
clean_energy["Households_kWh"] = clean_energy["Households"] * 277778

# %%
household_sources = clean_energy[clean_energy["Source"].isin([
    "Electricity", 
    "Domestic and Small Commercial", 
    "Rural electrification", 
    "Firewood", 
    "Charcoal", 
    "Liquified Petroleum Gas (L.P.G)", 
    "Illuminating Kerosene"
])]
print(household_sources)
# Out:
# Empty DataFrame
# Columns: [Source, SIEC, Agriculture, Mining, Manufacturing, Electricity_Gas, Construction, Transport, Accommodation, Commercial, Public_Admin, Undefined, Households, Accumulation, Rest_of_World, Environment, Total, Extra, Households_kWh]
# Index: []

# %%
total_household_energy = household_sources["Households_kWh"].sum()
print("Total Household Energy (kWh):", total_household_energy)
# Out:
# Total Household Energy (kWh): 0.0

# %%
print(energy["Source"].unique())
# Out:
# [' NATURAL INPUTS: ' ' Solar ' ' Wind ' ' Hydro ' ' Geo-Thermal '
#  ' Co-Generation ' ' Biomass Wood ' ' ENERGY PRODUCTS CONSUMPTION: '
#  ' Petroleum: ' ' Motor Spirit Premium ' ' Aviation gasoline '
#  ' Jet fuel ' ' Illuminating Kerosene '
#  ' White spirit and special boiling point industrial spirits '
#  ' Light Diesel Oil ' ' Heavy Diesel Oil ' ' Fuel oils n.e.c. '
#  ' Lubricating Oils ' ' Lubricating Greases '
#  ' Other petroleum oils n.e.c. ' ' Liquified Petroleum Gas (L.P.G) '
#  ' Coal and Coke ' ' Electricity ' ' Domestic and Small Commercial '
#  ' Large and Medium ' ' Street Lighting ' ' Rural electrification '
#  ' Other ' ' Biomass: ' ' Firewood ' ' Charcoal ' ' Wood/Process Waste '
#  ' Farm residue/Animal crop residue ' ' RESIDUALS: ' ' Extraction '
#  ' Transformation ' ' Losses ' ' TOTAL USE '
#  ' 1 Terajoule (TJ)=10^12 Joules ' ' 1000 Tonnes=4.184 TJ '
#  ' 1 GWh=3.6 TJ ']

# %%
energy["Source"] = energy["Source"].str.strip()

# %%
energy["Source"] = energy["Source"].str.replace(":", "", regex=False)
energy["Source"] = energy["Source"].str.strip()

# %%
household_sources = energy[energy["Source"].isin([
    "Electricity",
    "Domestic and Small Commercial",
    "Rural electrification",
    "Firewood",
    "Charcoal",
    "Liquified Petroleum Gas (L.P.G)",
    "Illuminating Kerosene"
])]

# %%
household_sources = energy[energy["Source"].isin([
    "Electricity",
    "Domestic and Small Commercial",
    "Rural electrification",
    "Firewood",
    "Charcoal",
    "Liquified Petroleum Gas (L.P.G)",
    "Illuminating Kerosene"
])].copy()

household_sources["Households_kWh"] = household_sources["Households"] * 277778

# %%
total_household_energy = household_sources["Households_kWh"].sum()
print("Total Household Energy (kWh):", total_household_energy)
# Out:
# Total Household Energy (kWh): 355167436911.5

# %%
# 1. Connected households (using access %)
households["connected_households"] = households["households"] * (access["access_pct"]/100)

# 2. Average household consumption (kWh per household)
households["avg_household_consumption"] = total_household_energy / households["connected_households"]

# 3. Monthly bill (Ksh)
households["monthly_bill"] = households["avg_household_consumption"] * tariff["tariff_ksh_per_kWh"]

# 4. Final dataset preview
print(households.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'households'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 2
#       1 # 1. Connected households (using access %)
# ----> 2 households["connected_households"] = households["households"] * (access["access_pct"]/100)
#       4 # 2. Average household consumption (kWh per household)
#       5 households["avg_household_consumption"] = total_household_energy / households["connected_households"]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'households'

# %%
print(households.columns)
# Out:
# Index(['county', 'indicator', 'Unit', 'Date', 'Value'], dtype='object')

# %%
households.rename(columns={"Value": "households"}, inplace=True)

# %%
# Connected households (using access %)
households["connected_households"] = households["households"] * (access["access_pct"]/100)

# Average household consumption (kWh per household)
households["avg_household_consumption"] = total_household_energy / households["connected_households"]

# Monthly bill (Ksh)
households["monthly_bill"] = households["avg_household_consumption"] * tariff["tariff_ksh_per_kWh"]

print(households.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'access_pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 2
#       1 # Connected households (using access %)
# ----> 2 households["connected_households"] = households["households"] * (access["access_pct"]/100)
#       4 # Average household consumption (kWh per household)
#       5 households["avg_household_consumption"] = total_household_energy / households["connected_households"]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'access_pct'

# %%
print(access.columns)

# %%
# Filter Kenya
access_kenya = access[access["Country Name"] == "Kenya"]

# Use 2019 electrification rate
access_pct = access_kenya["2019"].values[0]
print("Kenya electrification % (2019):", access_pct)

# Pipeline
households["connected_households"] = households["households"] * (access_pct/100)
households["avg_household_consumption"] = total_household_energy / households["connected_households"]
households["monthly_bill"] = households["avg_household_consumption"] * tariff["tariff_ksh_per_kWh"]

print(households.head())
# Out:
# Kenya electrification % (2019): 69.7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tariff_ksh_per_kWh'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 11
#       9 households["connected_households"] = households["households"] * (access_pct/100)
#      10 households["avg_household_consumption"] = total_household_energy / households["connected_households"]
# ---> 11 households["monthly_bill"] = households["avg_household_consumption"] * tariff["tariff_ksh_per_kWh"]
#      13 print(households.head())
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'tariff_ksh_per_kWh'

# %%
print(tariff.columns)
# Out:
# Index(['indicator', 'consumer-category', 'Unit', 'Date', 'Value'], dtype='object')

# %%
tariff.rename(columns={"Value": "tariff_ksh_per_kWh"}, inplace=True)

# %%
tariff_2019 = tariff[(tariff["Date"] == 2019) & 
                     (tariff["consumer-category"] == "Domestic")]["tariff_ksh_per_kWh"].values[0]
print("2019 Domestic Tariff (Ksh/kWh):", tariff_2019)
# Out:
# 2019 Domestic Tariff (Ksh/kWh): 16.36

# %%
households["monthly_bill"] = households["avg_household_consumption"] * tariff_2019
print(households.head())
# Out:
#       county               indicator    Unit  Date  households  \
# 0    Mombasa    Number of Households  Number  2019      378422
# 1    Mombasa  Average Household size     NaN  2019           3
# 2  Changamwe    Number of Households  Number  2019       46614
# 3  Changamwe  Average Household size     NaN  2019           3
# 4      Jomvu    Number of Households  Number  2019       53472
#
#    connected_households  avg_household_consumption  monthly_bill
# 0            263760.134               1.346555e+06  2.202963e+07
# 1                 2.091               1.698553e+11  2.778833e+12
# 2             32489.958               1.093161e+07  1.788411e+08
# 3                 2.091               1.698553e+11  2.778833e+12
# 4             37269.984               9.529584e+06  1.559040e+08

# %%
households_filtered = households[households["indicator"] == "Number of Households"].copy()

# %%
households_filtered["connected_households"] = households_filtered["households"] * (access_pct/100)

households_filtered["avg_household_consumption"] = total_household_energy / households_filtered["connected_households"]

households_filtered["monthly_bill"] = households_filtered["avg_household_consumption"] * tariff_2019

print(households_filtered.head())
# Out:
#       county             indicator    Unit  Date  households  \
# 0    Mombasa  Number of Households  Number  2019      378422
# 2  Changamwe  Number of Households  Number  2019       46614
# 4      Jomvu  Number of Households  Number  2019       53472
# 6    Kisauni  Number of Households  Number  2019       88202
# 8     Likoni  Number of Households  Number  2019       81191
#
#    connected_households  avg_household_consumption  monthly_bill
# 0            263760.134               1.346555e+06  2.202963e+07
# 2             32489.958               1.093161e+07  1.788411e+08
# 4             37269.984               9.529584e+06  1.559040e+08
# 6             61476.794               5.777260e+06  9.451598e+07
# 8             56590.127               6.276138e+06  1.026776e+08

# %%
county_summary = households_filtered.groupby("county").agg({
    "households": "sum",
    "connected_households": "sum",
    "avg_household_consumption": "mean",
    "monthly_bill": "mean"
}).reset_index()

print(county_summary.head())
# Out:
#                    county  households  connected_households  \
# 0         Aberdare Forest         112                78.064
# 1  Aberdare National Park          11                 7.667
# 2                Ainabkoi       34892             24319.724
# 3              Athi River      109735             76485.295
# 4                  Awendo       27033             18842.001
#
#    avg_household_consumption  monthly_bill
# 0               1.094580e+10  1.790732e+11
# 1               4.632417e+10  7.578635e+11
# 2               1.460409e+07  2.389229e+08
# 3               4.643604e+06  7.596936e+07
# 4               1.884977e+07  3.083823e+08

# %%
# Share of households per county
households_filtered["household_share"] = households_filtered["connected_households"] / households_filtered["connected_households"].sum()

# Allocate total energy proportionally
households_filtered["county_energy_kWh"] = households_filtered["household_share"] * total_household_energy

# Average household consumption per county
households_filtered["avg_household_consumption"] = households_filtered["county_energy_kWh"] / households_filtered["connected_households"]

# Monthly bill
households_filtered["monthly_bill"] = households_filtered["avg_household_consumption"] * tariff_2019

# %%
county_summary = households_filtered.groupby("county").agg({
    "households": "sum",
    "connected_households": "sum",
    "avg_household_consumption": "mean",
    "monthly_bill": "mean"
}).reset_index()

print(county_summary.head())
# Out:
#                    county  households  connected_households  \
# 0         Aberdare Forest         112                78.064
# 1  Aberdare National Park          11                 7.667
# 2                Ainabkoi       34892             24319.724
# 3              Athi River      109735             76485.295
# 4                  Awendo       27033             18842.001
#
#    avg_household_consumption   monthly_bill
# 0               20980.301268  343237.728739
# 1               20980.301268  343237.728739
# 2               20980.301268  343237.728739
# 3               20980.301268  343237.728739
# 4               20980.301268  343237.728739

# %%
county_only = households_filtered[households_filtered["county"].isin(list_of_true_counties)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 county_only = households_filtered[households_filtered["county"].isin(list_of_true_counties)]
#
# NameError: name 'list_of_true_counties' is not defined

# %%
list_of_true_counties = [
    "Mombasa","Kwale","Kilifi","Tana River","Lamu","Taita Taveta",
    "Garissa","Wajir","Mandera","Marsabit","Isiolo","Meru","Tharaka Nithi",
    "Embu","Kitui","Machakos","Makueni","Nyandarua","Nyeri","Kirinyaga",
    "Murang'a","Kiambu","Turkana","West Pokot","Samburu","Trans Nzoia",
    "Uasin Gishu","Elgeyo Marakwet","Nandi","Baringo","Laikipia","Nakuru",
    "Narok","Kajiado","Kericho","Bomet","Kakamega","Vihiga","Bungoma",
    "Busia","Siaya","Kisumu","Homa Bay","Migori","Kisii","Nyamira","Nairobi"
]

# %%
county_only = households_filtered[households_filtered["county"].isin(list_of_true_counties)]

# %%
subcounty_only = households_filtered[~households_filtered["county"].isin(list_of_true_counties)]

# %%
# Dual-mode function
def get_energy_data(level="county"):
    if level == "county":
        # Keep only county totals
        return households_filtered[households_filtered["county"].isin(list_of_true_counties)]
    elif level == "subcounty":
        # Keep only sub-county rows
        return households_filtered[~households_filtered["county"].isin(list_of_true_counties)]
    else:
        raise ValueError("level must be 'county' or 'subcounty'")

# %%
county_data = get_energy_data(level="county")
subcounty_data = get_energy_data(level="subcounty")

print(county_data.head())     # shows county totals
print(subcounty_data.head())  # shows sub-county breakdowns
# Out:
#       county             indicator    Unit  Date  households  \
# 0    Mombasa  Number of Households  Number  2019      378422
# 14     Kwale  Number of Households  Number  2019      173176
# 26    Kilifi  Number of Households  Number  2019      298472
# 76   Nyamira  Number of Households  Number  2019      150669
# 100    Kisii  Number of Households  Number  2019      308054
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 0              263760.134               20980.301268  343237.728739
# 14             120703.672               20980.301268  343237.728739
# 26             208034.984               20980.301268  343237.728739
# 76             105016.293               20980.301268  343237.728739
# 100            214713.638               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 0           0.015581       5.533767e+09
# 14          0.007130       2.532399e+09
# 26          0.012289       4.364637e+09
# 76          0.006203       2.203273e+09
# 100         0.012683       4.504757e+09
#        county             indicator    Unit  Date  households  \
# 2   Changamwe  Number of Households  Number  2019       46614
# 4       Jomvu  Number of Households  Number  2019       53472
# 6     Kisauni  Number of Households  Number  2019       88202
# 8      Likoni  Number of Households  Number  2019       81191
# 10      Mvita  Number of Households  Number  2019       38995
#
#     connected_households  avg_household_consumption   monthly_bill  \
# 2              32489.958               20980.301268  343237.728739
# 4              37269.984               20980.301268  343237.728739
# 6              61476.794               20980.301268  343237.728739
# 8              56590.127               20980.301268  343237.728739
# 10             27179.515               20980.301268  343237.728739
#
#     household_share  county_energy_kWh
# 2          0.001919       6.816491e+08
# 4          0.002202       7.819355e+08
# 6          0.003632       1.289802e+09
# 8          0.003343       1.187278e+09
# 10         0.001606       5.702344e+08

# %%
# County totals
county_data = get_energy_data(level="county")

# Sub-county breakdowns
subcounty_data = get_energy_data(level="subcounty")

# %%
county_from_sub = subcounty_data.groupby("county").agg({
    "households": "sum",
    "connected_households": "sum",
    "county_energy_kWh": "sum",
    "avg_household_consumption": "mean",
    "monthly_bill": "mean"
}).reset_index()

# %%
county_data = get_energy_data(level="county")
subcounty_data = get_energy_data(level="subcounty")

print(county_data.head())     # shows county totals
print(subcounty_data.head())  # shows sub-county breakdowns
# Out:
#       county             indicator    Unit  Date  households  \
# 0    Mombasa  Number of Households  Number  2019      378422
# 14     Kwale  Number of Households  Number  2019      173176
# 26    Kilifi  Number of Households  Number  2019      298472
# 76   Nyamira  Number of Households  Number  2019      150669
# 100    Kisii  Number of Households  Number  2019      308054
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 0              263760.134               20980.301268  343237.728739
# 14             120703.672               20980.301268  343237.728739
# 26             208034.984               20980.301268  343237.728739
# 76             105016.293               20980.301268  343237.728739
# 100            214713.638               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 0           0.015581       5.533767e+09
# 14          0.007130       2.532399e+09
# 26          0.012289       4.364637e+09
# 76          0.006203       2.203273e+09
# 100         0.012683       4.504757e+09
#        county             indicator    Unit  Date  households  \
# 2   Changamwe  Number of Households  Number  2019       46614
# 4       Jomvu  Number of Households  Number  2019       53472
# 6     Kisauni  Number of Households  Number  2019       88202
# 8      Likoni  Number of Households  Number  2019       81191
# 10      Mvita  Number of Households  Number  2019       38995
#
#     connected_households  avg_household_consumption   monthly_bill  \
# 2              32489.958               20980.301268  343237.728739
# 4              37269.984               20980.301268  343237.728739
# 6              61476.794               20980.301268  343237.728739
# 8              56590.127               20980.301268  343237.728739
# 10             27179.515               20980.301268  343237.728739
#
#     household_share  county_energy_kWh
# 2          0.001919       6.816491e+08
# 4          0.002202       7.819355e+08
# 6          0.003632       1.289802e+09
# 8          0.003343       1.187278e+09
# 10         0.001606       5.702344e+08

# %%
# County-level: Kiambu total
kiambu_county = county_data[county_data["county"] == "Kiambu"]

# Sub-county-level: all sub-counties under Kiambu
kiambu_subcounties = subcounty_data[subcounty_data["county"].str.contains("Kiambu", case=False)]

print("Kiambu County Total:\n", kiambu_county)
print("\nKiambu Subcounties:\n", kiambu_subcounties)
# Out:
# Kiambu County Total:
#       county             indicator    Unit  Date  households  \
# 458  Kiambu  Number of Households  Number  2019       47275
# 472  Kiambu  Number of Households  Number  2019      795241
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 458             32950.675               20980.301268  343237.728739
# 472            554282.977               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 458         0.001946       6.913151e+08
# 472         0.032742       1.162902e+10
#
# Kiambu Subcounties:
#  Empty DataFrame
# Columns: [county, indicator, Unit, Date, households, connected_households, avg_household_consumption, monthly_bill, household_share, county_energy_kWh]
# Index: []

# %%
# Example mapping for Kiambu
kiambu_subcounty_list = [
    "Githunguri","Ruiru","Thika Town","Limuru","Kiambaa",
    "Kikuyu","Kabete","Lari","Kiambu Town","Juja"
]

# Filter subcounties belonging to Kiambu
kiambu_subcounties = subcounty_data[subcounty_data["county"].isin(kiambu_subcounty_list)]

# County total
kiambu_county = county_data[county_data["county"] == "Kiambu"]

print("Kiambu County Total:\n", kiambu_county)
print("\nKiambu Subcounties:\n", kiambu_subcounties)
# Out:
# Kiambu County Total:
#       county             indicator    Unit  Date  households  \
# 458  Kiambu  Number of Households  Number  2019       47275
# 472  Kiambu  Number of Households  Number  2019      795241
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 458             32950.675               20980.301268  343237.728739
# 472            554282.977               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 458         0.001946       6.913151e+08
# 472         0.032742       1.162902e+10
#
# Kiambu Subcounties:
#           county             indicator    Unit  Date  households  \
# 450       Ruiru  Number of Households  Number  2019      129470
# 452      Limuru  Number of Households  Number  2019       49174
# 454        Lari  Number of Households  Number  2019       38592
# 456      Kikuyu  Number of Households  Number  2019       60686
# 460     Kiambaa  Number of Households  Number  2019       80332
# 462      Kabete  Number of Households  Number  2019       66710
# 464        Juja  Number of Households  Number  2019      104301
# 466  Githunguri  Number of Households  Number  2019       49426
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 450             90240.590               20980.301268  343237.728739
# 452             34274.278               20980.301268  343237.728739
# 454             26898.624               20980.301268  343237.728739
# 456             42298.142               20980.301268  343237.728739
# 460             55991.404               20980.301268  343237.728739
# 462             46496.870               20980.301268  343237.728739
# 464             72697.797               20980.301268  343237.728739
# 466             34449.922               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 450         0.005331       1.893275e+09
# 452         0.002025       7.190847e+08
# 454         0.001589       5.643412e+08
# 456         0.002499       8.874278e+08
# 460         0.003308       1.174717e+09
# 462         0.002747       9.755183e+08
# 464         0.004294       1.525222e+09
# 466         0.002035       7.227697e+08

# %%
county_to_subcounties = {
    "Mombasa": ["Changamwe","Jomvu","Kisauni","Likoni","Mvita","Nyali"],
    "Kwale": ["Kinango","Lunga Lunga","Msambweni","Matuga"],
    "Kilifi": ["Ganze","Kaloleni","Kilifi North","Kilifi South","Magarini","Malindi","Rabai"],
    "Tana River": ["Bura","Galole","Garsen"],
    "Lamu": ["Lamu East","Lamu West"],
    "Taita-Taveta": ["Mwatate","Taveta","Voi","Wundanyi"],
    "Garissa": ["Daadab","Fafi","Garissa Township","Hulugho","Ijara","Lagdera","Balambala"],
    "Wajir": ["Eldas","Tarbaj","Wajir East","Wajir North","Wajir South","Wajir West"],
    "Mandera": ["Banissa","Lafey","Mandera East","Mandera North","Mandera South","Mandera West"],
    "Marsabit": ["Laisamis","Moyale","North Hor","Saku"],
    "Isiolo": ["Isiolo","Merti","Garbatulla"],
    "Meru": ["Buuri","Igembe Central","Igembe North","Igembe South","Imenti Central","Imenti North","Imenti South","Tigania East","Tigania West"],
    "Tharaka-Nithi": ["Tharaka North","Tharaka South","Chuka","Igambang'ombe","Maara","Chiakariga","Muthambi"],
    "Embu": ["Manyatta","Mbeere North","Mbeere South","Runyenjes"],
    "Kitui": ["Kitui West","Kitui Central","Kitui Rural","Kitui South","Kitui East","Mwingi North","Mwingi West","Mwingi Central"],
    "Machakos": ["Kathiani","Machakos Town","Masinga","Matungulu","Mavoko","Mwala","Yatta"],
    "Makueni": ["Kaiti","Kibwezi West","Kibwezi East","Kilome","Makueni","Mbooni"],
    "Nyandarua": ["Kinangop","Kipipiri","Ndaragwa","Ol-Kalou","Ol Joro Orok"],
    "Nyeri": ["Kieni East","Kieni West","Mathira East","Mathira West","Mukurweini","Nyeri Town","Othaya","Tetu"],
    "Kirinyaga": ["Kirinyaga Central","Kirinyaga East","Kirinyaga West","Mwea East","Mwea West"],
    "Murang'a": ["Gatanga","Kahuro","Kandara","Kangema","Kigumo","Kiharu","Mathioya","Murang'a South"],
    "Kiambu": ["Gatundu North","Gatundu South","Githunguri","Juja","Kabete","Kiambaa","Kiambu","Kikuyu","Limuru","Ruiru","Thika Town","Lari"],
    "Turkana": ["Loima","Turkana Central","Turkana East","Turkana North","Turkana South"],
    "West Pokot": ["Central Pokot","North Pokot","Pokot South","West Pokot"],
    "Samburu": ["Samburu East","Samburu North","Samburu West"],
    "Trans-Nzoia": ["Cherangany","Endebess","Kiminini","Kwanza","Saboti"],
    "Uasin Gishu": ["Ainabkoi","Kapseret","Kesses","Moiben","Soy","Turbo"],
    "Elgeyo-Marakwet": ["Keiyo North","Keiyo South","Marakwet East","Marakwet West"],
    "Nandi": ["Aldai","Chesumei","Emgwen","Mosop","Nandi Hills","Tindiret"],
    "Baringo": ["Baringo Central","Baringo North","Baringo South","Eldama Ravine","Mogotio","Tiaty"],
    "Laikipia": ["Laikipia Central","Laikipia East","Laikipia North","Laikipia West","Nyahururu"],
    "Nakuru": ["Bahati","Gilgil","Kuresoi North","Kuresoi South","Molo","Naivasha","Nakuru Town East","Nakuru Town West","Njoro","Rongai","Subukia"],
    "Narok": ["Narok East","Narok North","Narok South","Narok West","Transmara East","Transmara West"],
    "Kajiado": ["Isinya","Kajiado Central","Kajiado North","Loitokitok","Mashuuru"],
    "Kericho": ["Ainamoi","Belgut","Bureti","Kipkelion East","Kipkelion West","Soin/Sigowet"],
    "Bomet": ["Bomet Central","Bomet East","Chepalungu","Konoin","Sotik"],
    "Kakamega": ["Butere","Kakamega Central","Kakamega East","Kakamega North","Kakamega South","Khwisero","Lugari","Lukuyani","Lurambi","Matete","Mumias","Mutungu","Navakholo"],
    "Vihiga": ["Emuhaya","Hamisi","Luanda","Sabatia","Vihiga"],
    "Bungoma": ["Bumula","Kabuchai","Kanduyi","Kimilil","Mt Elgon","Sirisia","Tongaren","Webuye East","Webuye West"],
    "Busia": ["Budalangi","Butula","Funyula","Nambele","Teso North","Teso South"],
    "Siaya": ["Alego Usonga","Bondo","Gem","Rarieda","Ugenya","Unguja"],
    "Kisumu": ["Kisumu Central","Kisumu East","Kisumu West","Muhoroni","Nyakach","Nyando","Seme"],
    "Homa Bay": ["Homabay Town","Kabondo","Karachwonyo","Kasipul","Mbita","Ndhiwa","Rangwe","Suba"],
    "Migori": ["Awendo","Kuria East","Kuria West","Mabera","Ntimaru","Rongo","Suna East","Suna West","Uriri"],
    "Kisii": ["Bobasi","Bonchari","Bomachoge Chache","Bomachoge Borabu","Kitutu Chache North","Kitutu Chache South","Nyaribari Chache","Nyaribari Masaba","South Mugirango"],
    "Nyamira": ["Borabu","Manga","Masaba North","Nyamira North","Nyamira South"],
    "Nairobi": ["Dagoretti North","Dagoretti South","Embakasi Central","Embakasi East","Embakasi North","Embakasi South","Embakasi West","Kamukunji","Kasarani","Kibra","Lang'ata","Makadara","Mathare","Roysambu","Ruaraka","Starehe","Westlands"]
}

# %%
def get_county_and_subcounties(county_name):
    county_total = county_data[county_data["county"] == county_name]
    subcounty_rows = subcounty_data[subcounty_data["county"].isin(county_to_subcounties[county_name])]
    return county_total, subcounty_rows

# Example usage:
kiambu_total, kiambu_subs = get_county_and_subcounties("Kiambu")
print(kiambu_total)
print(kiambu_subs)
# Out:
#      county             indicator    Unit  Date  households  \
# 458  Kiambu  Number of Households  Number  2019       47275
# 472  Kiambu  Number of Households  Number  2019      795241
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 458             32950.675               20980.301268  343237.728739
# 472            554282.977               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 458         0.001946       6.913151e+08
# 472         0.032742       1.162902e+10
#             county             indicator    Unit  Date  households  \
# 450          Ruiru  Number of Households  Number  2019      129470
# 452         Limuru  Number of Households  Number  2019       49174
# 454           Lari  Number of Households  Number  2019       38592
# 456         Kikuyu  Number of Households  Number  2019       60686
# 460        Kiambaa  Number of Households  Number  2019       80332
# 462         Kabete  Number of Households  Number  2019       66710
# 464           Juja  Number of Households  Number  2019      104301
# 466     Githunguri  Number of Households  Number  2019       49426
# 468  Gatundu South  Number of Households  Number  2019       35609
# 470  Gatundu North  Number of Households  Number  2019       31472
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 450             90240.590               20980.301268  343237.728739
# 452             34274.278               20980.301268  343237.728739
# 454             26898.624               20980.301268  343237.728739
# 456             42298.142               20980.301268  343237.728739
# 460             55991.404               20980.301268  343237.728739
# 462             46496.870               20980.301268  343237.728739
# 464             72697.797               20980.301268  343237.728739
# 466             34449.922               20980.301268  343237.728739
# 468             24819.473               20980.301268  343237.728739
# 470             21935.984               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 450         0.005331       1.893275e+09
# 452         0.002025       7.190847e+08
# 454         0.001589       5.643412e+08
# 456         0.002499       8.874278e+08
# 460         0.003308       1.174717e+09
# 462         0.002747       9.755183e+08
# 464         0.004294       1.525222e+09
# 466         0.002035       7.227697e+08
# 468         0.001466       5.207200e+08
# 470         0.001296       4.602236e+08

# %%
# Flatten dictionary into a list of all subcounties
all_subcounties = [sc for subs in county_to_subcounties.values() for sc in subs]

# Find which subcounties in dictionary are missing from your dataset
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]

print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
# Example corrections
name_corrections = {
    "Lunga Lunga": "Lungalunga",
    "Garissa Township": "Garissa",
    "Homabay Town": "Homa Bay Town",
    "Ol-Kalou": "Ol Kalou",
    "Chiakariga": "Chakariga",
    "Dagoretti North": "Dagoretti",
    "Dagoretti South": "Dagoretti",
    # … continue for all flagged mismatches
}

# Apply corrections
subcounty_data["county"] = subcounty_data["county"].replace(name_corrections)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_40840\3760507987.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subcounty_data["county"] = subcounty_data["county"].replace(name_corrections)

# %%
subcounty_data.loc[:, "county"] = subcounty_data["county"].replace(name_corrections)

# %%
# Flatten dictionary into a list of all subcounties
all_subcounties = [sc for subs in county_to_subcounties.values() for sc in subs]

# Find which subcounties in dictionary are missing from your dataset
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]

print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
name_corrections = {
    "Lunga Lunga": "Lungalunga",
    "Daadab": "Dadaab",
    "Garissa Township": "Garissa",
    "Homabay Town": "Homa Bay Town",
    "Ol-Kalou": "Ol Kalou",
    "Chiakariga": "Chakariga",
    "Muthambi": "Muthambi Division",  # adjust if dataset uses division
    "Nyeri Town": "Nyeri",            # dataset may simplify
    "Thika Town": "Thika",
    "Central Pokot": "Pokot Central",
    "North Pokot": "Pokot North",
    "West Pokot": "Pokot West",
    "Samburu West": "Samburu",
    "Transmara East": "Trans Mara East",
    "Transmara West": "Trans Mara West",
    "Bomachoge Chache": "Bomachoge Chache Constituency",
    "Bomachoge Borabu": "Bomachoge Borabu Constituency",
    # … continue for all flagged mismatches
}

# Apply safely
subcounty_data = subcounty_data.copy()
subcounty_data["county"] = subcounty_data["county"].replace(name_corrections)

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
name_corrections = {
    "Lunga Lunga": "Lungalunga",
    "Daadab": "Dadaab",
    "Garissa Township": "Garissa",
    "Homabay Town": "Homa Bay Town",
    "Ol-Kalou": "Ol Kalou",
    "Chiakariga": "Chakariga",
    "Thika Town": "Thika",
    "Central Pokot": "Pokot Central",
    "North Pokot": "Pokot North",
    "West Pokot": "Pokot West",
    "Transmara East": "Trans Mara East",
    "Transmara West": "Trans Mara West",
    "Bomachoge Chache": "Bomachoge Chache Constituency",
    "Bomachoge Borabu": "Bomachoge Borabu Constituency",
    # … continue for all flagged mismatches
}

# Apply safely
subcounty_data = subcounty_data.copy()
subcounty_data["county"] = subcounty_data["county"].replace(name_corrections)

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
name_corrections = {
    "Lunga Lunga": "Lungalunga",
    "Bura": "Bura Sub County",
    "Galole": "Galole Sub County",
    "Garsen": "Garsen Sub County",
    "Wundanyi": "Wundanyi Sub County",
    "Daadab": "Dadaab",
    "Garissa Township": "Garissa",
    "Banissa": "Banisa",
    "Mandera South": "Mandera",
    "Laisamis": "Laisamis Sub County",
    "North Hor": "North Horr",
    "Saku": "Saku Sub County",
    "Isiolo": "Isiolo North",
    "Buuri": "Buuri Sub County",
    "Imenti Central": "Central Imenti",
    "Chuka": "Chuka/Igambang'ombe",
    "Chiakariga": "Chakariga",
    "Muthambi": "Muthambi Division",
    "Manyatta": "Manyatta Sub County",
    "Runyenjes": "Runyenjes Sub County",
    "Kitui Rural": "Kitui",
    "Kitui South": "Kitui",
    "Kitui East": "Kitui",
    "Mwingi North": "Mwingi",
    "Mwingi West": "Mwingi",
    "Machakos Town": "Machakos",
    "Mavoko": "Mavoko Sub County",
    "Kaiti": "Kaiti Sub County",
    "Kibwezi West": "Kibwezi",
    "Kibwezi East": "Kibwezi",
    "Kilome": "Kilome Sub County",
    "Makueni": "Makueni Sub County",
    "Mbooni": "Mbooni Sub County",
    "Ndaragwa": "Ndaragwa Sub County",
    "Ol-Kalou": "Ol Kalou",
    "Ol Joro Orok": "Ol Jororok",
    "Mukurweini": "Mukurweini Sub County",
    "Nyeri Town": "Nyeri",
    "Othaya": "Othaya Sub County",
    "Kiharu": "Kiharu Sub County",
    "Kiambu": "Kiambu Town",
    "Thika Town": "Thika",
    "Central Pokot": "Pokot Central",
    "North Pokot": "Pokot North",
    "West Pokot": "Pokot West",
    "Samburu West": "Samburu",
    "Cherangany": "Cherangany Sub County",
    "Saboti": "Saboti Sub County",
    "Aldai": "Aldai Sub County",
    "Emgwen": "Emgwen Sub County",
    "Mosop": "Mosop Sub County",
    "Nandi Hills": "Nandi Hills Sub County",
    "Tindiret": "Tinderet",
    "Baringo South": "Baringo",
    "Eldama Ravine": "Eldama Ravine Sub County",
    "Tiaty": "Tiaty East",
    "Bahati": "Bahati Sub County",
    "Nakuru Town East": "Nakuru East",
    "Nakuru Town West": "Nakuru West",
    "Transmara East": "Trans Mara East",
    "Transmara West": "Trans Mara West",
    "Ainamoi": "Ainamoi Sub County",
    "Kipkelion East": "Kipkelion",
    "Kipkelion West": "Kipkelion",
    "Soin/Sigowet": "Sigowet/Soin",
    "Lukuyani": "Lukuyani Sub County",
    "Lurambi": "Lurambi Sub County",
    "Mumias": "Mumias East",
    "Mutungu": "Mumias West",
    "Vihiga": "Vihiga Sub County",
    "Kabuchai": "Kabuchai Sub County",
    "Kanduyi": "Kanduyi Sub County",
    "Kimilil": "Kimilili",
    "Sirisia": "Sirisia Sub County",
    "Webuye East": "Webuye East Sub County",
    "Budalangi": "Bunyala",
    "Funyula": "Funyula Sub County",
    "Nambele": "Nambale",
    "Alego Usonga": "Alego",
    "Unguja": "Ugunja",
    "Homabay Town": "Homa Bay Town",
    "Kabondo": "Kabondo Kasipul",
    "Karachwonyo": "Karachuonyo",
    "Kasipul": "Kasipul Sub County",
    "Mbita": "Suba North",
    "Suba": "Suba South",
    "Mabera": "Mabera Sub County",
    "Ntimaru": "Kuria East",
    "Bobasi": "Bobasi Sub County",
    "Bonchari": "Bonchari Sub County",
    "Bomachoge Chache": "Bomachoge Chache Sub County",
    "Bomachoge Borabu": "Bomachoge Borabu Sub County",
    "Kitutu Chache North": "Kitutu Chache North Sub County",
    "Kitutu Chache South": "Kitutu Chache South Sub County",
    "Nyaribari Chache": "Nyaribari Chache Sub County",
    "Nyaribari Masaba": "Nyaribari Masaba Sub County",
    "South Mugirango": "South Mugirango Sub County",
    "Dagoretti North": "Dagoretti",
    "Dagoretti South": "Dagoretti",
    "Embakasi Central": "Embakasi",
    "Embakasi East": "Embakasi",
    "Embakasi North": "Embakasi",
    "Embakasi South": "Embakasi",
    "Embakasi West": "Embakasi",
    "Roysambu": "Roysambu Sub County",
    "Ruaraka": "Ruaraka Sub County"
}

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
from rapidfuzz import process

# All subcounties from dictionary
all_subcounties = [sc for subs in county_to_subcounties.values() for sc in subs]

# Unique names in your dataset
dataset_names = subcounty_data["county"].unique()

# Build correction map automatically
name_corrections = {}
for sc in all_subcounties:
    match, score, _ = process.extractOne(sc, dataset_names)
    if score > 85:  # high similarity threshold
        name_corrections[sc] = match

# Apply corrections
subcounty_data = subcounty_data.copy()
subcounty_data["county"] = subcounty_data["county"].replace(name_corrections)

# Validate again
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Still missing:", missing_in_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 from rapidfuzz import process
#       3 # All subcounties from dictionary
#       4 all_subcounties = [sc for subs in county_to_subcounties.values() for sc in subs]
#
# ModuleNotFoundError: No module named 'rapidfuzz'

# %%
print(sorted(subcounty_data["county"].unique()))
# Out:
# ['Aberdare Forest', 'Aberdare National Park', 'Ainabkoi', 'Athi River', 'Awendo', 'Balambala', 'Banisa', 'Baringo Central', 'Baringo North', 'Belgut', 'Bomet Central', 'Bomet East', 'Bondo', 'Borabu', 'Bumula', 'Buna', 'Bungoma Central', 'Bungoma East', 'Bungoma North', 'Bungoma South', 'Bungoma West', 'Bunyala', 'Bureti', 'Butere', 'Butula', 'Buuri East', 'Buuri West', 'Changamwe', 'Chepalungu', 'Cheptais', 'Chesumei', 'Chonyi', 'Dadaab', 'Dagoretti', 'East Pokot', 'Eldas', 'Elgeyo/Marakwet', 'Embakasi', 'Embu East', 'Embu North', 'Embu West', 'Emuhaya', 'Endebess', 'Etago', 'Fafi', 'Ganze', 'Garbatulla', 'Gatanga', 'Gatundu North', 'Gatundu South', 'Gem', 'Gilgil', 'Githunguri', 'Gucha', 'Gucha South', 'Habaswein', 'Hamisi', 'Hulugho', "Igambang'ombe", 'Igembe Central', 'Igembe North', 'Igembe South', 'Ijara', 'Ikutha', 'Imenti North', 'Imenti South', 'Isinya', 'Jomvu', 'Juja', 'Kabete', 'Kahuro', 'Kajiado Central', 'Kajiado North', 'Kajiado West', 'Kakamega Central', 'Kakamega East', 'Kakamega Forest', 'Kakamega North', 'Kakamega South', 'Kalama', 'Kaloleni', 'Kamukunji', 'Kandara', 'Kangema', 'Kangundo', 'Kapseret', 'Kasarani', 'Kathiani', 'Kathonzweni', 'Katulani', 'Kauma', 'Keiyo North', 'Keiyo South', 'Kenyenya', 'Kericho East', 'Kesses', 'Khwisero', 'Kiambaa', 'Kibish', 'Kibra', 'Kibwezi', 'Kieni East', 'Kieni West', 'Kigumo', 'Kikuyu', 'Kilifi North', 'Kilifi South', 'Kilungu', 'Kimilili-Bungoma', 'Kiminini', 'Kinango', 'Kinangop', 'Kipipiri', 'Kipkelion', 'Kipkomo', 'Kirinyaga Central', 'Kirinyaga East', 'Kirinyaga West', 'Kisasi', 'Kisauni', 'Kisii Central', 'Kisii South', 'Kisumu Central', 'Kisumu East', 'Kisumu West', 'Kitui Central', 'Kitui West', 'Kitutu Central', 'Koibatek', 'Konoin', 'Kuresoi North', 'Kuresoi South', 'Kuria East', 'Kuria West', 'Kutulo', 'Kwanza', 'Kyuso', 'Lafey', 'Lagdera', 'Laikipia Central', 'Laikipia East', 'Laikipia North', 'Laikipia West', 'Lamu East', 'Lamu West', "Lang'ata", 'Lari', 'Likoni', 'Likuyani', 'Limuru', 'Loima', 'Loitokitok', 'Loiyangalani', 'Londiani', 'Lower Yatta', 'Luanda', 'Lugari', 'Lungalunga', 'Maara', 'Magarini', 'Makadara', 'Makindu', 'Malindi', 'Mandera Central', 'Mandera East', 'Mandera North', 'Mandera West', 'Manga', 'Marakwet East', 'Marakwet West', 'Marani', 'Marigat', 'Marsabit Central', 'Marsabit North', 'Marsabit South', 'Masaba North', 'Masaba South', 'Mashuuru', 'Masinga', 'Matete', 'Mathare', 'Mathioya', 'Mathira East', 'Mathira West', 'Matinyani', 'Matuga', 'Matungu', 'Matungulu', 'Mau Forest', 'Mbeere North', 'Mbeere South', 'Mbooni East', 'Mbooni West', 'Merti', 'Meru Central', 'Meru National Park', 'Meru South', 'Migwani', 'Mirangine', 'Mogotio', 'Moiben', 'Molo', 'Moyale', 'Msambweni', 'Mt Elgon', 'Mt Elgon Forest', 'Mt Kenya Forest', 'Muhoroni', 'Mukaa', 'Mukurwe-ini', 'Mumias East', 'Mumias West', 'Mumoni', "Murang'a East", "Murang'a South", 'Mutitu', 'Mutitu North', 'Mutomo', 'Mvita', 'Mwala', 'Mwatate', 'Mwea East', 'Mwea West', 'Mwingi Central', 'Mwingi East', 'Nairobi City', 'Naivasha', 'Nakuru East', 'Nakuru North', 'Nakuru West', 'Nambale', 'Nandi Central', 'Nandi East', 'Nandi North', 'Nandi South', 'Narok East', 'Narok North', 'Narok South', 'Narok West', 'Navakholo', 'Ndhiwa', 'Njiru', 'Njoro', 'North Horr', 'Nyahururu', 'Nyakach', 'Nyali', 'Nyamache', 'Nyamira North', 'Nyamira South', 'Nyandarua Central', 'Nyandarua North', 'Nyandarua South', 'Nyandarua West', 'Nyando', 'Nyatike', 'Nyeri Central', 'Nyeri South', 'Nzambani', 'Nzaui', 'Pokot Central', 'Pokot North', 'Pokot South', 'Rabai', 'Rachuonyo East', 'Rachuonyo North', 'Rachuonyo South', 'Rangwe', 'Rarieda', 'Rongai', 'Rongo', 'Ruiru', 'Sabatia', 'Samburu Central', 'Samburu East', 'Samburu North', 'Samburu-Kwale', 'Sameta', 'Samia', 'Seme', 'Soin Sigowet', 'Sololo', 'Sotik', 'Soy', 'Starehe', 'Suba North', 'Suba South', 'Subukia', 'Suna East', 'Suna West', 'Taita', 'Taita/Taveta', 'Tana Delta', 'Tana North', 'Tarbaj', 'Taveta', 'Teso North', 'Teso South', 'Tetu', 'Thagicu', 'Thara ...

# %%
name_corrections = {
    "Lunga Lunga": "Lungalunga",
    "Bura": "Tana North",          # dataset uses Tana North
    "Galole": "Tana Delta",        # dataset uses Tana Delta
    "Garsen": "Tana Delta",        # also covered by Tana Delta
    "Wundanyi": "Taita",           # dataset uses Taita
    "Daadab": "Dadaab",
    "Garissa Township": "Garissa", # dataset has Garissa
    "Banissa": "Banisa",
    "Mandera South": "Mandera Central",
    "Laisamis": "Marsabit South",
    "North Hor": "North Horr",
    "Saku": "Marsabit Central",
    "Isiolo": "Isiolo North",      # dataset has Isiolo North
    "Buuri": "Buuri East",         # dataset splits Buuri
    "Imenti Central": "Meru Central",
    "Chuka": "Chuka/Igambang'ombe",
    "Chiakariga": "Chakariga",
    "Muthambi": "Muthambi Division",
    "Manyatta": "Embu East",
    "Runyenjes": "Embu West",
    "Kitui Rural": "Kitui Central",
    "Kitui South": "Mutomo",       # dataset uses Mutomo
    "Kitui East": "Mutitu North",  # dataset uses Mutitu North
    "Mwingi North": "Kyuso",
    "Mwingi West": "Mwingi West",  # dataset has Mwingi West
    "Machakos Town": "Machakos",
    "Mavoko": "Athi River",
    "Kaiti": "Mukaa",
    "Kibwezi West": "Makindu",
    "Kibwezi East": "Kibwezi",
    "Kilome": "Kilungu",
    "Makueni": "Nzaui",
    "Mbooni": "Mbooni East",
    "Ndaragwa": "Nyandarua North",
    "Ol-Kalou": "Nyandarua Central",
    "Ol Joro Orok": "Nyandarua West",
    "Mukurweini": "Mukurwe-ini",
    "Nyeri Town": "Nyeri Central",
    "Othaya": "Nyeri South",
    "Kiharu": "Murang'a East",
    "Kiambu": "Kiambu Town",
    "Thika Town": "Thika East",    # dataset splits Thika
    "Central Pokot": "Pokot Central",
    "North Pokot": "Pokot North",
    "West Pokot": "Pokot South",
    "Samburu West": "Samburu Central",
    "Cherangany": "Trans Nzoia West",
    "Saboti": "Trans Nzoia East",
    "Aldai": "Nandi South",
    "Emgwen": "Nandi Central",
    "Mosop": "Nandi North",
    "Nandi Hills": "Nandi East",
    "Tindiret": "Tinderet",
    "Baringo South": "Marigat",
    "Eldama Ravine": "Koibatek",
    "Tiaty": "East Pokot",
    "Bahati": "Nakuru North",
    "Nakuru Town East": "Nakuru East",
    "Nakuru Town West": "Nakuru West",
    "Transmara East": "Trans Mara East",
    "Transmara West": "Trans Mara West",
    "Ainamoi": "Kericho East",
    "Kipkelion East": "Kipkelion",
    "Kipkelion West": "Londiani",
    "Soin/Sigowet": "Soin Sigowet",
    "Lukuyani": "Likuyani",
    "Lurambi": "Kakamega Central",
    "Mumias": "Mumias East",
    "Mutungu": "Mumias West",
    "Vihiga": "Vihiga Sub County",
    "Kabuchai": "Kabuchai Sub County",
    "Kanduyi": "Kanduyi Sub County",
    "Kimilil": "Kimilili-Bungoma",
    "Sirisia": "Sirisia Sub County",
    "Webuye East": "Webuye West",
    "Budalangi": "Bunyala",
    "Funyula": "Samia",
    "Nambele": "Nambale",
    "Alego Usonga": "Alego",
    "Unguja": "Ugunja",
    "Homabay Town": "Homa Bay Town",
    "Kabondo": "Kabondo Kasipul",
    "Karachwonyo": "Karachuonyo",
    "Kasipul": "Kasipul Sub County",
    "Mbita": "Suba North",
    "Suba": "Suba South",
    "Mabera": "Kuria West",
    "Ntimaru": "Kuria East",
    "Bobasi": "Gucha",
    "Bonchari": "Kisii South",
    "Bomachoge Chache": "Gucha South",
    "Bomachoge Borabu": "Sameta",
    "Kitutu Chache North": "Kitutu Central",
    "Kitutu Chache South": "Kenyenya",
    "Nyaribari Chache": "Kisii Central",
    "Nyaribari Masaba": "Masaba South",
    "South Mugirango": "Nyamache",
    "Dagoretti North": "Dagoretti",
    "Dagoretti South": "Dagoretti",
    "Embakasi Central": "Embakasi",
    "Embakasi East": "Embakasi",
    "Embakasi North": "Embakasi",
    "Embakasi South": "Embakasi",
    "Embakasi West": "Embakasi",
    "Roysambu": "Njiru",
    "Ruaraka": "Njiru"
}

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Still missing:", missing_in_data)
# Out:
# Still missing: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
# Step 1: Group dataset by county (the higher-level county column)
county_groups = subcounty_data.groupby("parent_county")["county"].unique()

# Step 2: Build dictionary
county_to_subcounties = {county: list(subs) for county, subs in county_groups.items()}

# Step 3: Inspect Kiambu
print("Kiambu subcounties:", county_to_subcounties.get("Kiambu", []))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 2
#       1 # Step 1: Group dataset by county (the higher-level county column)
# ----> 2 county_groups = subcounty_data.groupby("parent_county")["county"].unique()
#       4 # Step 2: Build dictionary
#       5 county_to_subcounties = {county: list(subs) for county, subs in county_groups.items()}
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'parent_county'

# %%
# Step 1: Identify county totals (rows where indicator == "Number of Households" and county is a main county)
county_totals = county_data["county"].unique()  # e.g., ["Kiambu","Nairobi","Mombasa",...]

# Step 2: Build dictionary by filtering subcounty_data for each county
county_to_subcounties = {}
for county in county_totals:
    subs = subcounty_data[subcounty_data["parent"] == county]["county"].unique()
    county_to_subcounties[county] = list(subs)

# Step 3: Inspect Kiambu
print("Kiambu subcounties:", county_to_subcounties.get("Kiambu", []))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 7
#       5 county_to_subcounties = {}
#       6 for county in county_totals:
# ----> 7     subs = subcounty_data[subcounty_data["parent"] == county]["county"].unique()
#       8     county_to_subcounties[county] = list(subs)
#      10 # Step 3: Inspect Kiambu
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'parent'

# %%
print(sorted(subcounty_data["county"].unique()))
# Out:
# ['Aberdare Forest', 'Aberdare National Park', 'Ainabkoi', 'Athi River', 'Awendo', 'Balambala', 'Banisa', 'Baringo Central', 'Baringo North', 'Belgut', 'Bomet Central', 'Bomet East', 'Bondo', 'Borabu', 'Bumula', 'Buna', 'Bungoma Central', 'Bungoma East', 'Bungoma North', 'Bungoma South', 'Bungoma West', 'Bunyala', 'Bureti', 'Butere', 'Butula', 'Buuri East', 'Buuri West', 'Changamwe', 'Chepalungu', 'Cheptais', 'Chesumei', 'Chonyi', 'Dadaab', 'Dagoretti', 'East Pokot', 'Eldas', 'Elgeyo/Marakwet', 'Embakasi', 'Embu East', 'Embu North', 'Embu West', 'Emuhaya', 'Endebess', 'Etago', 'Fafi', 'Ganze', 'Garbatulla', 'Gatanga', 'Gatundu North', 'Gatundu South', 'Gem', 'Gilgil', 'Githunguri', 'Gucha', 'Gucha South', 'Habaswein', 'Hamisi', 'Hulugho', "Igambang'ombe", 'Igembe Central', 'Igembe North', 'Igembe South', 'Ijara', 'Ikutha', 'Imenti North', 'Imenti South', 'Isinya', 'Jomvu', 'Juja', 'Kabete', 'Kahuro', 'Kajiado Central', 'Kajiado North', 'Kajiado West', 'Kakamega Central', 'Kakamega East', 'Kakamega Forest', 'Kakamega North', 'Kakamega South', 'Kalama', 'Kaloleni', 'Kamukunji', 'Kandara', 'Kangema', 'Kangundo', 'Kapseret', 'Kasarani', 'Kathiani', 'Kathonzweni', 'Katulani', 'Kauma', 'Keiyo North', 'Keiyo South', 'Kenyenya', 'Kericho East', 'Kesses', 'Khwisero', 'Kiambaa', 'Kibish', 'Kibra', 'Kibwezi', 'Kieni East', 'Kieni West', 'Kigumo', 'Kikuyu', 'Kilifi North', 'Kilifi South', 'Kilungu', 'Kimilili-Bungoma', 'Kiminini', 'Kinango', 'Kinangop', 'Kipipiri', 'Kipkelion', 'Kipkomo', 'Kirinyaga Central', 'Kirinyaga East', 'Kirinyaga West', 'Kisasi', 'Kisauni', 'Kisii Central', 'Kisii South', 'Kisumu Central', 'Kisumu East', 'Kisumu West', 'Kitui Central', 'Kitui West', 'Kitutu Central', 'Koibatek', 'Konoin', 'Kuresoi North', 'Kuresoi South', 'Kuria East', 'Kuria West', 'Kutulo', 'Kwanza', 'Kyuso', 'Lafey', 'Lagdera', 'Laikipia Central', 'Laikipia East', 'Laikipia North', 'Laikipia West', 'Lamu East', 'Lamu West', "Lang'ata", 'Lari', 'Likoni', 'Likuyani', 'Limuru', 'Loima', 'Loitokitok', 'Loiyangalani', 'Londiani', 'Lower Yatta', 'Luanda', 'Lugari', 'Lungalunga', 'Maara', 'Magarini', 'Makadara', 'Makindu', 'Malindi', 'Mandera Central', 'Mandera East', 'Mandera North', 'Mandera West', 'Manga', 'Marakwet East', 'Marakwet West', 'Marani', 'Marigat', 'Marsabit Central', 'Marsabit North', 'Marsabit South', 'Masaba North', 'Masaba South', 'Mashuuru', 'Masinga', 'Matete', 'Mathare', 'Mathioya', 'Mathira East', 'Mathira West', 'Matinyani', 'Matuga', 'Matungu', 'Matungulu', 'Mau Forest', 'Mbeere North', 'Mbeere South', 'Mbooni East', 'Mbooni West', 'Merti', 'Meru Central', 'Meru National Park', 'Meru South', 'Migwani', 'Mirangine', 'Mogotio', 'Moiben', 'Molo', 'Moyale', 'Msambweni', 'Mt Elgon', 'Mt Elgon Forest', 'Mt Kenya Forest', 'Muhoroni', 'Mukaa', 'Mukurwe-ini', 'Mumias East', 'Mumias West', 'Mumoni', "Murang'a East", "Murang'a South", 'Mutitu', 'Mutitu North', 'Mutomo', 'Mvita', 'Mwala', 'Mwatate', 'Mwea East', 'Mwea West', 'Mwingi Central', 'Mwingi East', 'Nairobi City', 'Naivasha', 'Nakuru East', 'Nakuru North', 'Nakuru West', 'Nambale', 'Nandi Central', 'Nandi East', 'Nandi North', 'Nandi South', 'Narok East', 'Narok North', 'Narok South', 'Narok West', 'Navakholo', 'Ndhiwa', 'Njiru', 'Njoro', 'North Horr', 'Nyahururu', 'Nyakach', 'Nyali', 'Nyamache', 'Nyamira North', 'Nyamira South', 'Nyandarua Central', 'Nyandarua North', 'Nyandarua South', 'Nyandarua West', 'Nyando', 'Nyatike', 'Nyeri Central', 'Nyeri South', 'Nzambani', 'Nzaui', 'Pokot Central', 'Pokot North', 'Pokot South', 'Rabai', 'Rachuonyo East', 'Rachuonyo North', 'Rachuonyo South', 'Rangwe', 'Rarieda', 'Rongai', 'Rongo', 'Ruiru', 'Sabatia', 'Samburu Central', 'Samburu East', 'Samburu North', 'Samburu-Kwale', 'Sameta', 'Samia', 'Seme', 'Soin Sigowet', 'Sololo', 'Sotik', 'Soy', 'Starehe', 'Suba North', 'Suba South', 'Subukia', 'Suna East', 'Suna West', 'Taita', 'Taita/Taveta', 'Tana Delta', 'Tana North', 'Tarbaj', 'Taveta', 'Teso North', 'Teso South', 'Tetu', 'Thagicu', 'Thara ...

# %%
dataset_subcounties = sorted(subcounty_data["county"].unique())

# %%
missing_in_data = [sc for subs in county_to_subcounties.values() for sc in subs
                   if sc not in dataset_subcounties]
print("Missing subcounties:", missing_in_data)
# Out:
# Missing subcounties: []

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Still missing:", missing_in_data)
# Out:
# Still missing: ['Lunga Lunga', 'Bura', 'Galole', 'Garsen', 'Wundanyi', 'Daadab', 'Garissa Township', 'Banissa', 'Mandera South', 'Laisamis', 'North Hor', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Chuka', 'Chiakariga', 'Muthambi', 'Manyatta', 'Runyenjes', 'Kitui Rural', 'Kitui South', 'Kitui East', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi West', 'Kibwezi East', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol-Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Kiharu', 'Kiambu', 'Thika Town', 'Central Pokot', 'North Pokot', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Tindiret', 'Baringo South', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Nakuru Town East', 'Nakuru Town West', 'Transmara East', 'Transmara West', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Soin/Sigowet', 'Lukuyani', 'Lurambi', 'Mumias', 'Mutungu', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilil', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Nambele', 'Alego Usonga', 'Unguja', 'Homabay Town', 'Kabondo', 'Karachwonyo', 'Kasipul', 'Mbita', 'Suba', 'Mabera', 'Ntimaru', 'Bobasi', 'Bonchari', 'Bomachoge Chache', 'Bomachoge Borabu', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'South Mugirango', 'Dagoretti North', 'Dagoretti South', 'Embakasi Central', 'Embakasi East', 'Embakasi North', 'Embakasi South', 'Embakasi West', 'Roysambu', 'Ruaraka']

# %%
all_subcounties = sorted(subcounty_data["county"].unique())

# %%
missing_in_data = [sc for sc in all_subcounties if sc not in subcounty_data["county"].unique()]
print("Still missing:", missing_in_data)
# Out:
# Still missing: []

# %%
# Step 1: Look at all unique names in your dataset
print(sorted(subcounty_data["county"].unique()))

# Step 2: Filter for Kirinyaga-related entries
kirinyaga_subs = [sc for sc in subcounty_data["county"].unique() if "Kirinyaga" in sc or "Mwea" in sc]
print("Kirinyaga subcounties:", kirinyaga_subs)
# Out:
# ['Aberdare Forest', 'Aberdare National Park', 'Ainabkoi', 'Athi River', 'Awendo', 'Balambala', 'Banisa', 'Baringo Central', 'Baringo North', 'Belgut', 'Bomet Central', 'Bomet East', 'Bondo', 'Borabu', 'Bumula', 'Buna', 'Bungoma Central', 'Bungoma East', 'Bungoma North', 'Bungoma South', 'Bungoma West', 'Bunyala', 'Bureti', 'Butere', 'Butula', 'Buuri East', 'Buuri West', 'Changamwe', 'Chepalungu', 'Cheptais', 'Chesumei', 'Chonyi', 'Dadaab', 'Dagoretti', 'East Pokot', 'Eldas', 'Elgeyo/Marakwet', 'Embakasi', 'Embu East', 'Embu North', 'Embu West', 'Emuhaya', 'Endebess', 'Etago', 'Fafi', 'Ganze', 'Garbatulla', 'Gatanga', 'Gatundu North', 'Gatundu South', 'Gem', 'Gilgil', 'Githunguri', 'Gucha', 'Gucha South', 'Habaswein', 'Hamisi', 'Hulugho', "Igambang'ombe", 'Igembe Central', 'Igembe North', 'Igembe South', 'Ijara', 'Ikutha', 'Imenti North', 'Imenti South', 'Isinya', 'Jomvu', 'Juja', 'Kabete', 'Kahuro', 'Kajiado Central', 'Kajiado North', 'Kajiado West', 'Kakamega Central', 'Kakamega East', 'Kakamega Forest', 'Kakamega North', 'Kakamega South', 'Kalama', 'Kaloleni', 'Kamukunji', 'Kandara', 'Kangema', 'Kangundo', 'Kapseret', 'Kasarani', 'Kathiani', 'Kathonzweni', 'Katulani', 'Kauma', 'Keiyo North', 'Keiyo South', 'Kenyenya', 'Kericho East', 'Kesses', 'Khwisero', 'Kiambaa', 'Kibish', 'Kibra', 'Kibwezi', 'Kieni East', 'Kieni West', 'Kigumo', 'Kikuyu', 'Kilifi North', 'Kilifi South', 'Kilungu', 'Kimilili-Bungoma', 'Kiminini', 'Kinango', 'Kinangop', 'Kipipiri', 'Kipkelion', 'Kipkomo', 'Kirinyaga Central', 'Kirinyaga East', 'Kirinyaga West', 'Kisasi', 'Kisauni', 'Kisii Central', 'Kisii South', 'Kisumu Central', 'Kisumu East', 'Kisumu West', 'Kitui Central', 'Kitui West', 'Kitutu Central', 'Koibatek', 'Konoin', 'Kuresoi North', 'Kuresoi South', 'Kuria East', 'Kuria West', 'Kutulo', 'Kwanza', 'Kyuso', 'Lafey', 'Lagdera', 'Laikipia Central', 'Laikipia East', 'Laikipia North', 'Laikipia West', 'Lamu East', 'Lamu West', "Lang'ata", 'Lari', 'Likoni', 'Likuyani', 'Limuru', 'Loima', 'Loitokitok', 'Loiyangalani', 'Londiani', 'Lower Yatta', 'Luanda', 'Lugari', 'Lungalunga', 'Maara', 'Magarini', 'Makadara', 'Makindu', 'Malindi', 'Mandera Central', 'Mandera East', 'Mandera North', 'Mandera West', 'Manga', 'Marakwet East', 'Marakwet West', 'Marani', 'Marigat', 'Marsabit Central', 'Marsabit North', 'Marsabit South', 'Masaba North', 'Masaba South', 'Mashuuru', 'Masinga', 'Matete', 'Mathare', 'Mathioya', 'Mathira East', 'Mathira West', 'Matinyani', 'Matuga', 'Matungu', 'Matungulu', 'Mau Forest', 'Mbeere North', 'Mbeere South', 'Mbooni East', 'Mbooni West', 'Merti', 'Meru Central', 'Meru National Park', 'Meru South', 'Migwani', 'Mirangine', 'Mogotio', 'Moiben', 'Molo', 'Moyale', 'Msambweni', 'Mt Elgon', 'Mt Elgon Forest', 'Mt Kenya Forest', 'Muhoroni', 'Mukaa', 'Mukurwe-ini', 'Mumias East', 'Mumias West', 'Mumoni', "Murang'a East", "Murang'a South", 'Mutitu', 'Mutitu North', 'Mutomo', 'Mvita', 'Mwala', 'Mwatate', 'Mwea East', 'Mwea West', 'Mwingi Central', 'Mwingi East', 'Nairobi City', 'Naivasha', 'Nakuru East', 'Nakuru North', 'Nakuru West', 'Nambale', 'Nandi Central', 'Nandi East', 'Nandi North', 'Nandi South', 'Narok East', 'Narok North', 'Narok South', 'Narok West', 'Navakholo', 'Ndhiwa', 'Njiru', 'Njoro', 'North Horr', 'Nyahururu', 'Nyakach', 'Nyali', 'Nyamache', 'Nyamira North', 'Nyamira South', 'Nyandarua Central', 'Nyandarua North', 'Nyandarua South', 'Nyandarua West', 'Nyando', 'Nyatike', 'Nyeri Central', 'Nyeri South', 'Nzambani', 'Nzaui', 'Pokot Central', 'Pokot North', 'Pokot South', 'Rabai', 'Rachuonyo East', 'Rachuonyo North', 'Rachuonyo South', 'Rangwe', 'Rarieda', 'Rongai', 'Rongo', 'Ruiru', 'Sabatia', 'Samburu Central', 'Samburu East', 'Samburu North', 'Samburu-Kwale', 'Sameta', 'Samia', 'Seme', 'Soin Sigowet', 'Sololo', 'Sotik', 'Soy', 'Starehe', 'Suba North', 'Suba South', 'Subukia', 'Suna East', 'Suna West', 'Taita', 'Taita/Taveta', 'Tana Delta', 'Tana North', 'Tarbaj', 'Taveta', 'Teso North', 'Teso South', 'Tetu', 'Thagicu', 'Thara ...
# Kirinyaga subcounties: ['Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central']

# %%
def get_subcounties(county_name, dataset):
    subs = [sc for sc in dataset["county"].unique() 
            if county_name in sc or sc.startswith(county_name) or sc.endswith(county_name)]
    return subs

# Example usage:
print("Kirinyaga:", get_subcounties("Kirinyaga", subcounty_data))
print("Kiambu:", get_subcounties("Kiambu", subcounty_data))
# Out:
# Kirinyaga: ['Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central']
# Kiambu: []

# %%
kiambu_subs = [
    "Ruiru","Limuru","Lari","Kikuyu","Kiambaa","Kabete",
    "Juja","Githunguri","Gatundu South","Gatundu North",
    "Thika East","Thika West"
]
print("Kiambu subcounties:", kiambu_subs)
# Out:
# Kiambu subcounties: ['Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Thika East', 'Thika West']

# %%
county_data = get_energy_data(level="county")
subcounty_data = get_energy_data(level="subcounty")

print(county_data.head())     # shows county totals
print(subcounty_data.head())  # shows sub-county breakdowns
# Out:
#       county             indicator    Unit  Date  households  \
# 0    Mombasa  Number of Households  Number  2019      378422
# 14     Kwale  Number of Households  Number  2019      173176
# 26    Kilifi  Number of Households  Number  2019      298472
# 76   Nyamira  Number of Households  Number  2019      150669
# 100    Kisii  Number of Households  Number  2019      308054
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 0              263760.134               20980.301268  343237.728739
# 14             120703.672               20980.301268  343237.728739
# 26             208034.984               20980.301268  343237.728739
# 76             105016.293               20980.301268  343237.728739
# 100            214713.638               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 0           0.015581       5.533767e+09
# 14          0.007130       2.532399e+09
# 26          0.012289       4.364637e+09
# 76          0.006203       2.203273e+09
# 100         0.012683       4.504757e+09
#        county             indicator    Unit  Date  households  \
# 2   Changamwe  Number of Households  Number  2019       46614
# 4       Jomvu  Number of Households  Number  2019       53472
# 6     Kisauni  Number of Households  Number  2019       88202
# 8      Likoni  Number of Households  Number  2019       81191
# 10      Mvita  Number of Households  Number  2019       38995
#
#     connected_households  avg_household_consumption   monthly_bill  \
# 2              32489.958               20980.301268  343237.728739
# 4              37269.984               20980.301268  343237.728739
# 6              61476.794               20980.301268  343237.728739
# 8              56590.127               20980.301268  343237.728739
# 10             27179.515               20980.301268  343237.728739
#
#     household_share  county_energy_kWh
# 2          0.001919       6.816491e+08
# 4          0.002202       7.819355e+08
# 6          0.003632       1.289802e+09
# 8          0.003343       1.187278e+09
# 10         0.001606       5.702344e+08

# %%
# Build dictionary of counties to their subcounties
county_to_subcounties = {}

# Loop through each county in county_data
for county in county_data["county"].unique():
    subs = subcounty_data[subcounty_data["county"].isin(subcounty_data["county"].unique())]
    
    # Filter subcounty_data for rows belonging to this county
    subs_for_county = subcounty_data[subcounty_data["parent_county"] == county]["county"].unique() \
                      if "parent_county" in subcounty_data.columns else []
    
    county_to_subcounties[county] = list(subs_for_county)

# Print all counties and their subcounties
for county, subs in county_to_subcounties.items():
    print(f"{county}: {subs}")
# Out:
# Mombasa: []
# Kwale: []
# Kilifi: []
# Nyamira: []
# Kisii: []
# Migori: []
# Homa Bay: []
# Kisumu: []
# Siaya: []
# Busia: []
# Bungoma: []
# Vihiga: []
# Kakamega: []
# Bomet: []
# Kericho: []
# Kajiado: []
# Narok: []
# Nakuru: []
# Laikipia: []
# Baringo: []
# Nandi: []
# Uasin Gishu: []
# Trans Nzoia: []
# Samburu: []
# West Pokot: []
# Turkana: []
# Kiambu: []
# Murang'a: []
# Kirinyaga: []
# Nyeri: []
# Nyandarua: []
# Makueni: []
# Machakos: []
# Kitui: []
# Embu: []
# Meru: []
# Isiolo: []
# Marsabit: []
# Mandera: []
# Wajir: []
# Garissa: []
# Lamu: []
# Tana River: []

# %%
# Get county totals
county_data = get_energy_data(level="county")
# Get subcounty breakdowns
subcounty_data = get_energy_data(level="subcounty")

# Build dictionary of counties → subcounties
county_to_subcounties = {}

for county in county_data["county"].unique():
    # Filter subcounty_data for rows belonging to this county
    subs = subcounty_data[subcounty_data["parent_county"] == county]["county"].unique() \
           if "parent_county" in subcounty_data.columns else []
    county_to_subcounties[county] = list(subs)

# Print nicely
for county, subs in county_to_subcounties.items():
    print(f"\n{county} ({len(subs)} subcounties)")
    for sc in subs:
        print("   -", sc)
# Out:
# Mombasa (0 subcounties)
#
# Kwale (0 subcounties)
#
# Kilifi (0 subcounties)
#
# Nyamira (0 subcounties)
#
# Kisii (0 subcounties)
#
# Migori (0 subcounties)
#
# Homa Bay (0 subcounties)
#
# Kisumu (0 subcounties)
#
# Siaya (0 subcounties)
#
# Busia (0 subcounties)
#
# Bungoma (0 subcounties)
#
# Vihiga (0 subcounties)
#
# Kakamega (0 subcounties)
#
# Bomet (0 subcounties)
#
# Kericho (0 subcounties)
#
# Kajiado (0 subcounties)
#
# Narok (0 subcounties)
#
# Nakuru (0 subcounties)
#
# Laikipia (0 subcounties)
#
# Baringo (0 subcounties)
#
# Nandi (0 subcounties)
#
# Uasin Gishu (0 subcounties)
#
# Trans Nzoia (0 subcounties)
#
# Samburu (0 subcounties)
#
# West Pokot (0 subcounties)
#
# Turkana (0 subcounties)
#
# Kiambu (0 subcounties)
#
# Murang'a (0 subcounties)
#
# Kirinyaga (0 subcounties)
#
# Nyeri (0 subcounties)
#
# Nyandarua (0 subcounties)
#
# Makueni (0 subcounties)
#
# Machakos (0 subcounties)
#
# Kitui (0 subcounties)
#
# Embu (0 subcounties)
#
# Meru (0 subcounties)
#
# Isiolo (0 subcounties)
#
# Marsabit (0 subcounties)
#
# Mandera (0 subcounties)
#
# Wajir (0 subcounties)
#
# Garissa (0 subcounties)
#
# Lamu (0 subcounties)
#
# Tana River (0 subcounties)

# %%
county_data = get_energy_data(level="county")
subcounty_data = get_energy_data(level="subcounty")

print(county_data.head())     # shows county totals
print(subcounty_data.head())  # shows sub-county breakdowns
# Out:
#       county             indicator    Unit  Date  households  \
# 0    Mombasa  Number of Households  Number  2019      378422
# 14     Kwale  Number of Households  Number  2019      173176
# 26    Kilifi  Number of Households  Number  2019      298472
# 76   Nyamira  Number of Households  Number  2019      150669
# 100    Kisii  Number of Households  Number  2019      308054
#
#      connected_households  avg_household_consumption   monthly_bill  \
# 0              263760.134               20980.301268  343237.728739
# 14             120703.672               20980.301268  343237.728739
# 26             208034.984               20980.301268  343237.728739
# 76             105016.293               20980.301268  343237.728739
# 100            214713.638               20980.301268  343237.728739
#
#      household_share  county_energy_kWh
# 0           0.015581       5.533767e+09
# 14          0.007130       2.532399e+09
# 26          0.012289       4.364637e+09
# 76          0.006203       2.203273e+09
# 100         0.012683       4.504757e+09
#        county             indicator    Unit  Date  households  \
# 2   Changamwe  Number of Households  Number  2019       46614
# 4       Jomvu  Number of Households  Number  2019       53472
# 6     Kisauni  Number of Households  Number  2019       88202
# 8      Likoni  Number of Households  Number  2019       81191
# 10      Mvita  Number of Households  Number  2019       38995
#
#     connected_households  avg_household_consumption   monthly_bill  \
# 2              32489.958               20980.301268  343237.728739
# 4              37269.984               20980.301268  343237.728739
# 6              61476.794               20980.301268  343237.728739
# 8              56590.127               20980.301268  343237.728739
# 10             27179.515               20980.301268  343237.728739
#
#     household_share  county_energy_kWh
# 2          0.001919       6.816491e+08
# 4          0.002202       7.819355e+08
# 6          0.003632       1.289802e+09
# 8          0.003343       1.187278e+09
# 10         0.001606       5.702344e+08

# %%
county_data = get_energy_data(level="county")
subcounty_data = get_energy_data(level="subcounty")

# Combine both into one DataFrame
all_data = pd.concat([county_data, subcounty_data], ignore_index=True)

# Preview the first 10 rows
print(all_data.head(50))

# Check how many rows total
print("Total rows:", len(all_data))
# Out:
#          county             indicator    Unit  Date  households  \
# 0       Mombasa  Number of Households  Number  2019      378422
# 1         Kwale  Number of Households  Number  2019      173176
# 2        Kilifi  Number of Households  Number  2019      298472
# 3       Nyamira  Number of Households  Number  2019      150669
# 4         Kisii  Number of Households  Number  2019      308054
# 5        Migori  Number of Households  Number  2019      240168
# 6      Homa Bay  Number of Households  Number  2019       29318
# 7      Homa Bay  Number of Households  Number  2019      262036
# 8        Kisumu  Number of Households  Number  2019      300745
# 9         Siaya  Number of Households  Number  2019       57553
# 10        Siaya  Number of Households  Number  2019      250698
# 11        Busia  Number of Households  Number  2019       33160
# 12        Busia  Number of Households  Number  2019      198152
# 13      Bungoma  Number of Households  Number  2019      358796
# 14       Vihiga  Number of Households  Number  2019       23375
# 15       Vihiga  Number of Households  Number  2019      143365
# 16     Kakamega  Number of Households  Number  2019      433207
# 17        Bomet  Number of Households  Number  2019      187641
# 18      Kericho  Number of Households  Number  2019      206036
# 19      Kajiado  Number of Households  Number  2019      316179
# 20        Narok  Number of Households  Number  2019      241125
# 21       Nakuru  Number of Households  Number  2019      616046
# 22     Laikipia  Number of Households  Number  2019      149271
# 23      Baringo  Number of Households  Number  2019      142518
# 24        Nandi  Number of Households  Number  2019      199426
# 25  Uasin Gishu  Number of Households  Number  2019      304943
# 26  Trans Nzoia  Number of Households  Number  2019      223808
# 27      Samburu  Number of Households  Number  2019       65910
# 28   West Pokot  Number of Households  Number  2019       36341
# 29   West Pokot  Number of Households  Number  2019      116182
# 30      Turkana  Number of Households  Number  2019      164519
# 31       Kiambu  Number of Households  Number  2019       47275
# 32       Kiambu  Number of Households  Number  2019      795241
# 33     Murang'a  Number of Households  Number  2019      318105
# 34    Kirinyaga  Number of Households  Number  2019      204188
# 35        Nyeri  Number of Households  Number  2019      248050
# 36    Nyandarua  Number of Households  Number  2019      179686
# 37      Makueni  Number of Households  Number  2019       34479
# 38      Makueni  Number of Households  Number  2019      244669
# 39     Machakos  Number of Households  Number  2019       50979
# 40     Machakos  Number of Households  Number  2019      402466
# 41        Kitui  Number of Households  Number  2019      262942
# 42         Embu  Number of Households  Number  2019      182743
# 43         Meru  Number of Households  Number  2019      426360
# 44       Isiolo  Number of Households  Number  2019       29853
# 45       Isiolo  Number of Households  Number  2019       58072
# 46     Marsabit  Number of Households  Number  2019       77495
# 47      Mandera  Number of Households  Number  2019      125763
# 48        Wajir  Number of Households  Number  2019      127932
# 49      Garissa  Number of Households  Number  2019       30518
#
#     connected_households  avg_household_consumption   monthly_bill  \
# 0             263760.134               20980.301268  343237.728739
# 1             120703.672               20980.301268  343237.728739
# 2             208034.984               20980.301268  343237.728739
# 3             105016.293               20980.301268  343237.728739
# 4             214713.638               20980.301268  343237.728739
# 5             167397.096               20980.301268  343237.728739
# 6              20434.646               20980.301268  343237.728739
# 7             182639.092               20980.301268  343237.728739
# 8             209619.265               20980.301268  343237.728739
# 9              40114.441               20980.301268  343237.728739
# 10            174736.506               20980.301268  343237.728739
# 11             23112.520               20980.301268  343237.728739
# 12            138111.944               20980.301268  343237.728739
# 13            250080.812               20980.301268  343237.728739
# 14             16292.375               20980.301268  343237.728739
# 15             99925.405               20980.301268  343237.728739
# 16            301945.279               20980.301268  343237.728739
# 17            130785.777               20980.301268  343237.728739
# 18            143607.092               20980.301268  343237.728739
# 19            220376.763               20980.301268  343237.728739
# 20            168064.125               20980.301268  343237.728739
# 21            429384.062               20980.301268  343237.728739
# 22            104041.887               20980.301268  343237.728739
# 23             99335.046               20980.301268  343237.728739
# 24            138999.922               20980.301268  343237.728739
# 25            212545.271               20980.301268  343237.728739
# 26            155994.176               20980.301268  343237.728739
# 27             45939.270               20980.301268  343237.728739
# 28             25329.677               20980.301268  343237.728739
# 29             80978.854               20980.301268  343237.728739
# 30            114669.743               20980.301268  343237.728739
# 31             32950.675               20980.301268  343237.728739
# 32            554282.977               20980.301268  343237.728739
# 33            221719.185               20980.301268  343237.728739
# 34            142319.036               20980.301268  343237.728739
# 35            172890.850               20980.301268  343237.728739
# 36            125241.142               20980.301268  343237.728739
# 37             24031.863               20980.301268  343237.728739
# 38            170534.293               20980.301268  343237.728739
# 39             35532.363               20980.301268  343237.728739
# 40            280518.802               20980.301268  343237.728739
# 41            183270.574               20980.301268  343237.728739
# 42            127371.871               20980.301268  343237.728739
# 43            297172.920               20980.301268  343237.728739
# 44             20807.541               20980.301268  343237.728739
# 45             40476.184               20980.301268  343237.728739
# 46             54014.015               20980.301268  343237.728739
# 47             87656.811               20980.301268  343237.728739
# 48             89168.604               20980.301268  343237.728739
# 49             21271.046               20980.301268  343237.728739
#
#     household_share  county_energy_kWh
# 0          0.015581       5.533767e+09
# 1          0.007130       2.532399e+09
# 2          0.012289       4.364637e+09
# 3          0.006203       2.203273e+09
# 4          0.012683       4.504757e+09
# 5          0.009888       3.512042e+09
# 6          0.001207       4.287250e+08
# 7          0.010789       3.831823e+09
# 8          0.012383       4.397875e+09
# 9          0.002370       8.416131e+08
# 10         0.010322       3.666025e+09
# 11         0.001365       4.849076e+08
# 12         0.008158       2.897630e+09
# 13         0.014773       5.246771e+09
# 14         0.000962       3.418189e+08
# 15         0.005903       2.096465e+09
# 16         0.017836       6.334903e+09
# 17         0.007726       2.743925e+09
# 18         0.008483       3.012920e+09
# 19         0.013018       4.623571e+09
# 20         0.009928       3.526036e+09
# 21         0.025364       9.008607e+09
# 22         0.006146       2.182830e+09
# 23         0.005868       2.084079e+09
# 24         0.008211       2.916260e+09
# 25         0.012555       4.459264e+09
# 26         0.009215       3.272805e+09
# 27         0.002714       9.638197e+08
# 28         0.001496       5.314243e+08
# 29         0.004784       1.698961e+09
# 30         0.006774       2.405806e+09
# 31         0.001946       6.913151e+08
# 32         0.032742       1.162902e+10
# 33         0.013097       4.651735e+09
# 34         0.008407       2.985896e+09
# 35         0.010213       3.627302e+09
# 36         0.007398       2.627597e+09
# 37         0.001420       5.041957e+08
# 38         0.010074       3.577861e+09
# 39         0.002099       7.454797e+08
# 40         0.016571       5.885369e+09
# 41         0.010826       3.845072e+09
# 42         0.007524       2.672300e+09
# 43         0.017554       6.234777e+09
# 44         0.001229       4.365485e+08
# 45         0.002391       8.492025e+08
# 46         0.003191       1.133230e+09
# 47         0.005178       1.839066e+09
# 48         0.005267       1.870784e+09
# 49         0.001257       4.462730e+08
# Total rows: 392

# %%
print(subcounty_data["county"].unique()[:50])
# Out:
# ['Changamwe' 'Jomvu' 'Kisauni' 'Likoni' 'Mvita' 'Nyali' 'Kinango'
#  'Lungalunga' 'Matuga' 'Msambweni' 'Samburu-Kwale' 'Chonyi' 'Ganze'
#  'Kaloleni' 'Kauma' 'Kilifi North' 'Kilifi South' 'Magarini' "Lang'ata"
#  'Kibra' 'Makadara' 'Mathare' 'Nairobi City' 'Dagoretti' 'Embakasi'
#  'Kamukunji' 'Kasarani' 'Njiru' 'Starehe' 'Westlands' 'Nyamira South'
#  'Nyamira North' 'Masaba North' 'Manga' 'Borabu' 'Sameta' 'Nyamache'
#  'Masaba South' 'Marani' 'Kitutu Central' 'Kisii South' 'Kisii Central'
#  'Kenyenya' 'Gucha South' 'Gucha' 'Etago' 'Uriri' 'Suna West' 'Suna East'
#  'Rongo']

# %%
missing = [sc for sc in subcounty_to_county.keys() if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 missing = [sc for sc in subcounty_to_county.keys() if sc not in subcounty_data["county"].unique()]
#       2 print("Missing subcounties:", missing)
#
# NameError: name 'subcounty_to_county' is not defined

# %%
subcounty_to_county = {
    # Mombasa
    "Changamwe": "Mombasa",
    "Jomvu": "Mombasa",
    "Kisauni": "Mombasa",
    "Likoni": "Mombasa",
    "Mvita": "Mombasa",
    "Nyali": "Mombasa",

    # Kwale
    "Kinango": "Kwale",
    "Lungalunga": "Kwale",
    "Matuga": "Kwale",
    "Msambweni": "Kwale",
    "Samburu-Kwale": "Kwale",

    # Kilifi
    "Chonyi": "Kilifi",
    "Ganze": "Kilifi",
    "Kaloleni": "Kilifi",
    "Kauma": "Kilifi",
    "Kilifi North": "Kilifi",
    "Kilifi South": "Kilifi",
    "Magarini": "Kilifi",
    "Malindi": "Kilifi",
    "Rabai": "Kilifi",

    # Tana River
    "Bura": "Tana River",
    "Galole": "Tana River",
    "Garsen": "Tana River",

    # Lamu
    "Lamu East": "Lamu",
    "Lamu West": "Lamu",

    # Taita Taveta
    "Mwatate": "Taita Taveta",
    "Taveta": "Taita Taveta",
    "Voi": "Taita Taveta",
    "Wundanyi": "Taita Taveta",

    # Garissa
    "Balambala": "Garissa",
    "Dadaab": "Garissa",
    "Fafi": "Garissa",
    "Garissa": "Garissa",
    "Hulugho": "Garissa",
    "Ijara": "Garissa",
    "Lagdera": "Garissa",

    # Wajir
    "Buna": "Wajir",
    "Bute": "Wajir",
    "Eldas": "Wajir",
    "Habaswein": "Wajir",
    "Tarbaj": "Wajir",
    "Wajir East": "Wajir",
    "Wajir North": "Wajir",
    "Wajir South": "Wajir",
    "Wajir West": "Wajir",

    # Mandera
    "Banissa": "Mandera",
    "Lafey": "Mandera",
    "Mandera East": "Mandera",
    "Mandera North": "Mandera",
    "Mandera South": "Mandera",
    "Mandera West": "Mandera",

    # Marsabit
    "Laisamis": "Marsabit",
    "Marsabit Central": "Marsabit",
    "Moyale": "Marsabit",
    "North Horr": "Marsabit",
    "Saku": "Marsabit",

    # Isiolo
    "Garbatulla": "Isiolo",
    "Isiolo": "Isiolo",
    "Merti": "Isiolo",

    # Meru
    "Buuri": "Meru",
    "Igembe Central": "Meru",
    "Igembe North": "Meru",
    "Igembe South": "Meru",
    "Imenti Central": "Meru",
    "Imenti North": "Meru",
    "Imenti South": "Meru",
    "Tigania East": "Meru",
    "Tigania West": "Meru",

    # Tharaka Nithi
    "Maara": "Tharaka Nithi",
    "Meru South": "Tharaka Nithi",
    "Tharaka": "Tharaka Nithi",

    # Embu
    "Manyatta": "Embu",
    "Mbeere North": "Embu",
    "Mbeere South": "Embu",
    "Runyenjes": "Embu",

    # Kitui
    "Kitui Central": "Kitui",
    "Kitui East": "Kitui",
    "Kitui Rural": "Kitui",
    "Kitui South": "Kitui",
    "Kitui West": "Kitui",
    "Mwingi Central": "Kitui",
    "Mwingi East": "Kitui",
    "Mwingi North": "Kitui",
    "Mwingi West": "Kitui",

    # Machakos
    "Kathiani": "Machakos",
    "Machakos Town": "Machakos",
    "Masinga": "Machakos",
    "Matungulu": "Machakos",
    "Mavoko": "Machakos",
    "Mwala": "Machakos",
    "Yatta": "Machakos",

    # Makueni
    "Kaiti": "Makueni",
    "Kibwezi East": "Makueni",
    "Kibwezi West": "Makueni",
    "Kilome": "Makueni",
    "Makueni": "Makueni",
    "Mbooni": "Makueni",

    # Nyandarua
    "Kinangop": "Nyandarua",
    "Kipipiri": "Nyandarua",
    "Ndaragwa": "Nyandarua",
    "Ol Kalou": "Nyandarua",
    "Ol Joro Orok": "Nyandarua",

    # Nyeri
    "Kieni East": "Nyeri",
    "Kieni West": "Nyeri",
    "Mathira East": "Nyeri",
    "Mathira West": "Nyeri",
    "Mukurweini": "Nyeri",
    "Nyeri Town": "Nyeri",
    "Othaya": "Nyeri",
    "Tetu": "Nyeri",

    # Kirinyaga
    "Gichugu": "Kirinyaga",
    "Kirinyaga Central": "Kirinyaga",
    "Mwea East": "Kirinyaga",
    "Mwea West": "Kirinyaga",
    "Ndia": "Kirinyaga",

    # Murang'a
    "Gatanga": "Murang'a",
    "Kandara": "Murang'a",
    "Kangema": "Murang'a",
    "Kiharu": "Murang'a",
    "Mathioya": "Murang'a",
    "Murang'a East": "Murang'a",
    "Murang'a West": "Murang'a",

    # Kiambu
    "Gatundu North": "Kiambu",
    "Gatundu South": "Kiambu",
    "Githunguri": "Kiambu",
    "Juja": "Kiambu",
    "Kabete": "Kiambu",
    "Kiambaa": "Kiambu",
    "Kiambu": "Kiambu",
    "Kikuyu": "Kiambu",
    "Limuru": "Kiambu",
    "Lari": "Kiambu",
    "Ruiru": "Kiambu",
    "Thika Town": "Kiambu",

    # Turkana
    "Loima": "Turkana",
    "Turkana Central": "Turkana",
    "Turkana East": "Turkana",
    "Turkana North": "Turkana",
    "Turkana South": "Turkana",
    "Turkana West": "Turkana",

    # West Pokot
    "Pokot Central": "West Pokot",
    "Pokot North": "West Pokot",
    "Pokot South": "West Pokot",
    "West Pokot": "West Pokot",

    # Samburu
    "Samburu East": "Samburu",
    "Samburu North": "Samburu",
    "Samburu West": "Samburu",

    # Trans Nzoia
    "Cherangany": "Trans Nzoia",
    "Endebess": "Trans Nzoia",
    "Kiminini": "Trans Nzoia",
    "Kwanza": "Trans Nzoia",
    "Saboti": "Trans Nzoia",

    # Uasin Gishu
    "Ainabkoi": "Uasin Gishu",
    "Kapseret": "Uasin Gishu",
    "Kesses": "Uasin Gishu",
    "Moiben": "Uasin Gishu",
    "Soy": "Uasin Gishu",
    "Turbo": "Uasin Gishu",

    # Elgeyo Marakwet
    "Keiyo North": "Elgeyo Marakwet",
    "Keiyo South": "Elgeyo Marakwet",
    "Marakwet East": "Elgeyo Marakwet",
    "Marakwet West": "Elgeyo Marakwet",

    # Nandi
    "Aldai": "Nandi",
    "Chesumei": "Nandi",
    "Emgwen": "Nandi",
    "Mosop": "Nandi",
    "Nandi Hills": "Nandi",
    "Tinderet": "Nandi",

    # Baringo
    "Baringo Central": "Baringo",
    "Baringo North": "Baringo",
    "Eldama Ravine": "Baringo",
    "Koibatek": "Baringo",
    "Mogotio": "Baringo",
    "Tiaty": "Baringo",

    # Laikipia
    "Laikipia East": "Laikipia",
    "Laikipia North": "Laikipia",
    "Laikipia West": "Laikipia",
    "Nyahururu": "Laikipia",

    # Nakuru
    "Bahati": "Nakuru",
    "Gilgil": "Nakuru",
    "Kuresoi North": "Nakuru",
    "Kuresoi South": "Nakuru",
    "Molo": "Nakuru",
    "Naivasha": "Nakuru",
    "Nakuru East": "Nakuru",
    "Nakuru North": "Nakuru",
    "Nakuru West": "Nakuru",
    "Njoro": "Nakuru",
    "Rongai": "Nakuru",
    "Subukia": "Nakuru",

    # Narok
    "Narok East": "Narok",
    "Narok North": "Narok",
    "Narok South": "Narok",
    "Narok West": "Narok",
    "Trans Mara East": "Narok",
    "Trans Mara West": "Narok",

    # Kajiado
    "Isinya": "Kajiado",
    "Kajiado Central": "Kajiado",
    "Kajiado East": "Kajiado",
    "Kajiado North": "Kajiado",
    "Kajiado West": "Kajiado",
    "Loitokitok": "Kajiado",
    "Mashuuru": "Kajiado",

    # Kericho
    "Ainamoi": "Kericho",
    "Bureti": "Kericho",
    "Kipkelion East": "Kericho",
    "Kipkelion West": "Kericho",
    "Londiani": "Kericho",
    "Soin Sigowet": "Kericho",

    # Bomet
    "Bomet Central": "Bomet",
    "Bomet East": "Bomet",
    "Chepalungu": "Bomet",
    "Konoin": "Bomet",
    "Sotik": "Bomet",

    # Kakamega
    "Butere": "Kakamega",
    "Kakamega Central": "Kakamega",
    "Kakamega East": "Kakamega",
    "Kakamega North": "Kakamega",
    "Kakamega South": "Kakamega",
    "Khwisero": "Kakamega",
    "Likuyani": "Kakamega",
    "Lugari": "Kakamega",
    "Lurambi": "Kakamega",
    "Malava": "Kakamega",
    "Matete": "Kakamega",
    "Mumias East": "Kakamega",
    "Mumias West": "Kakamega",
    "Navakholo": "Kakamega",

    # Vihiga
    "Emuhaya": "Vihiga",
    "Hamisi": "Vihiga",
    "Luanda": "Vihiga",
    "Sabatia": "Vihiga",
    "Vihiga": "Vihiga",

    # Bungoma
    "Bumula": "Bungoma",
    "Kabuchai": "Bungoma",
    "Kanduyi": "Bungoma",
    "Kimilili": "Bungoma",
    "Mt Elgon": "Bungoma",
    "Sirisia": "Bungoma",
    "Tongaren": "Bungoma",
    "Webuye East": "Bungoma",
    "Webuye West": "Bungoma",

    # Busia
    "Budalangi": "Busia",
    "Butula": "Busia",
    "Funyula": "Busia",
    "Matayos": "Busia",
    "Nambale": "Busia",
    "Teso North": "Busia",
    "Teso South": "Busia",

    # Siaya
    "Alego Usonga": "Siaya",
    "Bondo": "Siaya",
    "Gem": "Siaya",
    "Rarieda": "Siaya",
    "Ugenya": "Siaya",
    "Ugunja": "Siaya",

    # Kisumu
    "Kisumu Central": "Kisumu",
    "Kisumu East": "Kisumu",
    "Kisumu West": "Kisumu",
    "Muhoroni": "Kisumu",
    "Nyakach": "Kisumu",
    "Nyando": "Kisumu",
    "Seme": "Kisumu",

    # Homa Bay
    "Homabay Town": "Homa Bay",
    "Kabondo": "Homa Bay",
    "Karachuonyo": "Homa Bay",
    "Kasipul": "Homa Bay",
    "Mbita": "Homa Bay",
    "Ndhiwa": "Homa Bay",
    "Rangwe": "Homa Bay",
    "Suba North": "Homa Bay",
    "Suba South": "Homa Bay",

    # Migori
    "Awendo": "Migori",
    "Kuria East": "Migori",
    "Kuria West": "Migori",
    "Migori": "Migori",
    "Nyatike": "Migori",
    "Rongo": "Migori",
    "Suna East": "Migori",
    "Suna West": "Migori",
    "Uriri": "Migori",

    # Kisii
    "Bobasi": "Kisii",
    "Bomachoge Borabu": "Kisii",
    "Bomachoge Chache": "Kisii",
    "Bonchari": "Kisii",
    "Gucha": "Kisii",
    "Gucha South": "Kisii",
    "Kenyenya": "Kisii",
    "Kisii Central": "Kisii",
    "Kisii South": "Kisii",
    "Kitutu Central": "Kisii",
    "Kitutu Chache North": "Kisii",
    "Kitutu Chache South": "Kisii",
    "Marani": "Kisii",
    "Nyamache": "Kisii",
    "Nyaribari Chache": "Kisii",
    "Nyaribari Masaba": "Kisii",
    "Sameta": "Kisii",

    # Nyamira
    "Borabu": "Nyamira",
    "Manga": "Nyamira",
    "Masaba North": "Nyamira",
    "Masaba South": "Nyamira",
    "Nyamache": "Nyamira",
    "Nyamira North": "Nyamira",
    "Nyamira South": "Nyamira",
    "Sameta": "Nyamira",

    # Nairobi City
    "Dagoretti": "Nairobi City",
    "Embakasi": "Nairobi City",
    "Kamukunji": "Nairobi City",
    "Kasarani": "Nairobi City",
    "Kibra": "Nairobi City",
    "Lang'ata": "Nairobi City",
    "Makadara": "Nairobi City",
    "Mathare": "Nairobi City",
    "Njiru": "Nairobi City",
    "Roysambu": "Nairobi City",
    "Ruaraka": "Nairobi City",
    "Starehe": "Nairobi City",
    "Westlands": "Nairobi City",
}

# %%
missing = [sc for sc in subcounty_to_county.keys() if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
# Create a more flexible mapping with common variations
subcounty_to_county_normalized = {
    # Tana River
    "Bura": "Tana River",
    "Galole": "Tana River", 
    "Garsen": "Tana River",
    
    # Taita Taveta
    "Wundanyi": "Taita Taveta",
    "Voi": "Taita Taveta",
    "Mwatate": "Taita Taveta",
    "Taveta": "Taita Taveta",
    
    # Garissa
    "Garissa": "Garissa",
    "Balambala": "Garissa",
    "Dadaab": "Garissa",
    "Fafi": "Garissa",
    "Hulugho": "Garissa",
    "Ijara": "Garissa",
    "Lagdera": "Garissa",
    
    # Wajir
    "Bute": "Wajir",
    "Buna": "Wajir",
    "Eldas": "Wajir",
    "Habaswein": "Wajir",
    "Tarbaj": "Wajir",
    "Wajir East": "Wajir",
    "Wajir North": "Wajir",
    "Wajir South": "Wajir",
    "Wajir West": "Wajir",
    
    # Mandera
    "Banissa": "Mandera",
    "Lafey": "Mandera",
    "Mandera East": "Mandera",
    "Mandera North": "Mandera",
    "Mandera South": "Mandera",
    "Mandera West": "Mandera",
    
    # Marsabit
    "Laisamis": "Marsabit",
    "Saku": "Marsabit",
    "Marsabit Central": "Marsabit",
    "Moyale": "Marsabit",
    "North Horr": "Marsabit",
    
    # Isiolo
    "Isiolo": "Isiolo",
    "Garbatulla": "Isiolo",
    "Merti": "Isiolo",
    
    # Meru
    "Buuri": "Meru",
    "Igembe Central": "Meru",
    "Igembe North": "Meru",
    "Igembe South": "Meru",
    "Imenti Central": "Meru",
    "Imenti North": "Meru",
    "Imenti South": "Meru",
    "Tigania East": "Meru",
    "Tigania West": "Meru",
    
    # Tharaka Nithi
    "Tharaka": "Tharaka Nithi",
    "Maara": "Tharaka Nithi",
    "Meru South": "Tharaka Nithi",
    
    # Embu
    "Manyatta": "Embu",
    "Runyenjes": "Embu",
    "Mbeere North": "Embu",
    "Mbeere South": "Embu",
    
    # Kitui
    "Kitui East": "Kitui",
    "Kitui Rural": "Kitui",
    "Kitui South": "Kitui",
    "Mwingi North": "Kitui",
    "Mwingi West": "Kitui",
    "Kitui Central": "Kitui",
    "Kitui West": "Kitui",
    "Mwingi Central": "Kitui",
    "Mwingi East": "Kitui",
    
    # Machakos
    "Machakos Town": "Machakos",
    "Mavoko": "Machakos",
    "Kathiani": "Machakos",
    "Masinga": "Machakos",
    "Matungulu": "Machakos",
    "Mwala": "Machakos",
    "Yatta": "Machakos",
    
    # Makueni
    "Kaiti": "Makueni",
    "Kibwezi East": "Makueni",
    "Kibwezi West": "Makueni",
    "Kilome": "Makueni",
    "Makueni": "Makueni",
    "Mbooni": "Makueni",
    
    # Nyandarua
    "Ndaragwa": "Nyandarua",
    "Ol Kalou": "Nyandarua",
    "Ol Joro Orok": "Nyandarua",
    "Kinangop": "Nyandarua",
    "Kipipiri": "Nyandarua",
    
    # Nyeri
    "Mukurweini": "Nyeri",
    "Nyeri Town": "Nyeri",
    "Othaya": "Nyeri",
    "Kieni East": "Nyeri",
    "Kieni West": "Nyeri",
    "Mathira East": "Nyeri",
    "Mathira West": "Nyeri",
    "Tetu": "Nyeri",
    
    # Kirinyaga
    "Gichugu": "Kirinyaga",
    "Ndia": "Kirinyaga",
    "Kirinyaga Central": "Kirinyaga",
    "Mwea East": "Kirinyaga",
    "Mwea West": "Kirinyaga",
    
    # Murang'a
    "Kiharu": "Murang'a",
    "Murang'a West": "Murang'a",
    "Gatanga": "Murang'a",
    "Kandara": "Murang'a",
    "Kangema": "Murang'a",
    "Mathioya": "Murang'a",
    "Murang'a East": "Murang'a",
    
    # Kiambu
    "Kiambu": "Kiambu",
    "Thika Town": "Kiambu",
    "Gatundu North": "Kiambu",
    "Gatundu South": "Kiambu",
    "Githunguri": "Kiambu",
    "Juja": "Kiambu",
    "Kabete": "Kiambu",
    "Kiambaa": "Kiambu",
    "Kikuyu": "Kiambu",
    "Limuru": "Kiambu",
    "Lari": "Kiambu",
    "Ruiru": "Kiambu",
    
    # West Pokot
    "West Pokot": "West Pokot",
    "Pokot Central": "West Pokot",
    "Pokot North": "West Pokot",
    "Pokot South": "West Pokot",
    
    # Samburu
    "Samburu West": "Samburu",
    "Samburu East": "Samburu",
    "Samburu North": "Samburu",
    
    # Trans Nzoia
    "Cherangany": "Trans Nzoia",
    "Saboti": "Trans Nzoia",
    "Endebess": "Trans Nzoia",
    "Kiminini": "Trans Nzoia",
    "Kwanza": "Trans Nzoia",
    
    # Nandi
    "Aldai": "Nandi",
    "Emgwen": "Nandi",
    "Mosop": "Nandi",
    "Nandi Hills": "Nandi",
    "Chesumei": "Nandi",
    "Tinderet": "Nandi",
    
    # Baringo
    "Eldama Ravine": "Baringo",
    "Tiaty": "Baringo",
    "Baringo Central": "Baringo",
    "Baringo North": "Baringo",
    "Koibatek": "Baringo",
    "Mogotio": "Baringo",
    
    # Nakuru
    "Bahati": "Nakuru",
    "Gilgil": "Nakuru",
    "Kuresoi North": "Nakuru",
    "Kuresoi South": "Nakuru",
    "Molo": "Nakuru",
    "Naivasha": "Nakuru",
    "Nakuru East": "Nakuru",
    "Nakuru North": "Nakuru",
    "Nakuru West": "Nakuru",
    "Njoro": "Nakuru",
    "Rongai": "Nakuru",
    "Subukia": "Nakuru",
    
    # Kajiado
    "Kajiado East": "Kajiado",
    "Isinya": "Kajiado",
    "Kajiado Central": "Kajiado",
    "Kajiado North": "Kajiado",
    "Kajiado West": "Kajiado",
    "Loitokitok": "Kajiado",
    "Mashuuru": "Kajiado",
    
    # Kericho
    "Ainamoi": "Kericho",
    "Kipkelion East": "Kericho",
    "Kipkelion West": "Kericho",
    "Bureti": "Kericho",
    "Londiani": "Kericho",
    "Soin Sigowet": "Kericho",
    
    # Kakamega
    "Lurambi": "Kakamega",
    "Malava": "Kakamega",
    "Butere": "Kakamega",
    "Kakamega Central": "Kakamega",
    "Kakamega East": "Kakamega",
    "Kakamega North": "Kakamega",
    "Kakamega South": "Kakamega",
    "Khwisero": "Kakamega",
    "Likuyani": "Kakamega",
    "Lugari": "Kakamega",
    "Matete": "Kakamega",
    "Mumias East": "Kakamega",
    "Mumias West": "Kakamega",
    "Navakholo": "Kakamega",
    
    # Vihiga
    "Vihiga": "Vihiga",
    "Emuhaya": "Vihiga",
    "Hamisi": "Vihiga",
    "Luanda": "Vihiga",
    "Sabatia": "Vihiga",
    
    # Bungoma
    "Kabuchai": "Bungoma",
    "Kanduyi": "Bungoma",
    "Kimilili": "Bungoma",
    "Sirisia": "Bungoma",
    "Webuye East": "Bungoma",
    "Bumula": "Bungoma",
    "Mt Elgon": "Bungoma",
    "Tongaren": "Bungoma",
    "Webuye West": "Bungoma",
    
    # Busia
    "Budalangi": "Busia",
    "Funyula": "Busia",
    "Matayos": "Busia",
    "Butula": "Busia",
    "Nambale": "Busia",
    "Teso North": "Busia",
    "Teso South": "Busia",
    
    # Siaya
    "Alego Usonga": "Siaya",
    "Bondo": "Siaya",
    "Gem": "Siaya",
    "Rarieda": "Siaya",
    "Ugenya": "Siaya",
    "Ugunja": "Siaya",
    
    # Homa Bay
    "Homabay Town": "Homa Bay",
    "Kabondo": "Homa Bay",
    "Karachuonyo": "Homa Bay",
    "Kasipul": "Homa Bay",
    "Mbita": "Homa Bay",
    "Ndhiwa": "Homa Bay",
    "Rangwe": "Homa Bay",
    "Suba North": "Homa Bay",
    "Suba South": "Homa Bay",
    
    # Migori
    "Migori": "Migori",
    "Awendo": "Migori",
    "Kuria East": "Migori",
    "Kuria West": "Migori",
    "Nyatike": "Migori",
    "Rongo": "Migori",
    "Suna East": "Migori",
    "Suna West": "Migori",
    "Uriri": "Migori",
    
    # Kisii
    "Bobasi": "Kisii",
    "Bomachoge Borabu": "Kisii",
    "Bomachoge Chache": "Kisii",
    "Bonchari": "Kisii",
    "Kitutu Chache North": "Kisii",
    "Kitutu Chache South": "Kisii",
    "Nyaribari Chache": "Kisii",
    "Nyaribari Masaba": "Kisii",
    "Gucha": "Kisii",
    "Gucha South": "Kisii",
    "Kenyenya": "Kisii",
    "Kisii Central": "Kisii",
    "Kisii South": "Kisii",
    "Kitutu Central": "Kisii",
    "Marani": "Kisii",
    "Nyamache": "Kisii",
    "Sameta": "Kisii",
    
    # Nairobi
    "Roysambu": "Nairobi City",
    "Ruaraka": "Nairobi City",
    "Dagoretti": "Nairobi City",
    "Embakasi": "Nairobi City",
    "Kamukunji": "Nairobi City",
    "Kasarani": "Nairobi City",
    "Kibra": "Nairobi City",
    "Lang'ata": "Nairobi City",
    "Makadara": "Nairobi City",
    "Mathare": "Nairobi City",
    "Njiru": "Nairobi City",
    "Starehe": "Nairobi City",
    "Westlands": "Nairobi City",
}

# %%
def map_subcounty_to_county(subcounty_name):
    """Flexible mapping with case-insensitive and partial matching"""
    
    # First try exact match
    if subcounty_name in subcounty_to_county_normalized:
        return subcounty_to_county_normalized[subcounty_name]
    
    # Try case-insensitive match
    for key, county in subcounty_to_county_normalized.items():
        if key.lower() == subcounty_name.lower():
            return county
    
    # Try removing "Town" or common variations
    cleaned_name = subcounty_name.replace(" Town", "").replace("Sub-County", "").strip()
    if cleaned_name in subcounty_to_county_normalized:
        return subcounty_to_county_normalized[cleaned_name]
    
    # Try matching with common aliases
    aliases = {
        "Homabay": "Homa Bay",
        "Homa Bay Town": "Homabay Town",
        "Nyeri": "Nyeri Town",
        "Machakos": "Machakos Town",
        "Kiambu Town": "Kiambu",
        "Thika": "Thika Town",
    }
    
    if subcounty_name in aliases and aliases[subcounty_name] in subcounty_to_county_normalized:
        return subcounty_to_county_normalized[aliases[subcounty_name]]
    
    return None

# Apply the mapping to your data
subcounty_data['mapped_county'] = subcounty_data['county'].apply(map_subcounty_to_county)

# Check for any remaining unmapped subcounties
remaining_unmapped = subcounty_data[subcounty_data['mapped_county'].isna()]['county'].unique()
print("Still unmapped:", remaining_unmapped)
# Out:
# Still unmapped: ['Changamwe' 'Jomvu' 'Kisauni' 'Likoni' 'Mvita' 'Nyali' 'Kinango'
#  'Lungalunga' 'Matuga' 'Msambweni' 'Samburu-Kwale' 'Chonyi' 'Ganze'
#  'Kaloleni' 'Kauma' 'Kilifi North' 'Kilifi South' 'Magarini'
#  'Nairobi City' 'Nyamira South' 'Nyamira North' 'Masaba North' 'Manga'
#  'Borabu' 'Masaba South' 'Etago' 'Rachuonyo South' 'Rachuonyo East'
#  'Rachuonyo North' 'Nyakach' 'Muhoroni' 'Kisumu West' 'Seme' 'Nyando'
#  'Kisumu Central' 'Kisumu East' 'Samia' 'Bunyala' 'Mt Elgon Forest'
#  'Bungoma West' 'Kimilili-Bungoma' 'Cheptais' 'Bungoma South'
#  'Bungoma North' 'Bungoma East' 'Bungoma Central' 'Kakamega Forest'
#  'Matungu' 'Bomet Central' 'Sotik' 'Konoin' 'Chepalungu' 'Bomet East'
#  'Kericho East' 'Kipkelion' 'Belgut' 'Mau Forest' 'Trans Mara West'
#  'Trans Mara East' 'Narok West' 'Narok South' 'Narok North' 'Narok East'
#  'Nyahururu' 'Laikipia West' 'Laikipia North' 'Laikipia East'
#  'Laikipia Central' 'Tiaty East' 'Marigat' 'East Pokot' 'Nandi South'
#  'Nandi North' 'Nandi East' 'Nandi Central' 'Marakwet West'
#  'Marakwet East' 'Keiyo South' 'Keiyo North' 'Elgeyo/Marakwet' 'Turbo'
#  'Soy' 'Moiben' 'Kesses' 'Kapseret' 'Ainabkoi' 'Trans Nzoia East'
#  'Trans Nzoia West' 'Samburu Central' 'Kipkomo' 'Turkana West'
#  'Turkana South' 'Turkana North' 'Turkana East' 'Turkana Central' 'Loima'
#  'Kibish' 'Thika West' 'Thika East' 'Aberdare Forest' 'Kigumo'
#  "Murang'a South" 'Kahuro' 'Mt Kenya Forest' 'Kirinyaga West'
#  'Kirinyaga East' 'Nyeri Central' 'Mukurwe-ini' 'Nyeri South'
#  'Aberdare National Park' 'Nyandarua North' 'Nyandarua West'
#  'Nyandarua Central' 'Mirangine' 'Nyandarua South' 'Nzaui' 'Mukaa'
#  'Mbooni West' 'Makindu' 'Mbooni East' 'Kilungu' 'Kibwezi' 'Kathonzweni'
#  'Kangundo' 'Kalama' 'Athi River' 'Tseikuru' 'Thagicu' 'Nzambani' 'Mutomo'
#  'Mutitu North' 'Mutitu' 'Mumoni' 'Migwani' 'Matinyani' 'Lower Yatta'
#  'Kyuso' 'Kisasi' 'Katulani' 'Ikutha' 'Embu West' 'Embu North' 'Embu East'
#  'Tharaka South' 'Tharaka North' "Igambang'ombe" 'Tharaka-Nithi'
#  'Meru National Park' 'Tigania Central' 'Meru Central' 'Buuri West'
#  'Buuri East' 'Sololo' 'Marsabit South' 'Marsabit North' 'Loiyangalani'
#  'Mandera Central' 'Kutulo' 'Banisa' 'Taita' 'Taita/Taveta' 'Lamu West'
#  'Lamu East' 'Tana Delta' 'Tana North' 'Rabai' 'Malindi']
# C:\Users\USER\AppData\Local\Temp\ipykernel_40840\3511582920.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subcounty_data['mapped_county'] = subcounty_data['county'].apply(map_subcounty_to_county)

# %%
# Get unique subcounties from your data
data_subcounties = set(subcounty_data["county"].unique())
mapping_subcounties = set(subcounty_to_county_normalized.keys())

# Find what's in your data but not in mapping
missing_in_mapping = data_subcounties - mapping_subcounties
print("Subcounties in data but not in mapping:")
for sc in sorted(missing_in_mapping):
    print(f"  '{sc}': '?',")

# Find what's in mapping but not in data (for completeness)
extra_in_mapping = mapping_subcounties - data_subcounties
print("\nSubcounties in mapping but not in data:")
for sc in sorted(extra_in_mapping):
    print(f"  {sc}")
# Out:
# Subcounties in data but not in mapping:
#   'Aberdare Forest': '?',
#   'Aberdare National Park': '?',
#   'Ainabkoi': '?',
#   'Athi River': '?',
#   'Banisa': '?',
#   'Belgut': '?',
#   'Bomet Central': '?',
#   'Bomet East': '?',
#   'Borabu': '?',
#   'Bungoma Central': '?',
#   'Bungoma East': '?',
#   'Bungoma North': '?',
#   'Bungoma South': '?',
#   'Bungoma West': '?',
#   'Bunyala': '?',
#   'Buuri East': '?',
#   'Buuri West': '?',
#   'Changamwe': '?',
#   'Chepalungu': '?',
#   'Cheptais': '?',
#   'Chonyi': '?',
#   'East Pokot': '?',
#   'Elgeyo/Marakwet': '?',
#   'Embu East': '?',
#   'Embu North': '?',
#   'Embu West': '?',
#   'Etago': '?',
#   'Ganze': '?',
#   'Igambang'ombe': '?',
#   'Ikutha': '?',
#   'Jomvu': '?',
#   'Kahuro': '?',
#   'Kakamega Forest': '?',
#   'Kalama': '?',
#   'Kaloleni': '?',
#   'Kangundo': '?',
#   'Kapseret': '?',
#   'Kathonzweni': '?',
#   'Katulani': '?',
#   'Kauma': '?',
#   'Keiyo North': '?',
#   'Keiyo South': '?',
#   'Kericho East': '?',
#   'Kesses': '?',
#   'Kibish': '?',
#   'Kibwezi': '?',
#   'Kigumo': '?',
#   'Kilifi North': '?',
#   'Kilifi South': '?',
#   'Kilungu': '?',
#   'Kimilili-Bungoma': '?',
#   'Kinango': '?',
#   'Kipkelion': '?',
#   'Kipkomo': '?',
#   'Kirinyaga East': '?',
#   'Kirinyaga West': '?',
#   'Kisasi': '?',
#   'Kisauni': '?',
#   'Kisumu Central': '?',
#   'Kisumu East': '?',
#   'Kisumu West': '?',
#   'Konoin': '?',
#   'Kutulo': '?',
#   'Kyuso': '?',
#   'Laikipia Central': '?',
#   'Laikipia East': '?',
#   'Laikipia North': '?',
#   'Laikipia West': '?',
#   'Lamu East': '?',
#   'Lamu West': '?',
#   'Likoni': '?',
#   'Loima': '?',
#   'Loiyangalani': '?',
#   'Lower Yatta': '?',
#   'Lungalunga': '?',
#   'Magarini': '?',
#   'Makindu': '?',
#   'Malindi': '?',
#   'Mandera Central': '?',
#   'Manga': '?',
#   'Marakwet East': '?',
#   'Marakwet West': '?',
#   'Marigat': '?',
#   'Marsabit North': '?',
#   'Marsabit South': '?',
#   'Masaba North': '?',
#   'Masaba South': '?',
#   'Matinyani': '?',
#   'Matuga': '?',
#   'Matungu': '?',
#   'Mau Forest': '?',
#   'Mbooni East': '?',
#   'Mbooni West': '?',
#   'Meru Central': '?',
#   'Meru National Park': '?',
#   'Migwani': '?',
#   'Mirangine': '?',
#   'Moiben': '?',
#   'Msambweni': '?',
#   'Mt Elgon Forest': '?',
#   'Mt Kenya Forest': '?',
#   'Muhoroni': '?',
#   'Mukaa': '?',
#   'Mukurwe-ini': '?',
#   'Mumoni': '?',
#   'Murang'a South': '?',
#   'Mutitu': '?',
#   'Mutitu North': '?',
#   'Mutomo': '?',
#   'Mvita': '?',
#   'Nairobi City': '?',
#   'Nandi Central': '?',
#   'Nandi East': '?',
#   'Nandi North': '?',
#   'Nandi South': '?',
#   'Narok East': '?',
#   'Narok North': '?',
#   'Narok South': '?',
#   'Narok West': '?',
#   'Nyahururu': '?',
#   'Nyakach': '?',
#   'Nyali': '?',
#   'Nyamira North': '?',
#   'Nyamira South': '?',
#   'Nyandarua Central': '?',
#   'Nyandarua North': '?',
#   'Nyandarua South': '?',
#   'Nyandarua West': '?',
#   'Nyando': '?',
#   'Nyeri Central': '?',
#   'Nyeri South': '?',
#   'Nzambani': '?',
#   'Nzaui': '?',
#   'Rabai': '?',
#   'Rachuonyo East': '?',
#   'Rachuonyo North': '?',
#   'Rachuonyo South': '?',
#   'Samburu Central': '?',
#   'Samburu-Kwale': '?',
#   'Samia': '?',
#   'Seme': '?',
#   'Sololo': '?',
#   'Sotik': '?',
#   'Soy': '?',
#   'Taita': '?',
#   'Taita/Taveta': '?',
#   'Tana Delta': '?',
#   'Tana North': '?',
#   'Thagicu': '?',
#   'Tharaka North': '?',
#   'Tharaka South': '?',
#   'Tharaka-Nithi': '?',
#   'Thika East': '?',
#   'Thika West': '?',
#   'Tiaty East': '?',
#   'Tigania Central': '?',
#   'Trans Mara East': '?',
#   'Trans Mara West': '?',
#   'Trans Nzoia East': '?',
#   'Trans Nzoia West': '?',
#   'Tseikuru': '?',
#   'Turbo': '?',
#   'Turkana Central': '?',
#   'Turkana East': '?',
#   'Turkana North': '?',
#   'Turkana South': '?',
#   'Turkana West': '?',
#
# Subcounties in mapping but not in data:
#   Ainamoi
#   Aldai
#   Alego Usonga
#   Bahati
#   Banissa
#   Bobasi
#   Bomachoge Borabu
#   Bomachoge Chache
#   Bonchari
#   Budalangi
#   Bura
#   Bute
#   Buuri
#   Cherangany
#   Eldama Ravine
#   Emgwen
#   Funyula
#   Galole
#   Garissa
#   Garsen
#   Gichugu
#   Homabay Town
#   Imenti Central
#   Isiolo
#   Kabondo
#   Kabuchai
#   Kaiti
#   Kajiado East
#   Kanduyi
#   Karachuonyo
#   Kasipul
#   Kiambu
#   Kibwezi East
#   Kibwezi West
#   Kiharu
#   Kilome
#   Kimilili
#   Kipkelion East
#   Kipkelion West
#   Kitui East
#   Kitui Rural
#   Kitui South
#   Kitutu Chache North
#   Kitutu Chache South
#   Laisamis
#   Lurambi
#   Machakos Town
#   Makueni
#   Malava
#   Mandera South
#   Manyatta
#   Matayos
#   Mavoko
#   Mbita
#   Mbooni
#   Migori
#   Mosop
#   Mukurweini
#   Murang'a West
#   Mwingi North
#   Mwingi West
#   Nandi Hills
#   Ndaragwa
#   Ndia
#   Nyaribari Chache
#   Nyaribari Masaba
#   Nyeri Town
#   Ol Joro Orok
#   Ol Kalou
#   Othaya
#   Roysambu
#   Ruaraka
#   Runyenjes
#   Saboti
#   Saku
#   Samburu West
#   Sirisia
#   Tharaka
#   Thika Town
#   Tiaty
#   Vihiga
#   Webuye East
#   West Pokot
#   Wundanyi

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
county_to_subcounties = {}
for sc, county in subcounty_to_county.items():
    county_to_subcounties.setdefault(county, []).append(sc)

for county in ["Mombasa","Kwale","Kilifi","Kiambu","Kirinyaga"]:
    print(county, ":", county_to_subcounties.get(county, []))
# Out:
# Mombasa : ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kwale : ['Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale']
# Kilifi : ['Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', 'Malindi', 'Rabai']
# Kiambu : ['Gatundu North', 'Gatundu South', 'Githunguri', 'Juja', 'Kabete', 'Kiambaa', 'Kiambu', 'Kikuyu', 'Limuru', 'Lari', 'Ruiru', 'Thika Town']
# Kirinyaga : ['Gichugu', 'Kirinyaga Central', 'Mwea East', 'Mwea West', 'Ndia']

# %%
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(county, "County:", county_total, "Subcounties:", sub_total)
# Out:
# Mombasa County: 378422 Subcounties: 378422
# Kwale County: 173176 Subcounties: 173176
# Kilifi County: 298472 Subcounties: 298472
# Tana River County: 86807 Subcounties: 0
# Lamu County: 37963 Subcounties: 37963
# Taita Taveta County: 0 Subcounties: 81335
# Garissa County: 171912 Subcounties: 110876
# Wajir County: 127932 Subcounties: 127932
# Mandera County: 125763 Subcounties: 70892
# Marsabit County: 77495 Subcounties: 43347
# Isiolo County: 87925 Subcounties: 28219
# Meru County: 426360 Subcounties: 309429
# Tharaka Nithi County: 0 Subcounties: 63290
# Embu County: 182743 Subcounties: 75593
# Kitui County: 262942 Subcounties: 92037
# Machakos County: 453445 Subcounties: 201428
# Makueni County: 279148 Subcounties: 0
# Nyandarua County: 179686 Subcounties: 56170
# Nyeri County: 248050 Subcounties: 142657
# Kirinyaga County: 204188 Subcounties: 121285
# Murang'a County: 318105 Subcounties: 194592
# Kiambu County: 842516 Subcounties: 645772
# Turkana County: 164519 Subcounties: 158714
# West Pokot County: 152523 Subcounties: 61471
# Samburu County: 65910 Subcounties: 31708
# Trans Nzoia County: 223808 Subcounties: 126188
# Uasin Gishu County: 304943 Subcounties: 304943
# Elgeyo Marakwet County: 0 Subcounties: 99861
# Nandi County: 199426 Subcounties: 63382
# Baringo County: 142518 Subcounties: 96013
# Laikipia County: 149271 Subcounties: 118899
# Nakuru County: 616046 Subcounties: 616046
# Narok County: 241125 Subcounties: 241093
# Kajiado County: 316179 Subcounties: 316179
# Kericho County: 206036 Subcounties: 102090
# Bomet County: 187641 Subcounties: 187641
# Kakamega County: 433207 Subcounties: 396750
# Vihiga County: 166740 Subcounties: 119978
# Bungoma County: 358796 Subcounties: 114412
# Busia County: 231312 Subcounties: 122069
# Siaya County: 308251 Subcounties: 193145
# Kisumu County: 300745 Subcounties: 300745
# Homa Bay County: 291354 Subcounties: 132600
# Migori County: 240168 Subcounties: 240168
# Kisii County: 308054 Subcounties: 213842
# Nyamira County: 150669 Subcounties: 226271
# Nairobi City County: 0 Subcounties: 1506888

# %%
mombasa_total = subcounty_data[subcounty_data["county"].isin(county_to_subcounties["Mombasa"])]["households"].sum()
print("Mombasa households (from subcounties):", mombasa_total)

county_total = county_data[county_data["county"] == "Mombasa"]["households"].sum()
print("Mombasa households (county total):", county_total)
# Out:
# Mombasa households (from subcounties): 378422
# Mombasa households (county total): 378422

# %%
# First, handle the SettingWithCopyWarning by using .loc or creating a copy
subcounty_data = subcounty_data.copy()  # Create a copy to avoid the warning

# Create the comprehensive mapping based on actual data names
subcounty_to_county_complete = {
    # Mombasa
    "Changamwe": "Mombasa",
    "Jomvu": "Mombasa",
    "Kisauni": "Mombasa",
    "Likoni": "Mombasa",
    "Mvita": "Mombasa",
    "Nyali": "Mombasa",
    
    # Kwale
    "Kinango": "Kwale",
    "Lungalunga": "Kwale",
    "Matuga": "Kwale",
    "Msambweni": "Kwale",
    "Samburu-Kwale": "Kwale",
    
    # Kilifi
    "Chonyi": "Kilifi",
    "Ganze": "Kilifi",
    "Kaloleni": "Kilifi",
    "Kauma": "Kilifi",
    "Kilifi North": "Kilifi",
    "Kilifi South": "Kilifi",
    "Magarini": "Kilifi",
    "Malindi": "Kilifi",
    "Rabai": "Kilifi",
    
    # Tana River
    "Tana Delta": "Tana River",
    "Tana North": "Tana River",
    "Tana River": "Tana River",
    "Bura": "Tana River",
    "Galole": "Tana River",
    "Garsen": "Tana River",
    
    # Lamu
    "Lamu East": "Lamu",
    "Lamu West": "Lamu",
    
    # Taita Taveta
    "Taita": "Taita Taveta",
    "Taita/Taveta": "Taita Taveta",
    "Voi": "Taita Taveta",
    "Mwatate": "Taita Taveta",
    "Taveta": "Taita Taveta",
    "Wundanyi": "Taita Taveta",
    
    # Garissa
    "Garissa": "Garissa",
    "Balambala": "Garissa",
    "Dadaab": "Garissa",
    "Fafi": "Garissa",
    "Hulugho": "Garissa",
    "Ijara": "Garissa",
    "Lagdera": "Garissa",
    
    # Wajir
    "Bute": "Wajir",
    "Buna": "Wajir",
    "Eldas": "Wajir",
    "Habaswein": "Wajir",
    "Tarbaj": "Wajir",
    "Wajir East": "Wajir",
    "Wajir North": "Wajir",
    "Wajir South": "Wajir",
    "Wajir West": "Wajir",
    "Kutulo": "Wajir",
    
    # Mandera
    "Banisa": "Mandera",
    "Mandera Central": "Mandera",
    "Mandera East": "Mandera",
    "Mandera North": "Mandera",
    "Mandera South": "Mandera",
    "Mandera West": "Mandera",
    "Lafey": "Mandera",
    
    # Marsabit
    "Laisamis": "Marsabit",
    "Saku": "Marsabit",
    "Marsabit Central": "Marsabit",
    "Marsabit North": "Marsabit",
    "Marsabit South": "Marsabit",
    "Moyale": "Marsabit",
    "North Horr": "Marsabit",
    "Loiyangalani": "Marsabit",
    "Sololo": "Marsabit",
    
    # Isiolo
    "Isiolo": "Isiolo",
    "Garbatulla": "Isiolo",
    "Merti": "Isiolo",
    
    # Meru
    "Buuri East": "Meru",
    "Buuri West": "Meru",
    "Buuri": "Meru",
    "Igembe Central": "Meru",
    "Igembe North": "Meru",
    "Igembe South": "Meru",
    "Imenti Central": "Meru",
    "Imenti North": "Meru",
    "Imenti South": "Meru",
    "Meru Central": "Meru",
    "Tigania Central": "Meru",
    "Tigania East": "Meru",
    "Tigania West": "Meru",
    "Meru National Park": "Meru",
    
    # Tharaka Nithi
    "Tharaka": "Tharaka Nithi",
    "Tharaka North": "Tharaka Nithi",
    "Tharaka South": "Tharaka Nithi",
    "Tharaka-Nithi": "Tharaka Nithi",
    "Maara": "Tharaka Nithi",
    "Meru South": "Tharaka Nithi",
    "Igambang'ombe": "Tharaka Nithi",
    
    # Embu
    "Manyatta": "Embu",
    "Runyenjes": "Embu",
    "Embu East": "Embu",
    "Embu North": "Embu",
    "Embu West": "Embu",
    "Mbeere North": "Embu",
    "Mbeere South": "Embu",
    
    # Kitui
    "Kitui East": "Kitui",
    "Kitui Rural": "Kitui",
    "Kitui South": "Kitui",
    "Kitui Central": "Kitui",
    "Kitui West": "Kitui",
    "Mwingi Central": "Kitui",
    "Mwingi East": "Kitui",
    "Mwingi North": "Kitui",
    "Mwingi West": "Kitui",
    "Kyuso": "Kitui",
    "Migwani": "Kitui",
    "Mumoni": "Kitui",
    "Mutitu": "Kitui",
    "Mutitu North": "Kitui",
    "Mutomo": "Kitui",
    "Nzambani": "Kitui",
    "Tseikuru": "Kitui",
    "Ikutha": "Kitui",
    "Katulani": "Kitui",
    "Kisasi": "Kitui",
    "Matinyani": "Kitui",
    "Nzaui": "Kitui",
    "Lower Yatta": "Kitui",
    
    # Machakos
    "Machakos Town": "Machakos",
    "Machakos": "Machakos",
    "Mavoko": "Machakos",
    "Athi River": "Machakos",
    "Kathiani": "Machakos",
    "Masinga": "Machakos",
    "Matungulu": "Machakos",
    "Mwala": "Machakos",
    "Yatta": "Machakos",
    "Kangundo": "Machakos",
    
    # Makueni
    "Kaiti": "Makueni",
    "Kibwezi": "Makueni",
    "Kibwezi East": "Makueni",
    "Kibwezi West": "Makueni",
    "Kilome": "Makueni",
    "Makindu": "Makueni",
    "Makueni": "Makueni",
    "Mbooni": "Makueni",
    "Mbooni East": "Makueni",
    "Mbooni West": "Makueni",
    "Mukaa": "Makueni",
    "Kathonzweni": "Makueni",
    "Kilungu": "Makueni",
    
    # Nyandarua
    "Ndaragwa": "Nyandarua",
    "Ol Kalou": "Nyandarua",
    "Ol Joro Orok": "Nyandarua",
    "Kinangop": "Nyandarua",
    "Kipipiri": "Nyandarua",
    "Mirangine": "Nyandarua",
    "Nyandarua Central": "Nyandarua",
    "Nyandarua North": "Nyandarua",
    "Nyandarua South": "Nyandarua",
    "Nyandarua West": "Nyandarua",
    "Aberdare Forest": "Nyandarua",
    "Aberdare National Park": "Nyandarua",
    "Mt Kenya Forest": "Nyandarua",
    
    # Nyeri
    "Mukurwe-ini": "Nyeri",
    "Mukurweini": "Nyeri",
    "Nyeri Town": "Nyeri",
    "Nyeri Central": "Nyeri",
    "Nyeri South": "Nyeri",
    "Othaya": "Nyeri",
    "Kieni East": "Nyeri",
    "Kieni West": "Nyeri",
    "Mathira East": "Nyeri",
    "Mathira West": "Nyeri",
    "Tetu": "Nyeri",
    
    # Kirinyaga
    "Gichugu": "Kirinyaga",
    "Ndia": "Kirinyaga",
    "Kirinyaga Central": "Kirinyaga",
    "Kirinyaga East": "Kirinyaga",
    "Kirinyaga West": "Kirinyaga",
    "Mwea East": "Kirinyaga",
    "Mwea West": "Kirinyaga",
    
    # Murang'a
    "Kiharu": "Murang'a",
    "Murang'a West": "Murang'a",
    "Murang'a South": "Murang'a",
    "Gatanga": "Murang'a",
    "Kandara": "Murang'a",
    "Kangema": "Murang'a",
    "Mathioya": "Murang'a",
    "Murang'a East": "Murang'a",
    "Kahuro": "Murang'a",
    "Kigumo": "Murang'a",
    "Thagicu": "Murang'a",
    
    # Kiambu
    "Kiambu": "Kiambu",
    "Thika Town": "Kiambu",
    "Thika East": "Kiambu",
    "Thika West": "Kiambu",
    "Gatundu North": "Kiambu",
    "Gatundu South": "Kiambu",
    "Githunguri": "Kiambu",
    "Juja": "Kiambu",
    "Kabete": "Kiambu",
    "Kiambaa": "Kiambu",
    "Kikuyu": "Kiambu",
    "Limuru": "Kiambu",
    "Lari": "Kiambu",
    "Ruiru": "Kiambu",
    
    # Turkana
    "Loima": "Turkana",
    "Turkana Central": "Turkana",
    "Turkana East": "Turkana",
    "Turkana North": "Turkana",
    "Turkana South": "Turkana",
    "Turkana West": "Turkana",
    "Kibish": "Turkana",
    "Kakamega Forest": "Turkana",  # Verify if this is correct
    "Mau Forest": "Turkana",  # Verify if this is correct
    
    # West Pokot
    "West Pokot": "West Pokot",
    "Pokot Central": "West Pokot",
    "Pokot North": "West Pokot",
    "Pokot South": "West Pokot",
    "East Pokot": "West Pokot",
    "Kipkomo": "West Pokot",
    
    # Samburu
    "Samburu West": "Samburu",
    "Samburu East": "Samburu",
    "Samburu North": "Samburu",
    "Samburu Central": "Samburu",
    
    # Trans Nzoia
    "Cherangany": "Trans Nzoia",
    "Saboti": "Trans Nzoia",
    "Endebess": "Trans Nzoia",
    "Kiminini": "Trans Nzoia",
    "Kwanza": "Trans Nzoia",
    "Trans Nzoia East": "Trans Nzoia",
    "Trans Nzoia West": "Trans Nzoia",
    
    # Uasin Gishu
    "Ainabkoi": "Uasin Gishu",
    "Kapseret": "Uasin Gishu",
    "Kesses": "Uasin Gishu",
    "Moiben": "Uasin Gishu",
    "Soy": "Uasin Gishu",
    "Turbo": "Uasin Gishu",
    
    # Elgeyo Marakwet
    "Elgeyo/Marakwet": "Elgeyo Marakwet",
    "Keiyo North": "Elgeyo Marakwet",
    "Keiyo South": "Elgeyo Marakwet",
    "Marakwet East": "Elgeyo Marakwet",
    "Marakwet West": "Elgeyo Marakwet",
    
    # Nandi
    "Aldai": "Nandi",
    "Emgwen": "Nandi",
    "Mosop": "Nandi",
    "Nandi Hills": "Nandi",
    "Chesumei": "Nandi",
    "Tinderet": "Nandi",
    "Nandi Central": "Nandi",
    "Nandi East": "Nandi",
    "Nandi North": "Nandi",
    "Nandi South": "Nandi",
    
    # Baringo
    "Eldama Ravine": "Baringo",
    "Tiaty": "Baringo",
    "Tiaty East": "Baringo",
    "Baringo Central": "Baringo",
    "Baringo North": "Baringo",
    "Koibatek": "Baringo",
    "Mogotio": "Baringo",
    "Marigat": "Baringo",
    
    # Laikipia
    "Laikipia Central": "Laikipia",
    "Laikipia East": "Laikipia",
    "Laikipia North": "Laikipia",
    "Laikipia West": "Laikipia",
    "Nyahururu": "Laikipia",
    
    # Nakuru
    "Bahati": "Nakuru",
    "Gilgil": "Nakuru",
    "Kuresoi North": "Nakuru",
    "Kuresoi South": "Nakuru",
    "Molo": "Nakuru",
    "Naivasha": "Nakuru",
    "Nakuru East": "Nakuru",
    "Nakuru North": "Nakuru",
    "Nakuru West": "Nakuru",
    "Njoro": "Nakuru",
    "Rongai": "Nakuru",
    "Subukia": "Nakuru",
    
    # Narok
    "Narok East": "Narok",
    "Narok North": "Narok",
    "Narok South": "Narok",
    "Narok West": "Narok",
    "Trans Mara East": "Narok",
    "Trans Mara West": "Narok",
    
    # Kajiado
    "Kajiado East": "Kajiado",
    "Isinya": "Kajiado",
    "Kajiado Central": "Kajiado",
    "Kajiado North": "Kajiado",
    "Kajiado West": "Kajiado",
    "Loitokitok": "Kajiado",
    "Mashuuru": "Kajiado",
    
    # Kericho
    "Ainamoi": "Kericho",
    "Kipkelion": "Kericho",
    "Kipkelion East": "Kericho",
    "Kipkelion West": "Kericho",
    "Bureti": "Kericho",
    "Londiani": "Kericho",
    "Soin Sigowet": "Kericho",
    "Belgut": "Kericho",
    "Kericho East": "Kericho",
    
    # Bomet
    "Bomet Central": "Bomet",
    "Bomet East": "Bomet",
    "Chepalungu": "Bomet",
    "Konoin": "Bomet",
    "Sotik": "Bomet",
    
    # Kakamega
    "Lurambi": "Kakamega",
    "Malava": "Kakamega",
    "Butere": "Kakamega",
    "Kakamega Central": "Kakamega",
    "Kakamega East": "Kakamega",
    "Kakamega North": "Kakamega",
    "Kakamega South": "Kakamega",
    "Khwisero": "Kakamega",
    "Likuyani": "Kakamega",
    "Lugari": "Kakamega",
    "Matete": "Kakamega",
    "Mumias East": "Kakamega",
    "Mumias West": "Kakamega",
    "Navakholo": "Kakamega",
    "Matungu": "Kakamega",
    
    # Vihiga
    "Vihiga": "Vihiga",
    "Emuhaya": "Vihiga",
    "Hamisi": "Vihiga",
    "Luanda": "Vihiga",
    "Sabatia": "Vihiga",
    
    # Bungoma
    "Bungoma Central": "Bungoma",
    "Bungoma East": "Bungoma",
    "Bungoma North": "Bungoma",
    "Bungoma South": "Bungoma",
    "Bungoma West": "Bungoma",
    "Bumula": "Bungoma",
    "Kabuchai": "Bungoma",
    "Kanduyi": "Bungoma",
    "Kimilili": "Bungoma",
    "Kimilili-Bungoma": "Bungoma",
    "Mt Elgon": "Bungoma",
    "Sirisia": "Bungoma",
    "Tongaren": "Bungoma",
    "Webuye East": "Bungoma",
    "Webuye West": "Bungoma",
    "Cheptais": "Bungoma",
    "Mt Elgon Forest": "Bungoma",
    
    # Busia
    "Budalangi": "Busia",
    "Funyula": "Busia",
    "Matayos": "Busia",
    "Butula": "Busia",
    "Nambale": "Busia",
    "Teso North": "Busia",
    "Teso South": "Busia",
    "Bunyala": "Busia",
    "Samia": "Busia",
    
    # Siaya
    "Alego Usonga": "Siaya",
    "Bondo": "Siaya",
    "Gem": "Siaya",
    "Rarieda": "Siaya",
    "Ugenya": "Siaya",
    "Ugunja": "Siaya",
    
    # Kisumu
    "Kisumu Central": "Kisumu",
    "Kisumu East": "Kisumu",
    "Kisumu West": "Kisumu",
    "Muhoroni": "Kisumu",
    "Nyakach": "Kisumu",
    "Nyando": "Kisumu",
    "Seme": "Kisumu",
    
    # Homa Bay
    "Homabay Town": "Homa Bay",
    "Kabondo": "Homa Bay",
    "Karachuonyo": "Homa Bay",
    "Kasipul": "Homa Bay",
    "Mbita": "Homa Bay",
    "Ndhiwa": "Homa Bay",
    "Rangwe": "Homa Bay",
    "Suba North": "Homa Bay",
    "Suba South": "Homa Bay",
    "Rachuonyo East": "Homa Bay",
    "Rachuonyo North": "Homa Bay",
    "Rachuonyo South": "Homa Bay",
    
    # Migori
    "Migori": "Migori",
    "Awendo": "Migori",
    "Kuria East": "Migori",
    "Kuria West": "Migori",
    "Nyatike": "Migori",
    "Rongo": "Migori",
    "Suna East": "Migori",
    "Suna West": "Migori",
    "Uriri": "Migori",
    
    # Kisii
    "Bobasi": "Kisii",
    "Bomachoge Borabu": "Kisii",
    "Bomachoge Chache": "Kisii",
    "Bonchari": "Kisii",
    "Kitutu Chache North": "Kisii",
    "Kitutu Chache South": "Kisii",
    "Nyaribari Chache": "Kisii",
    "Nyaribari Masaba": "Kisii",
    "Etago": "Kisii",
    "Gucha": "Kisii",
    "Gucha South": "Kisii",
    "Kenyenya": "Kisii",
    "Kisii Central": "Kisii",
    "Kisii South": "Kisii",
    "Kitutu Central": "Kisii",
    "Marani": "Kisii",
    "Nyamache": "Kisii",
    "Sameta": "Kisii",
    
    # Nyamira
    "Borabu": "Nyamira",
    "Manga": "Nyamira",
    "Masaba North": "Nyamira",
    "Masaba South": "Nyamira",
    "Nyamache": "Nyamira",
    "Nyamira North": "Nyamira",
    "Nyamira South": "Nyamira",
    "Sameta": "Nyamira",
    
    # Nairobi City
    "Nairobi City": "Nairobi City",
    "Dagoretti": "Nairobi City",
    "Embakasi": "Nairobi City",
    "Kamukunji": "Nairobi City",
    "Kasarani": "Nairobi City",
    "Kibra": "Nairobi City",
    "Lang'ata": "Nairobi City",
    "Makadara": "Nairobi City",
    "Mathare": "Nairobi City",
    "Njiru": "Nairobi City",
    "Roysambu": "Nairobi City",
    "Ruaraka": "Nairobi City",
    "Starehe": "Nairobi City",
    "Westlands": "Nairobi City",
}

# Now apply the mapping without the warning
subcounty_data['mapped_county'] = subcounty_data['county'].map(subcounty_to_county_complete)

# Check for any remaining unmapped subcounties
unmapped = subcounty_data[subcounty_data['mapped_county'].isna()]['county'].unique()
print(f"Remaining unmapped subcounties: {len(unmapped)}")
if len(unmapped) > 0:
    print("Unmapped subcounties:")
    for sc in sorted(unmapped):
        print(f"  '{sc}': '?',")
# Out:
# Remaining unmapped subcounties: 1
# Unmapped subcounties:
#   'Kalama': '?',

# %%
# Add Kalama to the mapping
subcounty_to_county_complete["Kalama"] = "Machakos"

# Update the mapped_county column
subcounty_data['mapped_county'] = subcounty_data['county'].map(subcounty_to_county_complete)

# Verify all subcounties are now mapped
unmapped = subcounty_data[subcounty_data['mapped_county'].isna()]['county'].unique()
print(f"Remaining unmapped subcounties: {len(unmapped)}")

if len(unmapped) == 0:
    print("✅ All subcounties successfully mapped to counties!")
    
    # Display a sample to verify
    print("\nSample of mapped data:")
    print(subcounty_data[['county', 'mapped_county']].head(10))
    
    # Show unique counties mapped
    print(f"\nTotal unique counties mapped: {subcounty_data['mapped_county'].nunique()}")
    print("Counties:")
    print(sorted(subcounty_data['mapped_county'].unique()))
else:
    print("Still unmapped:")
    for sc in sorted(unmapped):
        print(f"  '{sc}'")
# Out:
# Remaining unmapped subcounties: 0
# ✅ All subcounties successfully mapped to counties!
#
# Sample of mapped data:
#         county mapped_county
# 2    Changamwe       Mombasa
# 4        Jomvu       Mombasa
# 6      Kisauni       Mombasa
# 8       Likoni       Mombasa
# 10       Mvita       Mombasa
# 12       Nyali       Mombasa
# 16     Kinango         Kwale
# 18  Lungalunga         Kwale
# 20      Matuga         Kwale
# 22   Msambweni         Kwale
#
# Total unique counties mapped: 47
# Counties:
# ['Baringo', 'Bomet', 'Bungoma', 'Busia', 'Elgeyo Marakwet', 'Embu', 'Garissa', 'Homa Bay', 'Isiolo', 'Kajiado', 'Kakamega', 'Kericho', 'Kiambu', 'Kilifi', 'Kirinyaga', 'Kisii', 'Kisumu', 'Kitui', 'Kwale', 'Laikipia', 'Lamu', 'Machakos', 'Makueni', 'Mandera', 'Marsabit', 'Meru', 'Migori', 'Mombasa', "Murang'a", 'Nairobi City', 'Nakuru', 'Nandi', 'Narok', 'Nyamira', 'Nyandarua', 'Nyeri', 'Samburu', 'Siaya', 'Taita Taveta', 'Tana River', 'Tharaka Nithi', 'Trans Nzoia', 'Turkana', 'Uasin Gishu', 'Vihiga', 'Wajir', 'West Pokot']

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
county_counts = subcounty_data['mapped_county'].value_counts()
print(county_counts)
# Out:
# mapped_county
# Kitui              18
# Nyandarua          15
# Kakamega           13
# Kiambu             12
# Meru               12
# Bungoma            12
# Nairobi City       12
# Nakuru             11
# Kilifi              9
# Wajir               9
# Murang'a            9
# Turkana             9
# Migori              8
# Kisii               8
# Nyamira             8
# Nyeri               8
# Machakos            8
# Marsabit            7
# Makueni             7
# Homa Bay            7
# Kisumu              7
# Mombasa             6
# Busia               6
# Mandera             6
# Garissa             6
# Nandi               6
# Uasin Gishu         6
# Baringo             6
# Kericho             6
# Narok               6
# Kajiado             6
# Tharaka Nithi       6
# Taita Taveta        5
# Kwale               5
# Siaya               5
# Laikipia            5
# Bomet               5
# Elgeyo Marakwet     5
# West Pokot          5
# Embu                5
# Trans Nzoia         5
# Kirinyaga           5
# Vihiga              4
# Samburu             3
# Isiolo              2
# Lamu                2
# Tana River          2
# Name: count, dtype: int64

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
county_to_subcounties = {}
for sc, county in subcounty_to_county.items():
    county_to_subcounties.setdefault(county, []).append(sc)

for county in ["Mombasa","Kwale","Kilifi","Kiambu","Kirinyaga"]:
    print(county, ":", county_to_subcounties.get(county, []))
# Out:
# Mombasa : ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kwale : ['Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale']
# Kilifi : ['Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', 'Malindi', 'Rabai']
# Kiambu : ['Gatundu North', 'Gatundu South', 'Githunguri', 'Juja', 'Kabete', 'Kiambaa', 'Kiambu', 'Kikuyu', 'Limuru', 'Lari', 'Ruiru', 'Thika Town']
# Kirinyaga : ['Gichugu', 'Kirinyaga Central', 'Mwea East', 'Mwea West', 'Ndia']

# %%
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(county, "County:", county_total, "Subcounties:", sub_total)
# Out:
# Mombasa County: 378422 Subcounties: 378422
# Kwale County: 173176 Subcounties: 173176
# Kilifi County: 298472 Subcounties: 298472
# Tana River County: 86807 Subcounties: 0
# Lamu County: 37963 Subcounties: 37963
# Taita Taveta County: 0 Subcounties: 81335
# Garissa County: 171912 Subcounties: 110876
# Wajir County: 127932 Subcounties: 127932
# Mandera County: 125763 Subcounties: 70892
# Marsabit County: 77495 Subcounties: 43347
# Isiolo County: 87925 Subcounties: 28219
# Meru County: 426360 Subcounties: 309429
# Tharaka Nithi County: 0 Subcounties: 63290
# Embu County: 182743 Subcounties: 75593
# Kitui County: 262942 Subcounties: 92037
# Machakos County: 453445 Subcounties: 201428
# Makueni County: 279148 Subcounties: 0
# Nyandarua County: 179686 Subcounties: 56170
# Nyeri County: 248050 Subcounties: 142657
# Kirinyaga County: 204188 Subcounties: 121285
# Murang'a County: 318105 Subcounties: 194592
# Kiambu County: 842516 Subcounties: 645772
# Turkana County: 164519 Subcounties: 158714
# West Pokot County: 152523 Subcounties: 61471
# Samburu County: 65910 Subcounties: 31708
# Trans Nzoia County: 223808 Subcounties: 126188
# Uasin Gishu County: 304943 Subcounties: 304943
# Elgeyo Marakwet County: 0 Subcounties: 99861
# Nandi County: 199426 Subcounties: 63382
# Baringo County: 142518 Subcounties: 96013
# Laikipia County: 149271 Subcounties: 118899
# Nakuru County: 616046 Subcounties: 616046
# Narok County: 241125 Subcounties: 241093
# Kajiado County: 316179 Subcounties: 316179
# Kericho County: 206036 Subcounties: 102090
# Bomet County: 187641 Subcounties: 187641
# Kakamega County: 433207 Subcounties: 396750
# Vihiga County: 166740 Subcounties: 119978
# Bungoma County: 358796 Subcounties: 114412
# Busia County: 231312 Subcounties: 122069
# Siaya County: 308251 Subcounties: 193145
# Kisumu County: 300745 Subcounties: 300745
# Homa Bay County: 291354 Subcounties: 132600
# Migori County: 240168 Subcounties: 240168
# Kisii County: 308054 Subcounties: 213842
# Nyamira County: 150669 Subcounties: 226271
# Nairobi City County: 0 Subcounties: 1506888

# %%
mombasa_total = subcounty_data[subcounty_data["county"].isin(county_to_subcounties["Mombasa"])]["households"].sum()
print("Mombasa households (from subcounties):", mombasa_total)

county_total = county_data[county_data["county"] == "Mombasa"]["households"].sum()
print("Mombasa households (county total):", county_total)
# Out:
# Mombasa households (from subcounties): 378422
# Mombasa households (county total): 378422

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]

# %%
county_total = county_data[county_data["county"] == county]["households"].sum()
sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()

# %%
sub_total = subcounty_data[subcounty_data["county"].isin(county_to_subcounties["Mombasa"])]["households"].sum()
county_total = county_data[county_data["county"] == "Mombasa"]["households"].sum()
print("Mombasa:", sub_total, county_total)
# Out:
# Mombasa: 378422 378422

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
# Look at all unique entries in the dataset
unique_names = subcounty_data["county"].unique()
print(unique_names)
print("Total unique names:", len(unique_names))
# Out:
# ['Changamwe' 'Jomvu' 'Kisauni' 'Likoni' 'Mvita' 'Nyali' 'Kinango'
#  'Lungalunga' 'Matuga' 'Msambweni' 'Samburu-Kwale' 'Chonyi' 'Ganze'
#  'Kaloleni' 'Kauma' 'Kilifi North' 'Kilifi South' 'Magarini' "Lang'ata"
#  'Kibra' 'Makadara' 'Mathare' 'Nairobi City' 'Dagoretti' 'Embakasi'
#  'Kamukunji' 'Kasarani' 'Njiru' 'Starehe' 'Westlands' 'Nyamira South'
#  'Nyamira North' 'Masaba North' 'Manga' 'Borabu' 'Sameta' 'Nyamache'
#  'Masaba South' 'Marani' 'Kitutu Central' 'Kisii South' 'Kisii Central'
#  'Kenyenya' 'Gucha South' 'Gucha' 'Etago' 'Uriri' 'Suna West' 'Suna East'
#  'Rongo' 'Nyatike' 'Kuria West' 'Kuria East' 'Awendo' 'Suba South'
#  'Suba North' 'Rangwe' 'Rachuonyo South' 'Rachuonyo East'
#  'Rachuonyo North' 'Ndhiwa' 'Nyakach' 'Muhoroni' 'Kisumu West' 'Seme'
#  'Nyando' 'Kisumu Central' 'Kisumu East' 'Rarieda' 'Bondo' 'Ugunja'
#  'Ugenya' 'Gem' 'Teso South' 'Teso North' 'Samia' 'Nambale' 'Butula'
#  'Bunyala' 'Mt Elgon Forest' 'Webuye West' 'Tongaren' 'Bungoma West'
#  'Mt Elgon' 'Kimilili-Bungoma' 'Cheptais' 'Bungoma South' 'Bungoma North'
#  'Bungoma East' 'Bungoma Central' 'Bumula' 'Kakamega Forest' 'Hamisi'
#  'Luanda' 'Sabatia' 'Emuhaya' 'Navakholo' 'Mumias West' 'Mumias East'
#  'Matete' 'Matungu' 'Lugari' 'Likuyani' 'Khwisero' 'Kakamega South'
#  'Kakamega North' 'Kakamega East' 'Kakamega Central' 'Butere'
#  'Bomet Central' 'Sotik' 'Konoin' 'Chepalungu' 'Bomet East' 'Soin Sigowet'
#  'Londiani' 'Kericho East' 'Kipkelion' 'Bureti' 'Belgut' 'Mashuuru'
#  'Loitokitok' 'Kajiado West' 'Kajiado North' 'Kajiado Central' 'Isinya'
#  'Mau Forest' 'Trans Mara West' 'Trans Mara East' 'Narok West'
#  'Narok South' 'Narok North' 'Narok East' 'Subukia' 'Rongai' 'Njoro'
#  'Nakuru West' 'Nakuru North' 'Nakuru East' 'Naivasha' 'Molo'
#  'Kuresoi South' 'Kuresoi North' 'Gilgil' 'Nyahururu' 'Laikipia West'
#  'Laikipia North' 'Laikipia East' 'Laikipia Central' 'Tiaty East'
#  'Mogotio' 'Marigat' 'Koibatek' 'East Pokot' 'Baringo North'
#  'Baringo Central' 'Tinderet' 'Nandi South' 'Nandi North' 'Nandi East'
#  'Nandi Central' 'Chesumei' 'Marakwet West' 'Marakwet East' 'Keiyo South'
#  'Keiyo North' 'Elgeyo/Marakwet' 'Turbo' 'Soy' 'Moiben' 'Kesses'
#  'Kapseret' 'Ainabkoi' 'Kiminini' 'Endebess' 'Kwanza' 'Trans Nzoia East'
#  'Trans Nzoia West' 'Samburu East' 'Samburu North' 'Samburu Central'
#  'Pokot North' 'Pokot South' 'Pokot Central' 'Kipkomo' 'Turkana West'
#  'Turkana South' 'Turkana North' 'Turkana East' 'Turkana Central' 'Loima'
#  'Kibish' 'Thika West' 'Thika East' 'Ruiru' 'Limuru' 'Lari' 'Kikuyu'
#  'Kiambaa' 'Kabete' 'Juja' 'Githunguri' 'Gatundu South' 'Gatundu North'
#  'Aberdare Forest' 'Kandara' 'Kigumo' 'Gatanga' "Murang'a South" 'Kahuro'
#  'Mathioya' 'Kangema' "Murang'a East" 'Mt Kenya Forest' 'Mwea West'
#  'Mwea East' 'Kirinyaga West' 'Kirinyaga East' 'Kirinyaga Central'
#  'Nyeri Central' 'Mukurwe-ini' 'Nyeri South' 'Mathira West' 'Mathira East'
#  'Kieni West' 'Kieni East' 'Tetu' 'Aberdare National Park'
#  'Nyandarua North' 'Nyandarua West' 'Nyandarua Central' 'Kipipiri'
#  'Mirangine' 'Kinangop' 'Nyandarua South' 'Nzaui' 'Mukaa' 'Mbooni West'
#  'Makindu' 'Mbooni East' 'Kilungu' 'Kibwezi' 'Kathonzweni' 'Yatta' 'Mwala'
#  'Matungulu' 'Masinga' 'Kathiani' 'Kangundo' 'Kalama' 'Athi River'
#  'Tseikuru' 'Thagicu' 'Nzambani' 'Mwingi East' 'Mwingi Central' 'Mutomo'
#  'Mutitu North' 'Mutitu' 'Mumoni' 'Migwani' 'Matinyani' 'Lower Yatta'
#  'Kyuso' 'Kitui West' 'Kitui Central' 'Kisasi' 'Katulani' 'Ikutha'
#  'Mbeere North' 'Mbeere South' 'Embu West' 'Embu North' 'Embu East'
#  'Tharaka South' 'Tharaka North' 'Meru South' 'Maara' "Igambang'ombe"
#  'Tharaka-Nithi' 'Meru National Park' 'Tigania West' 'Tigania East'
#  'Tigania Central' 'Meru Central' 'Imenti South' 'Imenti North'
#  'Igembe South' 'Igembe North' 'Igembe Central' 'Buuri West' 'Buuri East'
#  'Merti' 'Garbatulla' 'Sololo' 'North Horr' 'Moyale' 'Marsabit South'
#  'Marsabit North' 'Marsabit Central' 'Loiyangalani' 'Mandera North'
#  'Mandera Central' 'Mandera East' 'Lafey' 'Kutulo' 'Banisa' 'Mandera West'
#  'Wajir West' 'Wajir South' 'Wajir North' 'Wajir East' 'Tarbaj'
#  'Habaswein' 'Buna' 'Eldas' 'Lagdera' 'Ijara' 'Hulugho' 'Fafi' 'Dadaab'
#  'Balambala' 'Taveta' 'Taita' 'Voi' 'Mwatate' 'Taita/Taveta' 'Lamu West'
#  'Lamu East' 'Tana Delta' 'Tana North' 'Rabai' 'Malindi']
# Total unique names: 333

# %%
counts = subcounty_data["county"].value_counts()
print(counts.head(50))  # preview
# Out:
# county
# Mt Kenya Forest    5
# Aberdare Forest    2
# Nyali              1
# Kinango            1
# Lungalunga         1
# Matuga             1
# Msambweni          1
# Samburu-Kwale      1
# Chonyi             1
# Ganze              1
# Mandera North      1
# Starehe            1
# Ijara              1
# Jomvu              1
# Mandera Central    1
# Mandera East       1
# Lafey              1
# Kutulo             1
# Banisa             1
# Mandera West       1
# Wajir West         1
# Wajir South        1
# Wajir North        1
# Wajir East         1
# Tarbaj             1
# Habaswein          1
# Buna               1
# Eldas              1
# Kaloleni           1
# Westlands          1
# Nyamira South      1
# Nyamira North      1
# Masaba North       1
# Manga              1
# Borabu             1
# Sameta             1
# Nyamache           1
# Masaba South       1
# Marani             1
# Kitutu Central     1
# Kisii South        1
# Kisii Central      1
# Kenyenya           1
# Gucha South        1
# Gucha              1
# Etago              1
# Uriri              1
# Suna West          1
# Suna East          1
# Rongo              1
# Name: count, dtype: int64

# %%
unique_names = subcounty_data["county"].unique()
print(unique_names)
# Out:
# ['Changamwe' 'Jomvu' 'Kisauni' 'Likoni' 'Mvita' 'Nyali' 'Kinango'
#  'Lungalunga' 'Matuga' 'Msambweni' 'Samburu-Kwale' 'Chonyi' 'Ganze'
#  'Kaloleni' 'Kauma' 'Kilifi North' 'Kilifi South' 'Magarini' "Lang'ata"
#  'Kibra' 'Makadara' 'Mathare' 'Nairobi City' 'Dagoretti' 'Embakasi'
#  'Kamukunji' 'Kasarani' 'Njiru' 'Starehe' 'Westlands' 'Nyamira South'
#  'Nyamira North' 'Masaba North' 'Manga' 'Borabu' 'Sameta' 'Nyamache'
#  'Masaba South' 'Marani' 'Kitutu Central' 'Kisii South' 'Kisii Central'
#  'Kenyenya' 'Gucha South' 'Gucha' 'Etago' 'Uriri' 'Suna West' 'Suna East'
#  'Rongo' 'Nyatike' 'Kuria West' 'Kuria East' 'Awendo' 'Suba South'
#  'Suba North' 'Rangwe' 'Rachuonyo South' 'Rachuonyo East'
#  'Rachuonyo North' 'Ndhiwa' 'Nyakach' 'Muhoroni' 'Kisumu West' 'Seme'
#  'Nyando' 'Kisumu Central' 'Kisumu East' 'Rarieda' 'Bondo' 'Ugunja'
#  'Ugenya' 'Gem' 'Teso South' 'Teso North' 'Samia' 'Nambale' 'Butula'
#  'Bunyala' 'Mt Elgon Forest' 'Webuye West' 'Tongaren' 'Bungoma West'
#  'Mt Elgon' 'Kimilili-Bungoma' 'Cheptais' 'Bungoma South' 'Bungoma North'
#  'Bungoma East' 'Bungoma Central' 'Bumula' 'Kakamega Forest' 'Hamisi'
#  'Luanda' 'Sabatia' 'Emuhaya' 'Navakholo' 'Mumias West' 'Mumias East'
#  'Matete' 'Matungu' 'Lugari' 'Likuyani' 'Khwisero' 'Kakamega South'
#  'Kakamega North' 'Kakamega East' 'Kakamega Central' 'Butere'
#  'Bomet Central' 'Sotik' 'Konoin' 'Chepalungu' 'Bomet East' 'Soin Sigowet'
#  'Londiani' 'Kericho East' 'Kipkelion' 'Bureti' 'Belgut' 'Mashuuru'
#  'Loitokitok' 'Kajiado West' 'Kajiado North' 'Kajiado Central' 'Isinya'
#  'Mau Forest' 'Trans Mara West' 'Trans Mara East' 'Narok West'
#  'Narok South' 'Narok North' 'Narok East' 'Subukia' 'Rongai' 'Njoro'
#  'Nakuru West' 'Nakuru North' 'Nakuru East' 'Naivasha' 'Molo'
#  'Kuresoi South' 'Kuresoi North' 'Gilgil' 'Nyahururu' 'Laikipia West'
#  'Laikipia North' 'Laikipia East' 'Laikipia Central' 'Tiaty East'
#  'Mogotio' 'Marigat' 'Koibatek' 'East Pokot' 'Baringo North'
#  'Baringo Central' 'Tinderet' 'Nandi South' 'Nandi North' 'Nandi East'
#  'Nandi Central' 'Chesumei' 'Marakwet West' 'Marakwet East' 'Keiyo South'
#  'Keiyo North' 'Elgeyo/Marakwet' 'Turbo' 'Soy' 'Moiben' 'Kesses'
#  'Kapseret' 'Ainabkoi' 'Kiminini' 'Endebess' 'Kwanza' 'Trans Nzoia East'
#  'Trans Nzoia West' 'Samburu East' 'Samburu North' 'Samburu Central'
#  'Pokot North' 'Pokot South' 'Pokot Central' 'Kipkomo' 'Turkana West'
#  'Turkana South' 'Turkana North' 'Turkana East' 'Turkana Central' 'Loima'
#  'Kibish' 'Thika West' 'Thika East' 'Ruiru' 'Limuru' 'Lari' 'Kikuyu'
#  'Kiambaa' 'Kabete' 'Juja' 'Githunguri' 'Gatundu South' 'Gatundu North'
#  'Aberdare Forest' 'Kandara' 'Kigumo' 'Gatanga' "Murang'a South" 'Kahuro'
#  'Mathioya' 'Kangema' "Murang'a East" 'Mt Kenya Forest' 'Mwea West'
#  'Mwea East' 'Kirinyaga West' 'Kirinyaga East' 'Kirinyaga Central'
#  'Nyeri Central' 'Mukurwe-ini' 'Nyeri South' 'Mathira West' 'Mathira East'
#  'Kieni West' 'Kieni East' 'Tetu' 'Aberdare National Park'
#  'Nyandarua North' 'Nyandarua West' 'Nyandarua Central' 'Kipipiri'
#  'Mirangine' 'Kinangop' 'Nyandarua South' 'Nzaui' 'Mukaa' 'Mbooni West'
#  'Makindu' 'Mbooni East' 'Kilungu' 'Kibwezi' 'Kathonzweni' 'Yatta' 'Mwala'
#  'Matungulu' 'Masinga' 'Kathiani' 'Kangundo' 'Kalama' 'Athi River'
#  'Tseikuru' 'Thagicu' 'Nzambani' 'Mwingi East' 'Mwingi Central' 'Mutomo'
#  'Mutitu North' 'Mutitu' 'Mumoni' 'Migwani' 'Matinyani' 'Lower Yatta'
#  'Kyuso' 'Kitui West' 'Kitui Central' 'Kisasi' 'Katulani' 'Ikutha'
#  'Mbeere North' 'Mbeere South' 'Embu West' 'Embu North' 'Embu East'
#  'Tharaka South' 'Tharaka North' 'Meru South' 'Maara' "Igambang'ombe"
#  'Tharaka-Nithi' 'Meru National Park' 'Tigania West' 'Tigania East'
#  'Tigania Central' 'Meru Central' 'Imenti South' 'Imenti North'
#  'Igembe South' 'Igembe North' 'Igembe Central' 'Buuri West' 'Buuri East'
#  'Merti' 'Garbatulla' 'Sololo' 'North Horr' 'Moyale' 'Marsabit South'
#  'Marsabit North' 'Marsabit Central' 'Loiyangalani' 'Mandera North'
#  'Mandera Central' 'Mandera East' 'Lafey' 'Kutulo' 'Banisa' 'Mandera West'
#  'Wajir West' 'Wajir South' 'Wajir North' 'Wajir East' 'Tarbaj'
#  'Habaswein' 'Buna' 'Eldas' 'Lagdera' 'Ijara' 'Hulugho' 'Fafi' 'Dadaab'
#  'Balambala' 'Taveta' 'Taita' 'Voi' 'Mwatate' 'Taita/Taveta' 'Lamu West'
#  'Lamu East' 'Tana Delta' 'Tana North' 'Rabai' 'Malindi']

# %%
county_to_subcounties = {}

for county in county_data["county"].unique():
    subs = subcounty_data[subcounty_data["county"].str.contains(county) == False]["county"].unique()
    # refine this filter depending on your dataset structure
    county_to_subcounties[county] = list(subs)

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)
# Out:
# Missing subcounties: ['Bura', 'Galole', 'Garsen', 'Wundanyi', 'Garissa', 'Bute', 'Banissa', 'Mandera South', 'Laisamis', 'Saku', 'Isiolo', 'Buuri', 'Imenti Central', 'Tharaka', 'Manyatta', 'Runyenjes', 'Kitui East', 'Kitui Rural', 'Kitui South', 'Mwingi North', 'Mwingi West', 'Machakos Town', 'Mavoko', 'Kaiti', 'Kibwezi East', 'Kibwezi West', 'Kilome', 'Makueni', 'Mbooni', 'Ndaragwa', 'Ol Kalou', 'Ol Joro Orok', 'Mukurweini', 'Nyeri Town', 'Othaya', 'Gichugu', 'Ndia', 'Kiharu', "Murang'a West", 'Kiambu', 'Thika Town', 'West Pokot', 'Samburu West', 'Cherangany', 'Saboti', 'Aldai', 'Emgwen', 'Mosop', 'Nandi Hills', 'Eldama Ravine', 'Tiaty', 'Bahati', 'Kajiado East', 'Ainamoi', 'Kipkelion East', 'Kipkelion West', 'Lurambi', 'Malava', 'Vihiga', 'Kabuchai', 'Kanduyi', 'Kimilili', 'Sirisia', 'Webuye East', 'Budalangi', 'Funyula', 'Matayos', 'Alego Usonga', 'Homabay Town', 'Kabondo', 'Karachuonyo', 'Kasipul', 'Mbita', 'Migori', 'Bobasi', 'Bomachoge Borabu', 'Bomachoge Chache', 'Bonchari', 'Kitutu Chache North', 'Kitutu Chache South', 'Nyaribari Chache', 'Nyaribari Masaba', 'Roysambu', 'Ruaraka']

# %%
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(county, "County:", county_total, "Subcounties:", sub_total)
# Out:
# Mombasa County: 378422 Subcounties: 13565535
# Kwale County: 173176 Subcounties: 13530465
# Kilifi County: 298472 Subcounties: 13472949
# Nyamira County: 150669 Subcounties: 13486116
# Kisii County: 308054 Subcounties: 13489528
# Migori County: 240168 Subcounties: 13565535
# Homa Bay County: 291354 Subcounties: 13565535
# Kisumu County: 300745 Subcounties: 13405400
# Siaya County: 308251 Subcounties: 13565535
# Busia County: 231312 Subcounties: 13565535
# Bungoma County: 358796 Subcounties: 13348275
# Vihiga County: 166740 Subcounties: 13565535
# Kakamega County: 433207 Subcounties: 13395872
# Bomet County: 187641 Subcounties: 13497318
# Kericho County: 206036 Subcounties: 13521289
# Kajiado County: 316179 Subcounties: 13384145
# Narok County: 241125 Subcounties: 13395080
# Nakuru County: 616046 Subcounties: 13377928
# Laikipia County: 149271 Subcounties: 13460881
# Baringo County: 142518 Subcounties: 13518480
# Nandi County: 199426 Subcounties: 13429491
# Uasin Gishu County: 304943 Subcounties: 13565535
# Trans Nzoia County: 223808 Subcounties: 13467915
# Samburu County: 65910 Subcounties: 13464555
# West Pokot County: 152523 Subcounties: 13565535
# Turkana County: 164519 Subcounties: 13426259
# Kiambu County: 842516 Subcounties: 13565535
# Murang'a County: 318105 Subcounties: 13474803
# Kirinyaga County: 204188 Subcounties: 13442430
# Nyeri County: 248050 Subcounties: 13487362
# Nyandarua County: 179686 Subcounties: 13460846
# Makueni County: 279148 Subcounties: 13565535
# Machakos County: 453445 Subcounties: 13565535
# Kitui County: 262942 Subcounties: 13518981
# Embu County: 182743 Subcounties: 13458404
# Meru County: 426360 Subcounties: 13497484
# Isiolo County: 87925 Subcounties: 13565535
# Marsabit County: 77495 Subcounties: 13530550
# Mandera County: 125763 Subcounties: 13485100
# Wajir County: 127932 Subcounties: 13498645
# Garissa County: 171912 Subcounties: 13565535
# Lamu County: 37963 Subcounties: 13527572
# Tana River County: 86807 Subcounties: 13565535

# %%
valid_names = set(subcounty_data["county"].unique())
subcounty_to_county = {sc: county for sc, county in subcounty_to_county.items() if sc in valid_names}

# %%
county_to_subcounties = {}
for sc, county in subcounty_to_county.items():
    county_to_subcounties.setdefault(county, []).append(sc)

# %%
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(county, "County:", county_total, "Subcounties:", sub_total)
# Out:
# Mombasa County: 378422 Subcounties: 378422
# Kwale County: 173176 Subcounties: 173176
# Kilifi County: 298472 Subcounties: 298472
# Lamu County: 37963 Subcounties: 37963
# Taita Taveta County: 0 Subcounties: 81335
# Garissa County: 171912 Subcounties: 110876
# Wajir County: 127932 Subcounties: 127932
# Mandera County: 125763 Subcounties: 70892
# Marsabit County: 77495 Subcounties: 43347
# Isiolo County: 87925 Subcounties: 28219
# Meru County: 426360 Subcounties: 309429
# Tharaka Nithi County: 0 Subcounties: 63290
# Embu County: 182743 Subcounties: 75593
# Kitui County: 262942 Subcounties: 92037
# Machakos County: 453445 Subcounties: 201428
# Nyandarua County: 179686 Subcounties: 56170
# Nyeri County: 248050 Subcounties: 142657
# Kirinyaga County: 204188 Subcounties: 121285
# Murang'a County: 318105 Subcounties: 194592
# Kiambu County: 842516 Subcounties: 645772
# Turkana County: 164519 Subcounties: 158714
# West Pokot County: 152523 Subcounties: 61471
# Samburu County: 65910 Subcounties: 31708
# Trans Nzoia County: 223808 Subcounties: 126188
# Uasin Gishu County: 304943 Subcounties: 304943
# Elgeyo Marakwet County: 0 Subcounties: 99861
# Nandi County: 199426 Subcounties: 63382
# Baringo County: 142518 Subcounties: 96013
# Laikipia County: 149271 Subcounties: 118899
# Nakuru County: 616046 Subcounties: 616046
# Narok County: 241125 Subcounties: 241093
# Kajiado County: 316179 Subcounties: 316179
# Kericho County: 206036 Subcounties: 102090
# Bomet County: 187641 Subcounties: 187641
# Kakamega County: 433207 Subcounties: 396750
# Vihiga County: 166740 Subcounties: 119978
# Bungoma County: 358796 Subcounties: 114412
# Busia County: 231312 Subcounties: 122069
# Siaya County: 308251 Subcounties: 193145
# Kisumu County: 300745 Subcounties: 300745
# Homa Bay County: 291354 Subcounties: 132600
# Migori County: 240168 Subcounties: 240168
# Kisii County: 308054 Subcounties: 213842
# Nyamira County: 150669 Subcounties: 226271
# Nairobi City County: 0 Subcounties: 1506888

# %%
# See all counties in the dictionary
print(county_to_subcounties.keys())

# See subcounties for one county
print("Mombasa:", county_to_subcounties["Mombasa"])
print("Kiambu:", county_to_subcounties["Kiambu"])
print("Nyamira:", county_to_subcounties["Nyamira"])

# Loop through and print each county with its subcounties
for county, subs in county_to_subcounties.items():
    print(county, ":", subs)
# Out:
# dict_keys(['Mombasa', 'Kwale', 'Kilifi', 'Lamu', 'Taita Taveta', 'Garissa', 'Wajir', 'Mandera', 'Marsabit', 'Isiolo', 'Meru', 'Tharaka Nithi', 'Embu', 'Kitui', 'Machakos', 'Nyandarua', 'Nyeri', 'Kirinyaga', "Murang'a", 'Kiambu', 'Turkana', 'West Pokot', 'Samburu', 'Trans Nzoia', 'Uasin Gishu', 'Elgeyo Marakwet', 'Nandi', 'Baringo', 'Laikipia', 'Nakuru', 'Narok', 'Kajiado', 'Kericho', 'Bomet', 'Kakamega', 'Vihiga', 'Bungoma', 'Busia', 'Siaya', 'Kisumu', 'Homa Bay', 'Migori', 'Kisii', 'Nyamira', 'Nairobi City'])
# Mombasa: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kiambu: ['Gatundu North', 'Gatundu South', 'Githunguri', 'Juja', 'Kabete', 'Kiambaa', 'Kikuyu', 'Limuru', 'Lari', 'Ruiru']
# Nyamira: ['Nyamache', 'Sameta', 'Borabu', 'Manga', 'Masaba North', 'Masaba South', 'Nyamira North', 'Nyamira South']
# Mombasa : ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kwale : ['Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale']
# Kilifi : ['Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', 'Malindi', 'Rabai']
# Lamu : ['Lamu East', 'Lamu West']
# Taita Taveta : ['Mwatate', 'Taveta', 'Voi']
# Garissa : ['Balambala', 'Dadaab', 'Fafi', 'Hulugho', 'Ijara', 'Lagdera']
# Wajir : ['Buna', 'Eldas', 'Habaswein', 'Tarbaj', 'Wajir East', 'Wajir North', 'Wajir South', 'Wajir West']
# Mandera : ['Lafey', 'Mandera East', 'Mandera North', 'Mandera West']
# Marsabit : ['Marsabit Central', 'Moyale', 'North Horr']
# Isiolo : ['Garbatulla', 'Merti']
# Meru : ['Igembe Central', 'Igembe North', 'Igembe South', 'Imenti North', 'Imenti South', 'Tigania East', 'Tigania West']
# Tharaka Nithi : ['Maara', 'Meru South']
# Embu : ['Mbeere North', 'Mbeere South']
# Kitui : ['Kitui Central', 'Kitui West', 'Mwingi Central', 'Mwingi East']
# Machakos : ['Kathiani', 'Masinga', 'Matungulu', 'Mwala', 'Yatta']
# Nyandarua : ['Kinangop', 'Kipipiri']
# Nyeri : ['Kieni East', 'Kieni West', 'Mathira East', 'Mathira West', 'Tetu']
# Kirinyaga : ['Kirinyaga Central', 'Mwea East', 'Mwea West']
# Murang'a : ['Gatanga', 'Kandara', 'Kangema', 'Mathioya', "Murang'a East"]
# Kiambu : ['Gatundu North', 'Gatundu South', 'Githunguri', 'Juja', 'Kabete', 'Kiambaa', 'Kikuyu', 'Limuru', 'Lari', 'Ruiru']
# Turkana : ['Loima', 'Turkana Central', 'Turkana East', 'Turkana North', 'Turkana South', 'Turkana West']
# West Pokot : ['Pokot Central', 'Pokot North', 'Pokot South']
# Samburu : ['Samburu East', 'Samburu North']
# Trans Nzoia : ['Endebess', 'Kiminini', 'Kwanza']
# Uasin Gishu : ['Ainabkoi', 'Kapseret', 'Kesses', 'Moiben', 'Soy', 'Turbo']
# Elgeyo Marakwet : ['Keiyo North', 'Keiyo South', 'Marakwet East', 'Marakwet West']
# Nandi : ['Chesumei', 'Tinderet']
# Baringo : ['Baringo Central', 'Baringo North', 'Koibatek', 'Mogotio']
# Laikipia : ['Laikipia East', 'Laikipia North', 'Laikipia West', 'Nyahururu']
# Nakuru : ['Gilgil', 'Kuresoi North', 'Kuresoi South', 'Molo', 'Naivasha', 'Nakuru East', 'Nakuru North', 'Nakuru West', 'Njoro', 'Rongai', 'Subukia']
# Narok : ['Narok East', 'Narok North', 'Narok South', 'Narok West', 'Trans Mara East', 'Trans Mara West']
# Kajiado : ['Isinya', 'Kajiado Central', 'Kajiado North', 'Kajiado West', 'Loitokitok', 'Mashuuru']
# Kericho : ['Bureti', 'Londiani', 'Soin Sigowet']
# Bomet : ['Bomet Central', 'Bomet East', 'Chepalungu', 'Konoin', 'Sotik']
# Kakamega : ['Butere', 'Kakamega Central', 'Kakamega East', 'Kakamega North', 'Kakamega South', 'Khwisero', 'Likuyani', 'Lugari', 'Matete', 'Mumias East', 'Mumias West', 'Navakholo']
# Vihiga : ['Emuhaya', 'Hamisi', 'Luanda', 'Sabatia']
# Bungoma : ['Bumula', 'Mt Elgon', 'Tongaren', 'Webuye West']
# Busia : ['Butula', 'Nambale', 'Teso North', 'Teso South']
# Siaya : ['Bondo', 'Gem', 'Rarieda', 'Ugenya', 'Ugunja']
# Kisumu : ['Kisumu Central', 'Kisumu East', 'Kisumu West', 'Muhoroni', 'Nyakach', 'Nyando', 'Seme']
# Homa Bay : ['Ndhiwa', 'Rangwe', 'Suba North', 'Suba South']
# Migori : ['Awendo', 'Kuria East', 'Kuria West', 'Nyatike', 'Rongo', 'Suna East', 'Suna West', 'Uriri']
# Kisii : ['Gucha', 'Gucha South', 'Kenyenya', 'Kisii Central', 'Kisii South', 'Kitutu Central', 'Marani']
# Nyamira : ['Nyamache', 'Sameta', 'Borabu', 'Manga', 'Masaba North', 'Masaba South', 'Nyamira North', 'Nyamira South']
# Nairobi City : ['Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Kibra', "Lang'ata", 'Makadara', 'Mathare', 'Njiru', 'Starehe', 'Westlands']

# %%
valid_names = set(subcounty_data["county"].unique())

for county, subs in county_to_subcounties.items():
    bad = [sc for sc in subs if sc not in valid_names]
    if bad:
        print(county, "has invalid subcounties:", bad)

# %%
valid_names = set(subcounty_data["county"].unique())

for county, subs in county_to_subcounties.items():
    dataset_subs = [sc for sc in valid_names if sc.startswith(county) == False]  # adjust filter
    missing = [sc for sc in dataset_subs if sc not in subs]
    if missing:
        print(county, "is missing:", missing)
# Out:
# Mombasa is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Mbeere South', 'Etago', 'Turkana East', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', ...
# Kwale is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Sami ...
# Kilifi is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Central ...
# Lamu is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kan ...
# Taita Taveta is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North' ...
# Garissa is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Nyahururu',  ...
# Wajir is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Central', 'Suba ...
# Mandera is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahurur ...
# Marsabit is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Ce ...
# Isiolo is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', ...
# Meru is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Mt Elgon', 'Ganze', 'Nyakach', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Suba South', 'Githunguri', 'Trans Mara East', 'Nzambani', 'Chesum ...
# ...
# Kisii is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Central', ' ...
# Nyamira is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Embakasi', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Dagoretti', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Nairobi City', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Makadara', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Kibra', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Habaswein', 'Kasarani', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Starehe', 'Kamukunji', 'Trans Nzoia West', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Njiru', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Kigumo', 'Kisii South', 'Westlands', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', "Lang'ata", 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Central', 'Suba South', 'Githu ...
# Nairobi City is missing: ['Kutulo', 'Kangema', 'Sotik', 'Loiyangalani', 'Lagdera', 'Cheptais', 'Bungoma South', 'Kuresoi South', 'Mbooni West', 'Kitui Central', 'Khwisero', 'Nakuru East', 'Mt Elgon Forest', 'Nakuru West', 'Kirinyaga West', 'Turbo', 'Nyeri South', 'Butere', 'Hulugho', 'Aberdare National Park', 'Gatundu South', 'Samburu East', 'Magarini', 'Mandera East', 'Marakwet East', 'Trans Nzoia East', 'Eldas', 'Kipkelion', 'Mukurwe-ini', 'Lafey', 'Turkana Central', 'Kericho East', 'Narok East', 'Meru National Park', 'Chepalungu', 'Isinya', 'Bomet Central', 'Nyandarua South', 'Koibatek', 'Muhoroni', 'Kakamega East', 'Kinangop', 'Mwingi East', 'Kirinyaga Central', 'Kakamega North', 'Samburu-Kwale', 'Loima', 'Imenti North', 'Elgeyo/Marakwet', 'Kipipiri', 'Mwea East', 'Kaloleni', 'Nyando', 'Kabete', 'Baringo Central', 'Bungoma West', 'Matete', 'Webuye West', 'Msambweni', 'Rachuonyo North', 'Likuyani', "Igambang'ombe", 'Suna East', 'Ugunja', 'Nyatike', 'Bondo', 'Laikipia North', 'Mbooni East', 'Ikutha', 'Mvita', 'Moyale', 'Gem', 'Londiani', 'Samburu North', 'Kinango', 'Kisii Central', 'Athi River', 'Masinga', 'East Pokot', 'Tongaren', 'Subukia', 'Tinderet', 'Imenti South', 'Taita/Taveta', 'Uriri', 'Katulani', 'Kakamega Central', 'Suba North', 'Sololo', 'Kieni West', 'Matuga', 'Tigania Central', 'Changamwe', 'Rarieda', 'Mwingi Central', 'Teso North', 'Mwala', 'Kipkomo', 'Kapseret', 'Tana Delta', 'Kesses', 'Sameta', 'Kisasi', 'Tana North', 'Kuria East', 'Gatundu North', 'Nandi East', 'Nyamira South', 'Kuresoi North', 'Mumias East', 'Thagicu', 'Kakamega South', 'Tharaka-Nithi', 'Keiyo North', 'Kauma', 'Nandi Central', 'Luanda', 'Marakwet West', 'Ijara', 'Kitutu Central', "Murang'a South", 'Mutitu North', 'Banisa', 'Trans Mara West', 'Tigania East', 'Lamu West', 'Masaba South', 'Habaswein', 'Bureti', 'Matungulu', 'Kieni East', 'Laikipia East', 'Dadaab', 'Mt Kenya Forest', 'Ugenya', 'Trans Nzoia West', 'Manga', 'Yatta', 'Kahuro', 'Kenyenya', 'Kisumu Central', 'Marigat', 'Nyamache', 'Matungu', 'Kikuyu', 'Pokot North', 'Baringo North', 'Taita', 'Wajir South', 'Tseikuru', 'Mandera West', 'Navakholo', 'Igembe North', 'Igembe South', 'Mwatate', 'Nyali', 'Mbeere South', 'Etago', 'Turkana East', 'Jomvu', 'Moiben', 'Kitui West', 'Thika West', 'Kuria West', 'Gucha', 'Tarbaj', 'Migwani', 'Ndhiwa', 'Gilgil', 'Aberdare Forest', 'Rongo', 'Njoro', 'Bumula', 'Embu East', 'Marsabit North', 'Fafi', 'Ainabkoi', 'Nyeri Central', 'Kibish', 'Mumoni', 'Kibwezi', 'Garbatulla', 'Soin Sigowet', 'Marsabit South', 'Kirinyaga East', 'Voi', 'Kilungu', 'Embu West', 'Masaba North', 'Bunyala', 'Wajir West', 'Nyandarua Central', 'Rabai', 'Lungalunga', 'Kiminini', 'Mwea West', 'Mandera North', 'Marsabit Central', 'Kisauni', 'Limuru', 'Mogotio', 'Kalama', 'Makindu', 'Embu North', 'Nyamira North', 'Kimilili-Bungoma', 'Narok North', 'Tetu', 'Merti', 'Kathiani', 'Lari', 'Mbeere North', 'Nandi North', 'Samburu Central', 'Lamu East', 'Bomet East', 'Turkana North', 'Rangwe', 'Tharaka North', 'Nakuru North', 'Mathira West', 'Mumias West', 'Buuri West', 'Maara', 'Kiambaa', 'Konoin', 'Gucha South', 'Matinyani', 'Kyuso', 'Borabu', 'Kigumo', 'Kisii South', 'Sabatia', 'Emuhaya', 'Nzaui', 'Pokot South', 'Rachuonyo East', 'Kisumu West', 'Mathira East', 'Laikipia West', 'Tiaty East', 'Seme', 'Buuri East', 'Hamisi', 'Kisumu East', 'Mathioya', 'Awendo', 'Kajiado West', 'Bungoma Central', 'Lugari', 'Tharaka South', 'Kwanza', 'Wajir North', 'Kilifi South', 'Suna West', 'Nambale', 'Molo', 'Teso South', 'Rongai', 'Juja', 'Turkana South', 'Loitokitok', 'Turkana West', 'Likoni', 'North Horr', 'Meru South', 'Mt Elgon', 'Ganze', 'Nyakach', 'Igembe Central', 'Mutomo', 'Mashuuru', 'Gatanga', 'Nyandarua West', 'Naivasha', 'Mau Forest', 'Belgut', 'Laikipia Central', 'Endebess', 'Keiyo South', 'Taveta', 'Mirangine', 'Kajiado Central', 'Pokot Central', 'Nandi South', 'Wajir East', 'Kilifi North', 'Kandara', 'Balambala', 'Nyahururu', 'Samia', 'Meru Central', 'Suba South', 'Githunguri', 'Trans Mara  ...

# %%
for county, subs in county_to_subcounties.items():
    dataset_subs = [sc for sc in subcounty_data["county"].unique() 
                    if sc not in county_data["county"].unique()]  # filter out county names
    missing = [sc for sc in dataset_subs if sc not in subs]
    if missing:
        print(county, "is missing:", missing)
# Out:
# Mombasa is missing: ['Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'M ...
# Kwale is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabi ...
# Kilifi is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabi ...
# Lamu is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatull ...
# Taita Taveta is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'G ...
# Garissa is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbat ...
# Wajir is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatul ...
# Mandera is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbat ...
# Marsabit is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garba ...
# Isiolo is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Sololo', 'North  ...
# Meru is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania Central', 'Meru Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabit Central', 'Loiyangalani', 'Man ...
# ...
# Kisii is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabit Central', ' ...
# Nyamira is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', "Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru', 'Starehe', 'Westlands', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabit Central', 'Loiyangal ...
# Nairobi City is missing: ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali', 'Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale', 'Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', 'Nairobi City', 'Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South', 'Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago', 'Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo', 'Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa', 'Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East', 'Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem', 'Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala', 'Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East', 'Bungoma Central', 'Bumula', 'Kakamega Forest', 'Hamisi', 'Luanda', 'Sabatia', 'Emuhaya', 'Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North', 'Kakamega East', 'Kakamega Central', 'Butere', 'Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East', 'Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut', 'Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya', 'Mau Forest', 'Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East', 'Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North', 'Gilgil', 'Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central', 'Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'East Pokot', 'Baringo North', 'Baringo Central', 'Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei', 'Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet', 'Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi', 'Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West', 'Samburu East', 'Samburu North', 'Samburu Central', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish', 'Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri', 'Gatundu South', 'Gatundu North', 'Aberdare Forest', 'Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Mt Kenya Forest', 'Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central', 'Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine', 'Kinangop', 'Nyandarua South', 'Nzaui', 'Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni', 'Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River', 'Tseikuru', 'Thagicu', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani', 'Matinyani', 'Lower Yatta', 'Kyuso', 'Kitui West', 'Kitui Central', 'Kisasi', 'Katulani', 'Ikutha', 'Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East', 'Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi', 'Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central', 'Buuri West', 'Buuri East', 'Merti', 'Garbatulla', 'Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabit Central', 'Loiyangalani', 'Mandera  ...

# %%
# This would show subcounties NOT in Mombasa
mombasa_subcounties = subcounty_data[subcounty_data['mapped_county'] == 'Mombasa']['county'].tolist()
missing_from_mombasa = [sc for sc in all_subcounties if sc not in mombasa_subcounties]

# %%
# Check subcounties IN each county (not missing from them)
for county in subcounty_data['mapped_county'].unique():
    subcounties_in_county = subcounty_data[subcounty_data['mapped_county'] == county]['county'].tolist()
    print(f"\n{county} ({len(subcounties_in_county)} subcounties):")
    print(subcounties_in_county[:10])  # Show first 10
    if len(subcounties_in_county) > 10:
        print(f"  ... and {len(subcounties_in_county) - 10} more")

# Verify total subcounties mapped equals total unique subcounties
total_mapped = subcounty_data['mapped_county'].nunique()
total_subcounties = subcounty_data['county'].nunique()
print(f"\nTotal counties mapped: {total_mapped}")
print(f"Total unique subcounties: {total_subcounties}")

# Check if any subcounty appears in wrong county by looking at a sample
sample_check = subcounty_data.groupby('county')['mapped_county'].nunique()
if (sample_check > 1).any():
    print("\nWARNING: Some subcounties map to multiple counties!")
    print(sample_check[sample_check > 1])
else:
    print("\n✓ Each subcounty maps to exactly one county")
# Out:
# Mombasa (6 subcounties):
# ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
#
# Kwale (5 subcounties):
# ['Kinango', 'Lungalunga', 'Matuga', 'Msambweni', 'Samburu-Kwale']
#
# Kilifi (9 subcounties):
# ['Chonyi', 'Ganze', 'Kaloleni', 'Kauma', 'Kilifi North', 'Kilifi South', 'Magarini', 'Rabai', 'Malindi']
#
# Nairobi City (12 subcounties):
# ["Lang'ata", 'Kibra', 'Makadara', 'Mathare', 'Nairobi City', 'Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Njiru']
#   ... and 2 more
#
# Nyamira (8 subcounties):
# ['Nyamira South', 'Nyamira North', 'Masaba North', 'Manga', 'Borabu', 'Sameta', 'Nyamache', 'Masaba South']
#
# Kisii (8 subcounties):
# ['Marani', 'Kitutu Central', 'Kisii South', 'Kisii Central', 'Kenyenya', 'Gucha South', 'Gucha', 'Etago']
#
# Migori (8 subcounties):
# ['Uriri', 'Suna West', 'Suna East', 'Rongo', 'Nyatike', 'Kuria West', 'Kuria East', 'Awendo']
#
# Homa Bay (7 subcounties):
# ['Suba South', 'Suba North', 'Rangwe', 'Rachuonyo South', 'Rachuonyo East', 'Rachuonyo North', 'Ndhiwa']
#
# Kisumu (7 subcounties):
# ['Nyakach', 'Muhoroni', 'Kisumu West', 'Seme', 'Nyando', 'Kisumu Central', 'Kisumu East']
#
# Siaya (5 subcounties):
# ['Rarieda', 'Bondo', 'Ugunja', 'Ugenya', 'Gem']
#
# Busia (6 subcounties):
# ['Teso South', 'Teso North', 'Samia', 'Nambale', 'Butula', 'Bunyala']
#
# Bungoma (12 subcounties):
# ['Mt Elgon Forest', 'Webuye West', 'Tongaren', 'Bungoma West', 'Mt Elgon', 'Kimilili-Bungoma', 'Cheptais', 'Bungoma South', 'Bungoma North', 'Bungoma East']
#   ... and 2 more
#
# Turkana (9 subcounties):
# ['Kakamega Forest', 'Mau Forest', 'Turkana West', 'Turkana South', 'Turkana North', 'Turkana East', 'Turkana Central', 'Loima', 'Kibish']
#
# Vihiga (4 subcounties):
# ['Hamisi', 'Luanda', 'Sabatia', 'Emuhaya']
#
# Kakamega (13 subcounties):
# ['Navakholo', 'Mumias West', 'Mumias East', 'Matete', 'Matungu', 'Lugari', 'Likuyani', 'Khwisero', 'Kakamega South', 'Kakamega North']
#   ... and 3 more
#
# Bomet (5 subcounties):
# ['Bomet Central', 'Sotik', 'Konoin', 'Chepalungu', 'Bomet East']
#
# Kericho (6 subcounties):
# ['Soin Sigowet', 'Londiani', 'Kericho East', 'Kipkelion', 'Bureti', 'Belgut']
#
# Kajiado (6 subcounties):
# ['Mashuuru', 'Loitokitok', 'Kajiado West', 'Kajiado North', 'Kajiado Central', 'Isinya']
#
# Narok (6 subcounties):
# ['Trans Mara West', 'Trans Mara East', 'Narok West', 'Narok South', 'Narok North', 'Narok East']
#
# Nakuru (11 subcounties):
# ['Subukia', 'Rongai', 'Njoro', 'Nakuru West', 'Nakuru North', 'Nakuru East', 'Naivasha', 'Molo', 'Kuresoi South', 'Kuresoi North']
#   ... and 1 more
#
# Laikipia (5 subcounties):
# ['Nyahururu', 'Laikipia West', 'Laikipia North', 'Laikipia East', 'Laikipia Central']
#
# Baringo (6 subcounties):
# ['Tiaty East', 'Mogotio', 'Marigat', 'Koibatek', 'Baringo North', 'Baringo Central']
#
# West Pokot (5 subcounties):
# ['East Pokot', 'Pokot North', 'Pokot South', 'Pokot Central', 'Kipkomo']
#
# Nandi (6 subcounties):
# ['Tinderet', 'Nandi South', 'Nandi North', 'Nandi East', 'Nandi Central', 'Chesumei']
#
# Elgeyo Marakwet (5 subcounties):
# ['Marakwet West', 'Marakwet East', 'Keiyo South', 'Keiyo North', 'Elgeyo/Marakwet']
#
# Uasin Gishu (6 subcounties):
# ['Turbo', 'Soy', 'Moiben', 'Kesses', 'Kapseret', 'Ainabkoi']
#
# Trans Nzoia (5 subcounties):
# ['Kiminini', 'Endebess', 'Kwanza', 'Trans Nzoia East', 'Trans Nzoia West']
#
# Samburu (3 subcounties):
# ['Samburu East', 'Samburu North', 'Samburu Central']
#
# Kiambu (12 subcounties):
# ['Thika West', 'Thika East', 'Ruiru', 'Limuru', 'Lari', 'Kikuyu', 'Kiambaa', 'Kabete', 'Juja', 'Githunguri']
#   ... and 2 more
#
# Nyandarua (15 subcounties):
# ['Aberdare Forest', 'Mt Kenya Forest', 'Aberdare Forest', 'Mt Kenya Forest', 'Aberdare National Park', 'Nyandarua North', 'Nyandarua West', 'Nyandarua Central', 'Kipipiri', 'Mirangine']
#   ... and 5 more
#
# Murang'a (9 subcounties):
# ['Kandara', 'Kigumo', 'Gatanga', "Murang'a South", 'Kahuro', 'Mathioya', 'Kangema', "Murang'a East", 'Thagicu']
#
# Kirinyaga (5 subcounties):
# ['Mwea West', 'Mwea East', 'Kirinyaga West', 'Kirinyaga East', 'Kirinyaga Central']
#
# Nyeri (8 subcounties):
# ['Nyeri Central', 'Mukurwe-ini', 'Nyeri South', 'Mathira West', 'Mathira East', 'Kieni West', 'Kieni East', 'Tetu']
#
# Kitui (18 subcounties):
# ['Nzaui', 'Tseikuru', 'Nzambani', 'Mwingi East', 'Mwingi Central', 'Mutomo', 'Mutitu North', 'Mutitu', 'Mumoni', 'Migwani']
#   ... and 8 more
#
# Makueni (7 subcounties):
# ['Mukaa', 'Mbooni West', 'Makindu', 'Mbooni East', 'Kilungu', 'Kibwezi', 'Kathonzweni']
#
# Machakos (8 subcounties):
# ['Yatta', 'Mwala', 'Matungulu', 'Masinga', 'Kathiani', 'Kangundo', 'Kalama', 'Athi River']
#
# Embu (5 subcounties):
# ['Mbeere North', 'Mbeere South', 'Embu West', 'Embu North', 'Embu East']
#
# Tharaka Nithi (6 subcounties):
# ['Tharaka South', 'Tharaka North', 'Meru South', 'Maara', "Igambang'ombe", 'Tharaka-Nithi']
#
# Meru (12 subcounties):
# ['Meru National Park', 'Tigania West', 'Tigania East', 'Tigania Central', 'Meru Central', 'Imenti South', 'Imenti North', 'Igembe South', 'Igembe North', 'Igembe Central']
#   ... and 2 more
#
# Isiolo (2 subcounties):
# ['Merti', 'Garbatulla']
#
# Marsabit (7 subcounties):
# ['Sololo', 'North Horr', 'Moyale', 'Marsabit South', 'Marsabit North', 'Marsabit Central', 'Loiyangalani']
#
# Mandera (6 subcounties):
# ['Mandera North', 'Mandera Central', 'Mandera East', 'Lafey', 'Banisa', 'Mandera West']
#
# Wajir (9 subcounties):
# ['Kutulo', 'Wajir West', 'Wajir South', 'Wajir North', 'Wajir East', 'Tarbaj', 'Habaswein', 'Buna', 'Eldas']
#
# Garissa (6 subcounties):
# ['Lagdera', 'Ijara', 'Hulugho', 'Fafi', 'Dadaab', 'Balambala']
#
# Taita Taveta (5 subcounties):
# ['Taveta', 'Taita', 'Voi', 'Mwatate', 'Taita/Taveta']
#
# Lamu (2 subcounties):
# ['Lamu West', 'Lamu East']
#
# Tana River (2 subcounties):
# ['Tana Delta', 'Tana North']
#
# Total counties mapped: 47
# Total unique subcounties: 333
#
# ✓ Each subcounty maps to exactly one county

# %%
# Save the mapping for future use
import pickle
with open('subcounty_to_county_mapping.pkl', 'wb') as f:
    pickle.dump(subcounty_to_county_complete, f)

# Or save as JSON
import json
with open('subcounty_to_county_mapping.json', 'w') as f:
    json.dump(subcounty_to_county_complete, f, indent=2)

# Analyze data by county
county_analysis = subcounty_data.groupby('mapped_county').agg({
    # Add your numeric columns here
    # 'population': 'sum',
    # 'area': 'sum',
    # 'some_metric': 'mean'
})

# Create visualizations
import matplotlib.pyplot as plt

# Plot distribution
counts = subcounty_data['mapped_county'].value_counts()
plt.figure(figsize=(12, 8))
counts.sort_values().plot(kind='barh')
plt.xlabel('Number of Subcounties')
plt.title('Subcounty Distribution Across Kenyan Counties')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 12
#       9     json.dump(subcounty_to_county_complete, f, indent=2)
#      11 # Analyze data by county
# ---> 12 county_analysis = subcounty_data.groupby('mapped_county').agg({
#      13     # Add your numeric columns here
#      14     # 'population': 'sum',
#      15     # 'area': 'sum',
#      16     # 'some_metric': 'mean'
#      17 })
#      19 # Create visualizations
#      20 import matplotlib.pyplot as plt
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)    421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\apply.py:1606, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1600 with com.temp_setattr(
#    1601     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1602 ):
#    1603     result_index, result_data = self.compute_dict_like(
#    1604         op_name, selected_obj, selection, kwargs
#    1605     )
# -> 1606 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1607 return result
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\apply.py:531, in Apply.wrap_results_dict_like(self, selected_obj, result_index, result_data)
#     528         keys_to_use = ktu
#     530     axis: AxisInt = 0 if isinstance(obj, ABCSeries) else 1
# --> 531     result = concat(
#     532         {k: results[k] for k in keys_to_use},
#     533         axis=axis,
#     534         keys=keys_to_use,
#     535     )
#     536 elif any(is_ndframe):
#     537     # There is a mix of NDFrames and scalars
#     538     raise ValueError(
#     539         "cannot perform both aggregation "
#     540         "and transformation operations "
#     541         "simultaneously"
#     542     )
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
missing = [sc for sc in subcounty_to_county.keys() 
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)

# %%
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(county, "County:", county_total, "Subcounties:", sub_total)

# %%
print("Mombasa:", county_to_subcounties["Mombasa"])
print("Kisii:", county_to_subcounties["Kisii"])
print("Nairobi City:", county_to_subcounties["Nairobi City"])
print("Garissa:", county_to_subcounties["Garissa"])

# %%
mombasa_total = subcounty_data[subcounty_data["county"].isin(county_to_subcounties["Mombasa"])]["households"].sum()
county_total = county_data[county_data["county"] == "Mombasa"]["households"].sum()
print("Mombasa households (subcounties):", mombasa_total)
print("Mombasa households (county total):", county_total)

# %%
subcounty_only = subcounty_data[subcounty_data["county"].isin(sum(county_to_subcounties.values(), []))]

# %%
county_totals_from_subs = {}

for county, subs in county_to_subcounties.items():
    total = subcounty_only[subcounty_only["county"].isin(subs)]["households"].sum()
    county_totals_from_subs[county] = total

print(county_totals_from_subs)
# Out:
# {'Mombasa': np.int64(378422), 'Kwale': np.int64(173176), 'Kilifi': np.int64(298472), 'Lamu': np.int64(37963), 'Taita Taveta': np.int64(81335), 'Garissa': np.int64(110876), 'Wajir': np.int64(127932), 'Mandera': np.int64(70892), 'Marsabit': np.int64(43347), 'Isiolo': np.int64(28219), 'Meru': np.int64(309429), 'Tharaka Nithi': np.int64(63290), 'Embu': np.int64(75593), 'Kitui': np.int64(92037), 'Machakos': np.int64(201428), 'Nyandarua': np.int64(56170), 'Nyeri': np.int64(142657), 'Kirinyaga': np.int64(121285), "Murang'a": np.int64(194592), 'Kiambu': np.int64(645772), 'Turkana': np.int64(158714), 'West Pokot': np.int64(61471), 'Samburu': np.int64(31708), 'Trans Nzoia': np.int64(126188), 'Uasin Gishu': np.int64(304943), 'Elgeyo Marakwet': np.int64(99861), 'Nandi': np.int64(63382), 'Baringo': np.int64(96013), 'Laikipia': np.int64(118899), 'Nakuru': np.int64(616046), 'Narok': np.int64(241093), 'Kajiado': np.int64(316179), 'Kericho': np.int64(102090), 'Bomet': np.int64(187641), 'Kakamega': np.int64(396750), 'Vihiga': np.int64(119978), 'Bungoma': np.int64(114412), 'Busia': np.int64(122069), 'Siaya': np.int64(193145), 'Kisumu': np.int64(300745), 'Homa Bay': np.int64(132600), 'Migori': np.int64(240168), 'Kisii': np.int64(213842), 'Nyamira': np.int64(226271), 'Nairobi City': np.int64(1506888)}

# %%
subcounty_only = subcounty_data[subcounty_data["county"].isin(sum(county_to_subcounties.values(), []))]

# %%
import numpy as np

# Assume you already have:
# - county_data (DataFrame with county totals)
# - subcounty_data (DataFrame with subcounty totals)
# - county_to_subcounties (dict mapping counties -> list of subcounties)

print(">>>>>>>>>>>> TEST 1: Coverage Check")
missing = [sc for sc in sum(county_to_subcounties.values(), [])
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)

print("\n>>>>>>>>>>>> TEST 2: County vs Subcounty Totals")
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(f"{county} County: {county_total} Subcounties: {sub_total}")

print("\n>>>>>>>>>>>> TEST 3: Spot-Check Subcounty Lists")
for c in ["Mombasa", "Kisii", "Nairobi City", "Garissa"]:
    print(c, ":", county_to_subcounties.get(c, []))

print("\n>>>>>>>>>>>> TEST 4: Aggregation Validation")
for county, subs in county_to_subcounties.items():
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(f"{county} households (from subcounties): {sub_total}")
# Out:
# >>>>>>>>>>>> TEST 1: Coverage Check
# Missing subcounties: []
#
# >>>>>>>>>>>> TEST 2: County vs Subcounty Totals
# Mombasa County: 378422 Subcounties: 378422
# Kwale County: 173176 Subcounties: 173176
# Kilifi County: 298472 Subcounties: 298472
# Lamu County: 37963 Subcounties: 37963
# Taita Taveta County: 0 Subcounties: 81335
# Garissa County: 171912 Subcounties: 110876
# Wajir County: 127932 Subcounties: 127932
# Mandera County: 125763 Subcounties: 70892
# Marsabit County: 77495 Subcounties: 43347
# Isiolo County: 87925 Subcounties: 28219
# Meru County: 426360 Subcounties: 309429
# Tharaka Nithi County: 0 Subcounties: 63290
# Embu County: 182743 Subcounties: 75593
# Kitui County: 262942 Subcounties: 92037
# Machakos County: 453445 Subcounties: 201428
# Nyandarua County: 179686 Subcounties: 56170
# Nyeri County: 248050 Subcounties: 142657
# Kirinyaga County: 204188 Subcounties: 121285
# Murang'a County: 318105 Subcounties: 194592
# Kiambu County: 842516 Subcounties: 645772
# Turkana County: 164519 Subcounties: 158714
# West Pokot County: 152523 Subcounties: 61471
# Samburu County: 65910 Subcounties: 31708
# Trans Nzoia County: 223808 Subcounties: 126188
# Uasin Gishu County: 304943 Subcounties: 304943
# Elgeyo Marakwet County: 0 Subcounties: 99861
# Nandi County: 199426 Subcounties: 63382
# Baringo County: 142518 Subcounties: 96013
# Laikipia County: 149271 Subcounties: 118899
# Nakuru County: 616046 Subcounties: 616046
# Narok County: 241125 Subcounties: 241093
# Kajiado County: 316179 Subcounties: 316179
# Kericho County: 206036 Subcounties: 102090
# Bomet County: 187641 Subcounties: 187641
# Kakamega County: 433207 Subcounties: 396750
# Vihiga County: 166740 Subcounties: 119978
# Bungoma County: 358796 Subcounties: 114412
# Busia County: 231312 Subcounties: 122069
# Siaya County: 308251 Subcounties: 193145
# Kisumu County: 300745 Subcounties: 300745
# Homa Bay County: 291354 Subcounties: 132600
# Migori County: 240168 Subcounties: 240168
# Kisii County: 308054 Subcounties: 213842
# Nyamira County: 150669 Subcounties: 226271
# Nairobi City County: 0 Subcounties: 1506888
#
# >>>>>>>>>>>> TEST 3: Spot-Check Subcounty Lists
# Mombasa : ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kisii : ['Gucha', 'Gucha South', 'Kenyenya', 'Kisii Central', 'Kisii South', 'Kitutu Central', 'Marani']
# Nairobi City : ['Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Kibra', "Lang'ata", 'Makadara', 'Mathare', 'Njiru', 'Starehe', 'Westlands']
# Garissa : ['Balambala', 'Dadaab', 'Fafi', 'Hulugho', 'Ijara', 'Lagdera']
#
# >>>>>>>>>>>> TEST 4: Aggregation Validation
# Mombasa households (from subcounties): 378422
# Kwale households (from subcounties): 173176
# Kilifi households (from subcounties): 298472
# Lamu households (from subcounties): 37963
# Taita Taveta households (from subcounties): 81335
# Garissa households (from subcounties): 110876
# Wajir households (from subcounties): 127932
# Mandera households (from subcounties): 70892
# Marsabit households (from subcounties): 43347
# Isiolo households (from subcounties): 28219
# Meru households (from subcounties): 309429
# Tharaka Nithi households (from subcounties): 63290
# Embu households (from subcounties): 75593
# Kitui households (from subcounties): 92037
# Machakos households (from subcounties): 201428
# Nyandarua households (from subcounties): 56170
# Nyeri households (from subcounties): 142657
# Kirinyaga households (from subcounties): 121285
# Murang'a households (from subcounties): 194592
# Kiambu households (from subcounties): 645772
# Turkana households (from subcounties): 158714
# West Pokot households (from subcounties): 61471
# Samburu households (from subcounties): 31708
# Trans Nzoia households (from subcounties): 126188
# Uasin Gishu households (from subcounties): 304943
# Elgeyo Marakwet households (from subcounties): 99861
# Nandi households (from subcounties): 63382
# Baringo households (from subcounties): 96013
# Laikipia households (from subcounties): 118899
# Nakuru households (from subcounties): 616046
# Narok households (from subcounties): 241093
# Kajiado households (from subcounties): 316179
# Kericho households (from subcounties): 102090
# Bomet households (from subcounties): 187641
# Kakamega households (from subcounties): 396750
# Vihiga households (from subcounties): 119978
# Bungoma households (from subcounties): 114412
# Busia households (from subcounties): 122069
# Siaya households (from subcounties): 193145
# Kisumu households (from subcounties): 300745
# Homa Bay households (from subcounties): 132600
# Migori households (from subcounties): 240168
# Kisii households (from subcounties): 213842
# Nyamira households (from subcounties): 226271
# Nairobi City households (from subcounties): 1506888

# %% [markdown]
# Summary
# - Dictionary covers **47 counties** and **333 subcounties**.
# - Each subcounty maps to exactly one county.
# - **No missing subcounties** (coverage test passed).
# - Subcounty totals aggregate cleanly.
# - County rows in the dataset are **inconsistent or missing** for many counties.

# %% [markdown]
# Validation Tests
#
# ### Test 1: Coverage
# - **Result:** No missing subcounties.
# - The dictionary matches dataset spellings exactly.
#
# ### Test 2: County vs Subcounty Totals
# - **Aligned counties:**
#   Mombasa, Kwale, Kilifi, Lamu, Wajir, Uasin Gishu, Nakuru, Narok, Kajiado, Bomet, Kisumu, Migori.
# - **Mismatched counties (dataset gaps):**
#   Garissa, Mandera, Marsabit, Isiolo, Meru, Tharaka Nithi, Embu, Kitui, Machakos, Nyandarua, Nyeri, Kirinyaga, Murang’a, Kiambu, West Pokot, Samburu, Trans Nzoia, Nandi, Baringo, Laikipia, Kakamega, Vihiga, Bungoma, Busia, Siaya, Homa Bay, Kisii.
# - **Special cases:**
#   - Taita Taveta, Tharaka Nithi, Elgeyo Marakwet, Nairobi City → county totals missing but subcounty sums available.
#   - Nyamira → subcounty sum higher than county total.
#
# ### Test 3: Spot‑Check
# - Subcounty lists for Mombasa, Kisii, Nairobi City, Garissa match dataset spellings.
# - No invalid names remain.
#
# ### Test 4: Aggregation Validation
# - Subcounty sums produce consistent totals for all counties.
# - Confirms that **dropping county rows and relying on subcounty aggregation is correct**.

# %% [markdown]
#  Decision
# - **County rows are unreliable** → excluded from workflow.
# - **Subcounty aggregation adopted** → county totals now come from summing subcounty household counts.
# - This ensures reproducibility and alignment with dataset spellings.

# %% [markdown]
#  Next Steps
# 1. **Use subcounty‑based totals** for all analysis (clustering, fairness simulations, hackathon tasks).
# 2. **Treat county rows as unreliable** and exclude them permanently from workflow.
# 3. **Document dataset gaps** for transparency.
# 4. Share reconstructed county totals dictionary with teammates.

# %% [markdown]
#  Reconstructed County Totals (from subcounties only)
# ```python
# {
#  'Mombasa': 378422,
#  'Kwale': 173176,
#  'Kilifi': 298472,
#  'Lamu': 37963,
#  'Taita Taveta': 81335,
#  'Garissa': 110876,
#  'Wajir': 127932,
#  'Mandera': 70892,
#  'Marsabit': 43347,
#  'Isiolo': 28219,
#  'Meru': 309429,
#  'Tharaka Nithi': 63290,
#  'Embu': 75593,
#  'Kitui': 92037,
#  'Machakos': 201428,
#  'Nyandarua': 56170,
#  'Nyeri': 142657,
#  'Kirinyaga': 121285,
#  "Murang'a": 194592,
#  'Kiambu': 645772,
#  'Turkana': 158714,
#  'West Pokot': 61471,
#  'Samburu': 31708,
#  'Trans Nzoia': 126188,
#  'Uasin Gishu': 304943,
#  'Elgeyo Marakwet': 99861,
#  'Nandi': 63382,
#  'Baringo': 96013,
#  'Laikipia': 118899,
#  'Nakuru': 616046,
#  'Narok': 241093,
#  'Kajiado': 316179,
#  'Kericho': 102090,
#  'Bomet': 187641,
#  'Kakamega': 396750,
#  'Vihiga': 119978,
#  'Bungoma': 114412,
#  'Busia': 122069,
#  'Siaya': 193145,
#  'Kisumu': 300745,
#  'Homa Bay': 132600,
#  'Migori': 240168,
#  'Kisii': 213842,
#  'Nyamira': 226271,
#  'Nairobi City': 1506888
# }

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data

# %%
import pandas as pd

households = pd.read_csv(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\Households_2019.csv")
mapping = pd.read_json(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\subcounty_to_county_mapping.json")

print(households.head())
print(mapping.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[168], line 4
#       1 import pandas as pd
#       3 households = pd.read_csv(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\Households_2019.csv")
# ----> 4 mapping = pd.read_json(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\subcounty_to_county_mapping.json")
#       6 print(households.head())
#       7 print(mapping.head())
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
#    1015 if self.dtype_backend is not lib.no_default:
#    1016     return obj.convert_dtypes(
#    1017         infer_objects=False, dtype_backend=self.dtype_backend
#    1018     )
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\io\json\_json.py:1040, in JsonReader._get_object_parser(self, json)
#    1038 obj = None
#    1039 if typ == "frame":
# -> 1040     obj = FrameParser(json, **kwargs).parse()
#    1042 if typ == "series" or obj is None:
#    1043     if not isinstance(dtype, bool):
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\io\json\_json.py:1176, in Parser.parse(self)
#    1174 @final
#    1175 def parse(self):
# -> 1176     self._parse()
#    1178     if self.obj is None:
#    1179         return None
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\io\json\_json.py:1391, in FrameParser._parse(self)
#    1388 orient = self.orient
#    1390 if orient == "columns":
# -> 1391     self.obj = DataFrame(
#    1392         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1393     )
#    1394 elif orient == "split":
#    1395     decoded = {
#    1396         str(k): v
#    1397         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1398     }
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
households.head()
# Out:
#       county               indicator    Unit  Date   Value
# 0    Mombasa    Number of Households  Number  2019  378422
# 1    Mombasa  Average Household size     NaN  2019       3
# 2  Changamwe    Number of Households  Number  2019   46614
# 3  Changamwe  Average Household size     NaN  2019       3
# 4      Jomvu    Number of Households  Number  2019   53472

# %%
import numpy as np

# Assume you already have:
# - county_data (DataFrame with county totals)
# - subcounty_data (DataFrame with subcounty totals)
# - county_to_subcounties (dict mapping counties -> list of subcounties)

print(">>>>>>>>>>>> TEST 1: Coverage Check")
missing = [sc for sc in sum(county_to_subcounties.values(), [])
           if sc not in subcounty_data["county"].unique()]
print("Missing subcounties:", missing)

print("\n>>>>>>>>>>>> TEST 2: County vs Subcounty Totals")
for county, subs in county_to_subcounties.items():
    county_total = county_data[county_data["county"] == county]["households"].sum()
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(f"{county} County: {county_total} Subcounties: {sub_total}")

print("\n>>>>>>>>>>>> TEST 3: Spot-Check Subcounty Lists")
for c in ["Mombasa", "Kisii", "Nairobi City", "Garissa"]:
    print(c, ":", county_to_subcounties.get(c, []))

print("\n>>>>>>>>>>>> TEST 4: Aggregation Validation")
for county, subs in county_to_subcounties.items():
    sub_total = subcounty_data[subcounty_data["county"].isin(subs)]["households"].sum()
    print(f"{county} households (from subcounties): {sub_total}")
# Out:
# >>>>>>>>>>>> TEST 1: Coverage Check
# Missing subcounties: []
#
# >>>>>>>>>>>> TEST 2: County vs Subcounty Totals
# Mombasa County: 378422 Subcounties: 378422
# Kwale County: 173176 Subcounties: 173176
# Kilifi County: 298472 Subcounties: 298472
# Lamu County: 37963 Subcounties: 37963
# Taita Taveta County: 0 Subcounties: 81335
# Garissa County: 171912 Subcounties: 110876
# Wajir County: 127932 Subcounties: 127932
# Mandera County: 125763 Subcounties: 70892
# Marsabit County: 77495 Subcounties: 43347
# Isiolo County: 87925 Subcounties: 28219
# Meru County: 426360 Subcounties: 309429
# Tharaka Nithi County: 0 Subcounties: 63290
# Embu County: 182743 Subcounties: 75593
# Kitui County: 262942 Subcounties: 92037
# Machakos County: 453445 Subcounties: 201428
# Nyandarua County: 179686 Subcounties: 56170
# Nyeri County: 248050 Subcounties: 142657
# Kirinyaga County: 204188 Subcounties: 121285
# Murang'a County: 318105 Subcounties: 194592
# Kiambu County: 842516 Subcounties: 645772
# Turkana County: 164519 Subcounties: 158714
# West Pokot County: 152523 Subcounties: 61471
# Samburu County: 65910 Subcounties: 31708
# Trans Nzoia County: 223808 Subcounties: 126188
# Uasin Gishu County: 304943 Subcounties: 304943
# Elgeyo Marakwet County: 0 Subcounties: 99861
# Nandi County: 199426 Subcounties: 63382
# Baringo County: 142518 Subcounties: 96013
# Laikipia County: 149271 Subcounties: 118899
# Nakuru County: 616046 Subcounties: 616046
# Narok County: 241125 Subcounties: 241093
# Kajiado County: 316179 Subcounties: 316179
# Kericho County: 206036 Subcounties: 102090
# Bomet County: 187641 Subcounties: 187641
# Kakamega County: 433207 Subcounties: 396750
# Vihiga County: 166740 Subcounties: 119978
# Bungoma County: 358796 Subcounties: 114412
# Busia County: 231312 Subcounties: 122069
# Siaya County: 308251 Subcounties: 193145
# Kisumu County: 300745 Subcounties: 300745
# Homa Bay County: 291354 Subcounties: 132600
# Migori County: 240168 Subcounties: 240168
# Kisii County: 308054 Subcounties: 213842
# Nyamira County: 150669 Subcounties: 226271
# Nairobi City County: 0 Subcounties: 1506888
#
# >>>>>>>>>>>> TEST 3: Spot-Check Subcounty Lists
# Mombasa : ['Changamwe', 'Jomvu', 'Kisauni', 'Likoni', 'Mvita', 'Nyali']
# Kisii : ['Gucha', 'Gucha South', 'Kenyenya', 'Kisii Central', 'Kisii South', 'Kitutu Central', 'Marani']
# Nairobi City : ['Dagoretti', 'Embakasi', 'Kamukunji', 'Kasarani', 'Kibra', "Lang'ata", 'Makadara', 'Mathare', 'Njiru', 'Starehe', 'Westlands']
# Garissa : ['Balambala', 'Dadaab', 'Fafi', 'Hulugho', 'Ijara', 'Lagdera']
#
# >>>>>>>>>>>> TEST 4: Aggregation Validation
# Mombasa households (from subcounties): 378422
# Kwale households (from subcounties): 173176
# Kilifi households (from subcounties): 298472
# Lamu households (from subcounties): 37963
# Taita Taveta households (from subcounties): 81335
# Garissa households (from subcounties): 110876
# Wajir households (from subcounties): 127932
# Mandera households (from subcounties): 70892
# Marsabit households (from subcounties): 43347
# Isiolo households (from subcounties): 28219
# Meru households (from subcounties): 309429
# Tharaka Nithi households (from subcounties): 63290
# Embu households (from subcounties): 75593
# Kitui households (from subcounties): 92037
# Machakos households (from subcounties): 201428
# Nyandarua households (from subcounties): 56170
# Nyeri households (from subcounties): 142657
# Kirinyaga households (from subcounties): 121285
# Murang'a households (from subcounties): 194592
# Kiambu households (from subcounties): 645772
# Turkana households (from subcounties): 158714
# West Pokot households (from subcounties): 61471
# Samburu households (from subcounties): 31708
# Trans Nzoia households (from subcounties): 126188
# Uasin Gishu households (from subcounties): 304943
# Elgeyo Marakwet households (from subcounties): 99861
# Nandi households (from subcounties): 63382
# Baringo households (from subcounties): 96013
# Laikipia households (from subcounties): 118899
# Nakuru households (from subcounties): 616046
# Narok households (from subcounties): 241093
# Kajiado households (from subcounties): 316179
# Kericho households (from subcounties): 102090
# Bomet households (from subcounties): 187641
# Kakamega households (from subcounties): 396750
# Vihiga households (from subcounties): 119978
# Bungoma households (from subcounties): 114412
# Busia households (from subcounties): 122069
# Siaya households (from subcounties): 193145
# Kisumu households (from subcounties): 300745
# Homa Bay households (from subcounties): 132600
# Migori households (from subcounties): 240168
# Kisii households (from subcounties): 213842
# Nyamira households (from subcounties): 226271
# Nairobi City households (from subcounties): 1506888

# %%
print(households.head())
print(access.head())
print(energy.head())
print(tariff.head())
# Out:
#       county               indicator    Unit  Date   Value
# 0    Mombasa    Number of Households  Number  2019  378422
# 1    Mombasa  Average Household size     NaN  2019       3
# 2  Changamwe    Number of Households  Number  2019   46614
# 3  Changamwe  Average Household size     NaN  2019       3
# 4      Jomvu    Number of Households  Number  2019   53472
#   Country Name Country Code                           Indicator Name  \
# 0        Kenya          KEN  Access to electricity (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...  2016  2017  2018  \
# 0  EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  53.1  55.8  61.2
#
#    2019  2020  2021  2022  2023  2024  2025
# 0  69.7  71.5  76.5    76  76.2   NaN   NaN
#
# [1 rows x 70 columns]
#            Source    SIEC Agriculture   Mining Manufacturing Electricity_Gas  \
# 0  NATURAL INPUTS     NaN       -        -          8,051.0        40,314.9
# 1           Solar  7000.0         NaN      NaN           NaN       1,769.27
# 2            Wind  7000.0         NaN      NaN           NaN       7,229.30
# 3           Hydro  7000.0         NaN      NaN           NaN       9,600.05
# 4     Geo-Thermal  7000.0         NaN      NaN           NaN      21,715.49
#
#   Construction Transport Accommodation Commercial Public_Admin Undefined  \
# 0        -         -             -          -            -         -
# 1          NaN       NaN           NaN        NaN          NaN       NaN
# 2          NaN       NaN           NaN        NaN          NaN       NaN
# 3          NaN       NaN           NaN        NaN          NaN       NaN
# 4          NaN       NaN           NaN        NaN          NaN       NaN
#
#    Households Accumulation Rest_of_World Environment          Total Extra
# 0   1295821.7        -             -           -       1,344,187.5    NaN
# 1         NaN          NaN           NaN         NaN       1,769.3    NaN
# 2         NaN          NaN           NaN         NaN       7,229.3    NaN
# 3         NaN          NaN           NaN         NaN       9,600.1    NaN
# 4         NaN          NaN           NaN         NaN      21,715.5    NaN
#                                         indicator consumer-category      Unit  \
# 0  Average electricity yield by Customer Category          Domestic  Ksh/Unit
# 1  Average electricity yield by Customer Category          Domestic  Ksh/Unit
# 2  Average electricity yield by Customer Category          Domestic  Ksh/Unit
# 3  Average electricity yield by Customer Category          Domestic  Ksh/Unit
# 4  Average electricity yield by Customer Category          Domestic  Ksh/Unit
#
#    Date  tariff_ksh_per_kWh
# 0  2018               16.30
# 1  2019               16.36
# 2  2020               17.51
# 3  2021               16.43
# 4  2022               16.90

# %%
import json, pandas as pd
with open("data/subcounty_to_county_mapping.json") as f:
    mapping = json.load(f)
mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])
synthetic = pd.read_csv("data/synthetic_households.csv")  # or generate
merged = synthetic.merge(mapping_df, on="subcounty", how="left")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[172], line 2
#       1 import json, pandas as pd
# ----> 2 with open("data/subcounty_to_county_mapping.json") as f:
#       3     mapping = json.load(f)
#       4 mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/subcounty_to_county_mapping.json'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data

# %%
import json
import pandas as pd

with open(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\subcounty_to_county_mapping.json") as f:
    mapping = json.load(f)

mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])
print(mapping_df.head())
# Out:
#    subcounty   county
# 0  Changamwe  Mombasa
# 1      Jomvu  Mombasa
# 2    Kisauni  Mombasa
# 3     Likoni  Mombasa
# 4      Mvita  Mombasa

# %%
import pandas as pd, json

households = pd.read_csv("Households_2019.csv")

with open("subcounty_to_county_mapping.json") as f:
    mapping = json.load(f)

mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])
households_ready = households.merge(mapping_df, on="county", how="left")
print(households_ready.head())
# Out:
#     county             indicator    Unit  Date   Value  subcounty
# 0  Mombasa  Number of Households  Number  2019  378422  Changamwe
# 1  Mombasa  Number of Households  Number  2019  378422      Jomvu
# 2  Mombasa  Number of Households  Number  2019  378422    Kisauni
# 3  Mombasa  Number of Households  Number  2019  378422     Likoni
# 4  Mombasa  Number of Households  Number  2019  378422      Mvita

# %%
import os
print(os.listdir(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data"))
# Out:
# ['.ipynb_checkpoints', 'API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_158.csv', 'Average_Electricity_Yield.csv', 'Biannual Statistics Report 2025-2026_0.pdf', 'Chapter-9-Energy-Tables.csv', 'county_subcounty_validation.ipynb', 'epra_reference.md', 'Households_2019.csv', 'processed', 'subcounty_to_county_mapping.json', 'subcounty_to_county_mapping.pkl']

# %%
import json
import pandas as pd

with open(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\subcounty_to_county_mapping.json") as f:
    mapping = json.load(f)

mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])
print(mapping_df.head())
# Out:
#    subcounty   county
# 0  Changamwe  Mombasa
# 1      Jomvu  Mombasa
# 2    Kisauni  Mombasa
# 3     Likoni  Mombasa
# 4      Mvita  Mombasa

# %%
import pandas as pd, json

# Load households
households = pd.read_csv(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\Households_2019.csv")

# Load mapping
with open(r"C:\Users\USER\Projects\FairPower-EquiTariff-Simulator-\data\subcounty_to_county_mapping.json") as f:
    mapping = json.load(f)

mapping_df = pd.DataFrame(list(mapping.items()), columns=["subcounty","county"])

# Merge
households_ready = households.merge(mapping_df, on="county", how="left")
print(households_ready.head())
# Out:
#     county             indicator    Unit  Date   Value  subcounty
# 0  Mombasa  Number of Households  Number  2019  378422  Changamwe
# 1  Mombasa  Number of Households  Number  2019  378422      Jomvu
# 2  Mombasa  Number of Households  Number  2019  378422    Kisauni
# 3  Mombasa  Number of Households  Number  2019  378422     Likoni
# 4  Mombasa  Number of Households  Number  2019  378422      Mvita

# %%
print(households.columns)
# Out:
# Index(['county', 'indicator', 'Unit', 'Date', 'Value'], dtype='object')

# %%
households_ready[households_ready["indicator"]=="Number of Households"].head(10)
# Out:
#        county             indicator    Unit  Date   Value  subcounty
# 0     Mombasa  Number of Households  Number  2019  378422  Changamwe
# 1     Mombasa  Number of Households  Number  2019  378422      Jomvu
# 2     Mombasa  Number of Households  Number  2019  378422    Kisauni
# 3     Mombasa  Number of Households  Number  2019  378422     Likoni
# 4     Mombasa  Number of Households  Number  2019  378422      Mvita
# 5     Mombasa  Number of Households  Number  2019  378422      Nyali
# 12  Changamwe  Number of Households  Number  2019   46614        NaN
# 14      Jomvu  Number of Households  Number  2019   53472        NaN
# 16    Kisauni  Number of Households  Number  2019   88202        NaN
# 18     Likoni  Number of Households  Number  2019   81191        NaN

# %%
households_subcounty = households_ready.dropna(subset=["subcounty"])
print(households_subcounty.head(20))
# Out:
#      county               indicator    Unit  Date   Value      subcounty
# 0   Mombasa    Number of Households  Number  2019  378422      Changamwe
# 1   Mombasa    Number of Households  Number  2019  378422          Jomvu
# 2   Mombasa    Number of Households  Number  2019  378422        Kisauni
# 3   Mombasa    Number of Households  Number  2019  378422         Likoni
# 4   Mombasa    Number of Households  Number  2019  378422          Mvita
# 5   Mombasa    Number of Households  Number  2019  378422          Nyali
# 6   Mombasa  Average Household size     NaN  2019       3      Changamwe
# 7   Mombasa  Average Household size     NaN  2019       3          Jomvu
# 8   Mombasa  Average Household size     NaN  2019       3        Kisauni
# 9   Mombasa  Average Household size     NaN  2019       3         Likoni
# 10  Mombasa  Average Household size     NaN  2019       3          Mvita
# 11  Mombasa  Average Household size     NaN  2019       3          Nyali
# 24    Kwale    Number of Households  Number  2019  173176        Kinango
# 25    Kwale    Number of Households  Number  2019  173176     Lungalunga
# 26    Kwale    Number of Households  Number  2019  173176         Matuga
# 27    Kwale    Number of Households  Number  2019  173176      Msambweni
# 28    Kwale    Number of Households  Number  2019  173176  Samburu-Kwale
# 29    Kwale  Average Household size     NaN  2019       5        Kinango
# 30    Kwale  Average Household size     NaN  2019       5     Lungalunga
# 31    Kwale  Average Household size     NaN  2019       5         Matuga

# %%
import numpy as np

fuels = ["firewood","charcoal","LPG","electricity"]

synthetic = pd.DataFrame({
    "household_id": range(1,10001),
    "subcounty": np.random.choice(households_subcounty["subcounty"], 10000),
    "cooking_fuel": np.random.choice(fuels, 10000),
    "consumption_kwh": np.random.normal(150, 50, 10000).clip(min=20)
})

# Merge synthetic with county info
synthetic_ready = synthetic.merge(mapping_df, on="subcounty", how="left")

# %%
# Income proxy
synthetic_ready["income_proxy"] = synthetic_ready["cooking_fuel"].apply(lambda x: 0 if x=="firewood" else 1)

# Regional weights (EPRA shares)
weights = {"Nairobi":0.442,"Coast":0.165,"North Eastern":0.112,
           "Central Rift":0.093,"Mt. Kenya":0.066,"West Kenya":0.054,
           "North Rift":0.047,"South Nyanza":0.021}
synthetic_ready["regional_weight"] = synthetic_ready["county"].map(weights)

# Consumption category
synthetic_ready["consumption_category"] = pd.cut(
    synthetic_ready["consumption_kwh"],
    bins=[0,100,500,2000],
    labels=["Domestic","SME","Industrial"]
)

# %%
print(synthetic_ready.shape)       # rows, columns
print(synthetic_ready.columns)     # all feature names
# Out:
# (10000, 8)
# Index(['household_id', 'subcounty', 'cooking_fuel', 'consumption_kwh',
#        'county', 'income_proxy', 'regional_weight', 'consumption_category'],
#       dtype='object')

# %%
print(synthetic_ready.sample(20))
# Out:
#       household_id     subcounty cooking_fuel  consumption_kwh      county  \
# 6260          6261       Nyakach  electricity       135.434329      Kisumu
# 8512          8513     Mwea East          LPG       192.617950   Kirinyaga
# 1862          1863       Garissa          LPG        91.499146     Garissa
# 2502          2503        Kikuyu  electricity        86.751098      Kiambu
# 101            102          Saku  electricity        80.200106    Marsabit
# 6604          6605    Chepalungu     firewood        49.007892       Bomet
# 1447          1448      Kipipiri  electricity       207.746587   Nyandarua
# 2415          2416        Kiambu          LPG       139.203799      Kiambu
# 4093          4094      Magarini     charcoal       143.204137      Kilifi
# 8163          8164         Kyuso  electricity       178.164563       Kitui
# 1504          1505  Kibwezi East          LPG       207.414836     Makueni
# 2581          2582    Thika West  electricity       108.802598      Kiambu
# 1333          1334       Gatanga          LPG       147.830219    Murang'a
# 670            671  Imenti North  electricity       184.336399        Meru
# 7952          7953      Katulani  electricity        98.356269       Kitui
# 4096          4097      Kipipiri     firewood       165.415222   Nyandarua
# 1062          1063   Kathonzweni     charcoal       100.164943     Makueni
# 9034          9035       Kipkomo          LPG        80.892520  West Pokot
# 9077          9078      Likuyani     charcoal       124.205552    Kakamega
# 1699          1700        Rangwe          LPG       130.051491    Homa Bay
#
#       income_proxy  regional_weight consumption_category
# 6260             1              NaN                  SME
# 8512             1              NaN                  SME
# 1862             1              NaN             Domestic
# 2502             1              NaN             Domestic
# 101              1              NaN             Domestic
# 6604             0              NaN             Domestic
# 1447             1              NaN                  SME
# 2415             1              NaN                  SME
# 4093             1              NaN                  SME
# 8163             1              NaN                  SME
# 1504             1              NaN                  SME
# 2581             1              NaN                  SME
# 1333             1              NaN                  SME
# 670              1              NaN                  SME
# 7952             1              NaN             Domestic
# 4096             0              NaN                  SME
# 1062             1              NaN                  SME
# 9034             1              NaN             Domestic
# 9077             1              NaN                  SME
# 1699             1              NaN                  SME

# %%
synthetic_ready["income_proxy"].value_counts()
# Out:
# income_proxy
# 1    7493
# 0    2507
# Name: count, dtype: int64

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo        NaN
# Bomet          NaN
# Bungoma        NaN
# Busia          NaN
# Embu           NaN
# Garissa        NaN
# Homa Bay       NaN
# Isiolo         NaN
# Kajiado        NaN
# Kakamega       NaN
# Kericho        NaN
# Kiambu         NaN
# Kilifi         NaN
# Kirinyaga      NaN
# Kisii          NaN
# Kisumu         NaN
# Kitui          NaN
# Kwale          NaN
# Laikipia       NaN
# Lamu           NaN
# Machakos       NaN
# Makueni        NaN
# Mandera        NaN
# Marsabit       NaN
# Meru           NaN
# Migori         NaN
# Mombasa        NaN
# Murang'a       NaN
# Nairobi City   NaN
# Nakuru         NaN
# Nandi          NaN
# Narok          NaN
# Nyamira        NaN
# Nyandarua      NaN
# Nyeri          NaN
# Samburu        NaN
# Siaya          NaN
# Tana River     NaN
# Trans Nzoia    NaN
# Turkana        NaN
# Uasin Gishu    NaN
# Vihiga         NaN
# Wajir          NaN
# West Pokot     NaN
# Name: regional_weight, dtype: float64

# %%
synthetic_ready["consumption_category"].value_counts()
# Out:
# consumption_category
# SME           8342
# Domestic      1658
# Industrial       0
# Name: count, dtype: int64

# %%
print(synthetic_ready.isna().sum())
# Out:
# household_id                0
# subcounty                   0
# cooking_fuel                0
# consumption_kwh             0
# county                      0
# income_proxy                0
# regional_weight         10000
# consumption_category        0
# dtype: int64

# %%
county_map = {
    "Nairobi City":"Nairobi",
    "Murang'a":"Muranga",
    "Mt Kenya Forest":"Mt. Kenya"
}
synthetic_ready["county_clean"] = synthetic_ready["county"].replace(county_map)
synthetic_ready["regional_weight"] = synthetic_ready["county_clean"].map(weights)

# %%
synthetic_ready["consumption_kwh"] = np.random.normal(400, 300, 10000).clip(min=20)

# %%
print(synthetic_ready["regional_weight"].value_counts(dropna=False))
print(synthetic_ready["consumption_category"].value_counts())
# Out:
# regional_weight
# NaN      9706
# 0.442     294
# Name: count, dtype: int64
# consumption_category
# SME           8342
# Domestic      1658
# Industrial       0
# Name: count, dtype: int64

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo           NaN
# Bomet             NaN
# Bungoma           NaN
# Busia             NaN
# Embu              NaN
# Garissa           NaN
# Homa Bay          NaN
# Isiolo            NaN
# Kajiado           NaN
# Kakamega          NaN
# Kericho           NaN
# Kiambu            NaN
# Kilifi            NaN
# Kirinyaga         NaN
# Kisii             NaN
# Kisumu            NaN
# Kitui             NaN
# Kwale             NaN
# Laikipia          NaN
# Lamu              NaN
# Machakos          NaN
# Makueni           NaN
# Mandera           NaN
# Marsabit          NaN
# Meru              NaN
# Migori            NaN
# Mombasa           NaN
# Murang'a          NaN
# Nairobi City    0.442
# Nakuru            NaN
# Nandi             NaN
# Narok             NaN
# Nyamira           NaN
# Nyandarua         NaN
# Nyeri             NaN
# Samburu           NaN
# Siaya             NaN
# Tana River        NaN
# Trans Nzoia       NaN
# Turkana           NaN
# Uasin Gishu       NaN
# Vihiga            NaN
# Wajir             NaN
# West Pokot        NaN
# Name: regional_weight, dtype: float64

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo           NaN
# Bomet             NaN
# Bungoma           NaN
# Busia             NaN
# Embu              NaN
# Garissa           NaN
# Homa Bay          NaN
# Isiolo            NaN
# Kajiado           NaN
# Kakamega          NaN
# Kericho           NaN
# Kiambu            NaN
# Kilifi            NaN
# Kirinyaga         NaN
# Kisii             NaN
# Kisumu            NaN
# Kitui             NaN
# Kwale             NaN
# Laikipia          NaN
# Lamu              NaN
# Machakos          NaN
# Makueni           NaN
# Mandera           NaN
# Marsabit          NaN
# Meru              NaN
# Migori            NaN
# Mombasa           NaN
# Murang'a          NaN
# Nairobi City    0.442
# Nakuru            NaN
# Nandi             NaN
# Narok             NaN
# Nyamira           NaN
# Nyandarua         NaN
# Nyeri             NaN
# Samburu           NaN
# Siaya             NaN
# Tana River        NaN
# Trans Nzoia       NaN
# Turkana           NaN
# Uasin Gishu       NaN
# Vihiga            NaN
# Wajir             NaN
# West Pokot        NaN
# Name: regional_weight, dtype: float64

# %%
county_to_region = {
    # Nairobi
    "Nairobi City": "Nairobi",

    # Coast
    "Mombasa": "Coast", "Kwale": "Coast", "Kilifi": "Coast",
    "Tana River": "Coast", "Lamu": "Coast",
    "Taita Taveta": "Coast",  # moved from "remaining" to Coast

    # North Eastern
    "Garissa": "North Eastern", "Wajir": "North Eastern", "Mandera": "North Eastern",

    # Central Rift
    "Baringo": "Central Rift", "Nakuru": "Central Rift", "Kericho": "Central Rift",
    "Laikipia": "Central Rift",
    "Machakos": "Central Rift", "Makueni": "Central Rift", "Kitui": "Central Rift",
    "Kajiado": "Central Rift", "Narok": "Central Rift",

    # Mt. Kenya
    "Nyeri": "Mt. Kenya", "Kirinyaga": "Mt. Kenya", "Murang'a": "Mt. Kenya",
    "Kiambu": "Mt. Kenya", "Embu": "Mt. Kenya", "Meru": "Mt. Kenya",
    "Tharaka-Nithi": "Mt. Kenya",
    "Isiolo": "Mt. Kenya",  # added from remaining

    # West Kenya
    "Kakamega": "West Kenya", "Vihiga": "West Kenya", "Bungoma": "West Kenya",
    "Busia": "West Kenya",
    "Siaya": "West Kenya",  # added from remaining

    # North Rift
    "Turkana": "North Rift", "West Pokot": "North Rift", "Elgeyo-Marakwet": "North Rift",
    "Nandi": "North Rift", "Uasin Gishu": "North Rift", "Trans Nzoia": "North Rift",
    "Marsabit": "North Rift", "Samburu": "North Rift",  # added from remaining

    # South Nyanza
    "Kisii": "South Nyanza", "Nyamira": "South Nyanza", "Migori": "South Nyanza",
    "Homa Bay": "South Nyanza",
}

# %%
synthetic_ready["region"] = synthetic_ready["county"].map(county_to_region)

weights = {
    "Nairobi":0.442,"Coast":0.165,"North Eastern":0.112,
    "Central Rift":0.093,"Mt. Kenya":0.066,"West Kenya":0.054,
    "North Rift":0.047,"South Nyanza":0.021
}

synthetic_ready["regional_weight"] = synthetic_ready["region"].map(weights)

# %%
print(synthetic_ready["regional_weight"].value_counts(dropna=False))
# Out:
# regional_weight
# 0.093    2405
# 0.066    1745
# 0.054    1412
# 0.047    1181
# 0.021    1110
# 0.165     717
# 0.112     623
# NaN       513
# 0.442     294
# Name: count, dtype: int64

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo         0.093
# Bomet             NaN
# Bungoma         0.054
# Busia           0.054
# Embu            0.066
# Garissa         0.112
# Homa Bay        0.021
# Isiolo          0.066
# Kajiado         0.093
# Kakamega        0.054
# Kericho         0.093
# Kiambu          0.066
# Kilifi          0.165
# Kirinyaga       0.066
# Kisii           0.021
# Kisumu            NaN
# Kitui           0.093
# Kwale           0.165
# Laikipia        0.093
# Lamu            0.165
# Machakos        0.093
# Makueni         0.093
# Mandera         0.112
# Marsabit        0.047
# Meru            0.066
# Migori          0.021
# Mombasa         0.165
# Murang'a        0.066
# Nairobi City    0.442
# Nakuru          0.093
# Nandi           0.047
# Narok           0.093
# Nyamira         0.021
# Nyandarua         NaN
# Nyeri           0.066
# Samburu         0.047
# Siaya           0.054
# Tana River      0.165
# Trans Nzoia     0.047
# Turkana         0.047
# Uasin Gishu     0.047
# Vihiga          0.054
# Wajir           0.112
# West Pokot      0.047
# Name: regional_weight, dtype: float64

# %%
synthetic_ready["region"] = synthetic_ready["county"].map(county_to_region)

weights = {
    "Nairobi":0.442,"Coast":0.165,"North Eastern":0.112,
    "Central Rift":0.093,"Mt. Kenya":0.066,"West Kenya":0.054,
    "North Rift":0.047,"South Nyanza":0.021
}

synthetic_ready["regional_weight"] = synthetic_ready["region"].map(weights)

# %%
county_to_region.update({
    "Bomet": "Central Rift",
    "Kisumu": "West Kenya",
    "Nyandarua": "Mt. Kenya"
})

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo         0.093
# Bomet             NaN
# Bungoma         0.054
# Busia           0.054
# Embu            0.066
# Garissa         0.112
# Homa Bay        0.021
# Isiolo          0.066
# Kajiado         0.093
# Kakamega        0.054
# Kericho         0.093
# Kiambu          0.066
# Kilifi          0.165
# Kirinyaga       0.066
# Kisii           0.021
# Kisumu            NaN
# Kitui           0.093
# Kwale           0.165
# Laikipia        0.093
# Lamu            0.165
# Machakos        0.093
# Makueni         0.093
# Mandera         0.112
# Marsabit        0.047
# Meru            0.066
# Migori          0.021
# Mombasa         0.165
# Murang'a        0.066
# Nairobi City    0.442
# Nakuru          0.093
# Nandi           0.047
# Narok           0.093
# Nyamira         0.021
# Nyandarua         NaN
# Nyeri           0.066
# Samburu         0.047
# Siaya           0.054
# Tana River      0.165
# Trans Nzoia     0.047
# Turkana         0.047
# Uasin Gishu     0.047
# Vihiga          0.054
# Wajir           0.112
# West Pokot      0.047
# Name: regional_weight, dtype: float64

# %%
synthetic_ready["region"] = synthetic_ready["county"].map(county_to_region)
synthetic_ready["regional_weight"] = synthetic_ready["region"].map(weights)

# %%
print(synthetic_ready["regional_weight"].isna().sum())
# Out:
# 0

# %%
synthetic_ready.groupby("county")["regional_weight"].mean()
# Out:
# county
# Baringo         0.093
# Bomet           0.093
# Bungoma         0.054
# Busia           0.054
# Embu            0.066
# Garissa         0.112
# Homa Bay        0.021
# Isiolo          0.066
# Kajiado         0.093
# Kakamega        0.054
# Kericho         0.093
# Kiambu          0.066
# Kilifi          0.165
# Kirinyaga       0.066
# Kisii           0.021
# Kisumu          0.054
# Kitui           0.093
# Kwale           0.165
# Laikipia        0.093
# Lamu            0.165
# Machakos        0.093
# Makueni         0.093
# Mandera         0.112
# Marsabit        0.047
# Meru            0.066
# Migori          0.021
# Mombasa         0.165
# Murang'a        0.066
# Nairobi City    0.442
# Nakuru          0.093
# Nandi           0.047
# Narok           0.093
# Nyamira         0.021
# Nyandarua       0.066
# Nyeri           0.066
# Samburu         0.047
# Siaya           0.054
# Tana River      0.165
# Trans Nzoia     0.047
# Turkana         0.047
# Uasin Gishu     0.047
# Vihiga          0.054
# Wajir           0.112
# West Pokot      0.047
# Name: regional_weight, dtype: float64

# %%
import matplotlib.pyplot as plt

# Compare EPRA official vs synthetic distribution
epra_weights = {
    "Nairobi":0.442,"Coast":0.165,"North Eastern":0.112,
    "Central Rift":0.093,"Mt. Kenya":0.066,"West Kenya":0.054,
    "North Rift":0.047,"South Nyanza":0.021
}

synthetic_dist = synthetic_ready["region"].value_counts(normalize=True)

plt.figure(figsize=(10,6))
plt.bar(epra_weights.keys(), epra_weights.values(), alpha=0.6, label="EPRA Official")
plt.bar(synthetic_dist.index, synthetic_dist.values, alpha=0.6, label="Synthetic Dataset")
plt.ylabel("Proportion")
plt.title("Regional Distribution: EPRA vs Synthetic")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

regions = list(epra_weights.keys())
epra_vals = [epra_weights[r] for r in regions]
synthetic_vals = [synthetic_dist[r] for r in regions]

x = np.arange(len(regions))
width = 0.35  # bar width

plt.figure(figsize=(10,6))
plt.bar(x - width/2, epra_vals, width, label="EPRA Official", color="blue", alpha=0.7)
plt.bar(x + width/2, synthetic_vals, width, label="Synthetic Dataset", color="orange", alpha=0.7)

plt.xticks(x, regions, rotation=45)   # <-- make sure this line is closed
plt.ylabel("Proportion")
plt.title("Regional Distribution: EPRA vs Synthetic")
plt.legend()
plt.show()

plt.figure(figsize=(10,6))
plt.bar(regions, diffs, color="red", alpha=0.7)
plt.axhline(0, color="black", linewidth=1)
plt.ylabel("Synthetic - EPRA")
plt.title("Difference Between Synthetic and EPRA Distribution")
plt.show()

# %%
import numpy as np
import pandas as pd

# EPRA regional weights
weights = {
    "Nairobi":0.442,"Coast":0.165,"North Eastern":0.112,
    "Central Rift":0.093,"Mt. Kenya":0.066,"West Kenya":0.054,
    "North Rift":0.047,"South Nyanza":0.021
}

# Number of synthetic households
n_households = 10000

# Allocate households per region based on EPRA weights
region_counts = {region:int(weight*n_households) for region,weight in weights.items()}

# Generate synthetic households stratified by region
synthetic = []
fuels = ["firewood","charcoal","LPG","electricity"]

for region, count in region_counts.items():
    for i in range(count):
        synthetic.append({
            "household_id": len(synthetic)+1,
            "region": region,
            "cooking_fuel": np.random.choice(fuels),
            "consumption_kwh": np.random.normal(400, 300)  # adjust mean/variance
        })

synthetic_ready = pd.DataFrame(synthetic)

# %%
import numpy as np

diffs = np.array(synthetic_vals) - np.array(epra_vals)
for region, d in zip(regions, diffs):
    print(f"{region}: {d:.4f}")
# Out:
# Nairobi: -0.4126
# Coast: -0.0933
# North Eastern: -0.0497
# Central Rift: 0.1577
# Mt. Kenya: 0.1351
# West Kenya: 0.1017
# North Rift: 0.0711
# South Nyanza: 0.0900

# %%
import numpy as np

# Add small random variation ±2% around EPRA weights
synthetic_vals = [max(0, min(1, v + np.random.uniform(-0.02, 0.02))) for v in epra_vals]

# Normalize so they sum to 1
total = sum(synthetic_vals)
synthetic_vals = [v/total for v in synthetic_vals]

# %%
print(synthetic_ready.isna().sum())
print(synthetic_ready["region"].value_counts(normalize=True))
# Out:
# household_id       0
# region             0
# cooking_fuel       0
# consumption_kwh    0
# dtype: int64
# region
# Nairobi          0.442
# Coast            0.165
# North Eastern    0.112
# Central Rift     0.093
# Mt. Kenya        0.066
# West Kenya       0.054
# North Rift       0.047
# South Nyanza     0.021
# Name: proportion, dtype: float64

# %%
# Allocate households per region based on EPRA weights
n_households = 10000
region_counts = {region:int(weight*n_households) for region, weight in epra_weights.items()}

synthetic = []
fuels = ["firewood","charcoal","LPG","electricity"]

for region, count in region_counts.items():
    for i in range(count):
        synthetic.append({
            "household_id": len(synthetic)+1,
            "region": region,
            "cooking_fuel": np.random.choice(fuels),
            "consumption_kwh": np.random.normal(400, 300)
        })

synthetic_ready = pd.DataFrame(synthetic)

# %%
# Compare EPRA vs Synthetic distributions
epra_vals = np.array([epra_weights[r] for r in regions])
synthetic_vals = np.array([synthetic_ready["region"].value_counts(normalize=True)[r] for r in regions])

diffs = synthetic_vals - epra_vals

print("Mean Absolute Error:", np.mean(np.abs(diffs)))
print("Max Difference:", np.max(np.abs(diffs)))
# Out:
# Mean Absolute Error: 0.0
# Max Difference: 0.0

# %%
print(synthetic_ready.isna().sum())
# Out:
# household_id       0
# region             0
# cooking_fuel       0
# consumption_kwh    0
# dtype: int64

# %%
print(synthetic_ready["region"].value_counts(normalize=True))
# Out:
# region
# Nairobi          0.442
# Coast            0.165
# North Eastern    0.112
# Central Rift     0.093
# Mt. Kenya        0.066
# West Kenya       0.054
# North Rift       0.047
# South Nyanza     0.021
# Name: proportion, dtype: float64

# %%
epra_vals = np.array([epra_weights[r] for r in regions])
synthetic_vals = np.array([synthetic_ready["region"].value_counts(normalize=True)[r] for r in regions])

diffs = synthetic_vals - epra_vals
for region, d in zip(regions, diffs):
    print(f"{region}: {d:.4f}")

print("Mean Absolute Error:", np.mean(np.abs(diffs)))
print("Max Difference:", np.max(np.abs(diffs)))
# Out:
# Nairobi: 0.0000
# Coast: 0.0000
# North Eastern: 0.0000
# Central Rift: 0.0000
# Mt. Kenya: 0.0000
# West Kenya: 0.0000
# North Rift: 0.0000
# South Nyanza: 0.0000
# Mean Absolute Error: 0.0
# Max Difference: 0.0

# %%
# Compare synthetic demand growth vs EPRA's 8.25% benchmark
synthetic_total = synthetic_ready["consumption_kwh"].sum()
epra_baseline = 1.0  # normalized baseline
synthetic_growth = (synthetic_total / synthetic_total) - 1  # or compare against EPRA’s published baseline
print("Synthetic Demand Growth:", synthetic_growth)
print("EPRA Benchmark Growth: 0.0825")
# Out:
# Synthetic Demand Growth: 0.0
# EPRA Benchmark Growth: 0.0825

# %%
capacity_mix = {"Geothermal":0.2572,"Hydro":0.2378,"Solar":0.1474}
renewable_share = sum(capacity_mix.values())
print("Renewable Share:", renewable_share)
# Out:
# Renewable Share: 0.6424

# %%
import pandas as pd

# Assume synthetic_ready already exists with a 'consumption_kwh' column
baseline_total = synthetic_ready["consumption_kwh"].sum()

# Apply EPRA's official 8.25% growth multiplier
growth_factor = 1.0825
projected_total = baseline_total * growth_factor

# Calculate growth
synthetic_growth = (projected_total / baseline_total) - 1

print("Baseline Synthetic Demand (kWh):", baseline_total)
print("Projected Year 1 Demand (kWh):", projected_total)
print("Synthetic Demand Growth:", round(synthetic_growth, 4))
print("EPRA Benchmark Growth: 0.0825")
# Out:
# Baseline Synthetic Demand (kWh): 3984017.7049098248
# Projected Year 1 Demand (kWh): 4312699.165564885
# Synthetic Demand Growth: 0.0825
# EPRA Benchmark Growth: 0.0825

# %%
import pandas as pd

# Regional growth factors from EPRA (YoY % increases)
regional_growth = {
    "South Nyanza": 1.2253,   # +22.53%
    "North Eastern": 1.1373,  # +13.73%
    "Nairobi": 1.0825,        # baseline EPRA growth
    "Coast": 1.0825,
    "Central Rift": 1.0825,
    "Mt. Kenya": 1.0825,
    "West Kenya": 1.0825,
    "North Rift": 1.0825
}

# Apply growth multipliers to consumption_kwh
synthetic_ready["consumption_kwh_projected"] = synthetic_ready.apply(
    lambda row: row["consumption_kwh"] * regional_growth[row["region"]],
    axis=1
)

# Compare baseline vs projected totals
baseline_total = synthetic_ready["consumption_kwh"].sum()
projected_total = synthetic_ready["consumption_kwh_projected"].sum()
synthetic_growth = (projected_total / baseline_total) - 1

print("Baseline Synthetic Demand (kWh):", baseline_total)
print("Projected Year 1 Demand (kWh):", projected_total)
print("Synthetic Demand Growth:", round(synthetic_growth, 4))
print("EPRA Benchmark Growth: 0.0825")

# Regional comparison
regional_projection = synthetic_ready.groupby("region")[["consumption_kwh","consumption_kwh_projected"]].sum()
regional_projection["growth_rate"] = (regional_projection["consumption_kwh_projected"] / regional_projection["consumption_kwh"]) - 1
print(regional_projection)
# Out:
# Baseline Synthetic Demand (kWh): 3984017.7049098248
# Projected Year 1 Demand (kWh): 4349768.417718844
# Synthetic Demand Growth: 0.0918
# EPRA Benchmark Growth: 0.0825
#                consumption_kwh  consumption_kwh_projected  growth_rate
# region
# Central Rift      3.623081e+05               3.921985e+05       0.0825
# Coast             6.729501e+05               7.284685e+05       0.0825
# Mt. Kenya         2.632933e+05               2.850150e+05       0.0825
# Nairobi           1.741477e+06               1.885148e+06       0.0825
# North Eastern     4.525377e+05               5.146711e+05       0.1373
# North Rift        1.942498e+05               2.102754e+05       0.0825
# South Nyanza      8.592569e+04               1.052847e+05       0.2253
# West Kenya        2.112766e+05               2.287069e+05       0.0825

# %%
print("Baseline Synthetic Demand (kWh):", baseline_total)
print("Projected Year 1 Demand (kWh):", projected_total)
print("Synthetic Demand Growth:", round(synthetic_growth, 4))
print("EPRA Benchmark Growth: 0.0825")
# Out:
# Baseline Synthetic Demand (kWh): 3984017.7049098248
# Projected Year 1 Demand (kWh): 4349768.417718844
# Synthetic Demand Growth: 0.0918
# EPRA Benchmark Growth: 0.0825

# %%
print("Baseline Synthetic Demand (kWh):", baseline_total)
print("Projected Year 1 Demand (kWh):", projected_total)
print("Synthetic Demand Growth:", round(synthetic_growth, 4))
print("EPRA Benchmark Growth: 0.0825")
# Out:
# Baseline Synthetic Demand (kWh): 3984017.7049098248
# Projected Year 1 Demand (kWh): 4349768.417718844
# Synthetic Demand Growth: 0.0918
# EPRA Benchmark Growth: 0.0825

# %%
print(regional_projection)
# Out:
#                consumption_kwh  consumption_kwh_projected  growth_rate
# region
# Central Rift      3.623081e+05               3.921985e+05       0.0825
# Coast             6.729501e+05               7.284685e+05       0.0825
# Mt. Kenya         2.632933e+05               2.850150e+05       0.0825
# Nairobi           1.741477e+06               1.885148e+06       0.0825
# North Eastern     4.525377e+05               5.146711e+05       0.1373
# North Rift        1.942498e+05               2.102754e+05       0.0825
# South Nyanza      8.592569e+04               1.052847e+05       0.2253
# West Kenya        2.112766e+05               2.287069e+05       0.0825

# %%
print(synthetic_ready.head())
print(synthetic_ready.columns)
# Out:
#    household_id   region cooking_fuel  consumption_kwh  \
# 0             1  Nairobi     charcoal       416.114069
# 1             2  Nairobi     charcoal       788.856868
# 2             3  Nairobi          LPG       265.797006
# 3             4  Nairobi     charcoal       545.066227
# 4             5  Nairobi     firewood       372.099827
#
#    consumption_kwh_projected
# 0                 450.443479
# 1                 853.937560
# 2                 287.725259
# 3                 590.034191
# 4                 402.798063
# Index(['household_id', 'region', 'cooking_fuel', 'consumption_kwh',
#        'consumption_kwh_projected'],
#       dtype='object')

# %%
print(synthetic_ready.isnull().sum())
# Out:
# household_id                 0
# region                       0
# cooking_fuel                 0
# consumption_kwh              0
# consumption_kwh_projected    0
# dtype: int64

# %%
print(synthetic_ready.shape)
print(synthetic_ready.columns)
# Out:
# (10000, 5)
# Index(['household_id', 'region', 'cooking_fuel', 'consumption_kwh',
#        'consumption_kwh_projected'],
#       dtype='object')

# %%
print(synthetic_ready.sample(20))
# Out:
#       household_id        region cooking_fuel  consumption_kwh  \
# 4540          4541         Coast          LPG       407.595895
# 2356          2357       Nairobi          LPG       470.759702
# 1741          1742       Nairobi     charcoal       598.219365
# 4789          4790         Coast     charcoal       608.429575
# 2926          2927       Nairobi     firewood       284.467957
# 3283          3284       Nairobi     firewood       538.809129
# 4355          4356       Nairobi     firewood       349.624892
# 726            727       Nairobi  electricity      -150.515083
# 1671          1672       Nairobi     charcoal       373.433909
# 3477          3478       Nairobi     firewood      -130.939787
# 9038          9039    West Kenya     firewood       269.282562
# 9187          9188    West Kenya     firewood       174.664842
# 938            939       Nairobi          LPG       782.818524
# 8364          8365     Mt. Kenya  electricity       535.896687
# 8401          8402     Mt. Kenya     firewood       593.602824
# 7647          7648  Central Rift     firewood       311.479596
# 5080          5081         Coast     charcoal        14.162959
# 2636          2637       Nairobi  electricity       540.817842
# 8700          8701     Mt. Kenya     firewood       564.412107
# 123            124       Nairobi          LPG       424.101075
#
#       consumption_kwh_projected
# 4540                 441.222556
# 2356                 509.597377
# 1741                 647.572462
# 4789                 658.625015
# 2926                 307.936564
# 3283                 583.260882
# 4355                 378.468946
# 726                 -162.932577
# 1671                 404.242206
# 3477                -141.742319
# 9038                 291.498373
# 9187                 189.074691
# 938                  847.401052
# 8364                 580.108164
# 8401                 642.575057
# 7647                 337.176663
# 5080                  15.331404
# 2636                 585.435314
# 8700                 610.976106
# 123                  459.089414

# %%
regional_totals = synthetic_ready.groupby("region")["consumption_kwh"].sum()
regional_proportions = regional_totals / regional_totals.sum()

print(regional_proportions)
# Compare against EPRA official proportions
epra_proportions = {
    "Nairobi": 0.442, "Coast": 0.165, "North Eastern": 0.112,
    "Central Rift": 0.093, "Mt. Kenya": 0.066, "West Kenya": 0.054,
    "North Rift": 0.047, "South Nyanza": 0.021
}

mae = sum(abs(regional_proportions[r] - epra_proportions[r]) for r in epra_proportions) / len(epra_proportions)
print("Mean Absolute Error:", mae)
# Out:
# region
# Central Rift     0.090940
# Coast            0.168912
# Mt. Kenya        0.066087
# Nairobi          0.437116
# North Eastern    0.113588
# North Rift       0.048757
# South Nyanza     0.021568
# West Kenya       0.053031
# Name: consumption_kwh, dtype: float64
# Mean Absolute Error: 0.00197823263039515

# %%
baseline_total = synthetic_ready["consumption_kwh"].sum()
projected_total = synthetic_ready["consumption_kwh_projected"].sum()
synthetic_growth = (projected_total / baseline_total) - 1

print("Baseline:", baseline_total)
print("Projected:", projected_total)
print("Synthetic Growth:", round(synthetic_growth, 4))
print("EPRA Benchmark Growth: 0.0825")
# Out:
# Baseline: 3984017.7049098248
# Projected: 4349768.417718844
# Synthetic Growth: 0.0918
# EPRA Benchmark Growth: 0.0825

# %%
regional_projection = synthetic_ready.groupby("region")[["consumption_kwh","consumption_kwh_projected"]].sum()
regional_projection["growth_rate"] = (regional_projection["consumption_kwh_projected"] / regional_projection["consumption_kwh"]) - 1
print(regional_projection)
# Out:
#                consumption_kwh  consumption_kwh_projected  growth_rate
# region
# Central Rift      3.623081e+05               3.921985e+05       0.0825
# Coast             6.729501e+05               7.284685e+05       0.0825
# Mt. Kenya         2.632933e+05               2.850150e+05       0.0825
# Nairobi           1.741477e+06               1.885148e+06       0.0825
# North Eastern     4.525377e+05               5.146711e+05       0.1373
# North Rift        1.942498e+05               2.102754e+05       0.0825
# South Nyanza      8.592569e+04               1.052847e+05       0.2253
# West Kenya        2.112766e+05               2.287069e+05       0.0825

# %%
renewable_share = synthetic_ready["renewable"].sum() / synthetic_ready["capacity"].sum()
print("Synthetic Renewable Share:", renewable_share)
print("EPRA Renewable Share: 0.7879")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'renewable'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 renewable_share = synthetic_ready["renewable"].sum() / synthetic_ready["capacity"].sum()
#       2 print("Synthetic Renewable Share:", renewable_share)
#       3 print("EPRA Renewable Share: 0.7879")
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\equitariff\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'renewable'

# %%
import os

# Create the processed folder if it doesn't exist
os.makedirs("data/processed", exist_ok=True)

# Now save the dataset
synthetic_ready.to_csv("data/processed/synthetic_dataset.csv", index=False)

print(" Synthetic dataset saved to data/processed/synthetic_dataset.csv")
# Out:
#  Synthetic dataset saved to data/processed/synthetic_dataset.csv
